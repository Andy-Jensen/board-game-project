# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('games.csv')

# %%
df
# Out:
#      Unnamed: 0          id                       handle  \
# 0             0  TAAifFP590                         root
# 1             1  yqR4PtpO8X                       scythe
# 2             2  5H5JS0KLzK                     wingspan
# 3             3  RLlDWHh7hR                   gloomhaven
# 4             4  fDn9rQjH9O            terraforming-mars
# ..          ...         ...                          ...
# 995         995  utvG6nvnq5                    snake-oil
# 996         996  2LJTEmU5LY    bob-ross-the-art-of-chill
# 997         997  JBQPZrO0yC           a-study-in-emerald
# 998         998  kz2pqBlpT4          mansions-of-madness
# 999         999  kgs5t2m5kv  kokoro-avenue-of-the-kodama
#
#                                                    url  \
# 0    https://www.boardgameatlas.com/game/TAAifFP590...
# 1    https://www.boardgameatlas.com/game/yqR4PtpO8X...
# 2    https://www.boardgameatlas.com/game/5H5JS0KLzK...
# ...

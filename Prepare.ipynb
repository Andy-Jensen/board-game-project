# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('games.csv')

# %%
df
# Out:
#              id                       handle  \
# 0    TAAifFP590                         root
# 1    yqR4PtpO8X                       scythe
# 2    5H5JS0KLzK                     wingspan
# 3    RLlDWHh7hR                   gloomhaven
# 4    fDn9rQjH9O            terraforming-mars
# ..          ...                          ...
# 995  utvG6nvnq5                    snake-oil
# 996  2LJTEmU5LY    bob-ross-the-art-of-chill
# 997  JBQPZrO0yC           a-study-in-emerald
# 998  kz2pqBlpT4          mansions-of-madness
# 999  kgs5t2m5kv  kokoro-avenue-of-the-kodama
#
#                                                    url  \
# 0    https://www.boardgameatlas.com/game/TAAifFP590...
# 1    https://www.boardgameatlas.com/game/yqR4PtpO8X...
# 2    https://www.boardgameatlas.com/game/5H5JS0KLzK...
# 3    https://www.boardgameatlas.com/game/RLlDWHh7hR...
# 4    https://www.boardgameatlas.com/game/fDn9rQjH9O...
# ..                                                 ...
# 995  https://www.boardgameatlas.com/game/utvG6nvnq5...
# 996  https://www.boardgameatlas.com/game/2LJTEmU5LY...
# 997  https://www.boardgameatlas.com/game/JBQPZrO0yC...
# 998  https://www.boardgameatlas.com/game/kz2pqBlpT4...
# 999  https://www.boardgameatlas.com/game/kgs5t2m5kv...
#
#                                           bga_edit_url  \
# 0    https://www.boardgameatlas.com/game/TAAifFP590...
# 1    https://www.boardgameatlas.com/game/yqR4PtpO8X...
# 2    https://www.boardgameatlas.com/game/5H5JS0KLzK...
# 3    https://www.boardgameatlas.com/game/RLlDWHh7hR...
# 4    https://www.boardgameatlas.com/game/fDn9rQjH9O...
# ..                                                 ...
# 995  https://www.boardgameatlas.com/game/utvG6nvnq5...
# 996  https://www.boardgameatlas.com/game/2LJTEmU5LY...
# 997  https://www.boardgameatlas.com/game/JBQPZrO0yC...
# 998  https://www.boardgameatlas.com/game/kz2pqBlpT4...
# 999  https://www.boardgameatlas.com/game/kgs5t2m5kv...
#
#                                           template_url  \
# 0    /products/listing?objectId=TAAifFP590&product_...
# 1    /products/listing?objectId=yqR4PtpO8X&product_...
# 2    /products/listing?objectId=5H5JS0KLzK&product_...
# 3    /products/listing?objectId=RLlDWHh7hR&product_...
# 4    /products/listing?objectId=fDn9rQjH9O&product_...
# ..                                                 ...
# 995  /products/listing?objectId=utvG6nvnq5&product_...
# 996  /products/listing?objectId=2LJTEmU5LY&product_...
# 997  /products/listing?objectId=JBQPZrO0yC&product_...
# 998  /products/listing?objectId=kz2pqBlpT4&product_...
# 999  /products/listing?objectId=kgs5t2m5kv&product_...
#
#                              name   price  price_ca  price_uk  price_au  ...  \
# 0                            Root   45.00     60.96      0.00     71.99  ...
# 1                          Scythe   54.39     78.95     72.17     99.00  ...
# 2                        Wingspan   50.00     32.59     37.31     40.00  ...
# 3                      Gloomhaven  105.97    110.99      0.00    184.95  ...
# 4               Terraforming Mars   51.99     12.99     50.17     79.99  ...
# ..                            ...     ...       ...       ...       ...  ...
# 995                     Snake Oil   19.99     22.95      0.00     40.00  ...
# 996     Bob Ross the Art of Chill   24.46     22.49     17.27      0.00  ...
# 997            A Study in Emerald  149.95      0.00      0.00      0.00  ...
# 998           Mansions of Madness    5.89    119.95      0.00      0.00  ...
# 999  Kokoro: Avenue of the Kodama   13.39     13.99     15.99     27.99  ...
#
#      playtime msrp_text  price_text  \
# 0       60-90    $60.00      $45.00
# 1      90-120    $90.00      $54.39
# 2       40-70    $60.00      $50.00
# 3      60-150   $140.00     $105.97
# 4      90-120    $69.95      $51.99
# ..        ...       ...         ...
# 995     20-30    $19.95      $19.99
# 996        30    $31.99      $24.46
# 997        90       NaN     $149.95
# 998   120-180    $99.95       $5.89
# 999     30-45    $19.99      $13.39
#
#                                                   tags  \
# 0    ['Корни', '茂林源记', '루트', 'Root', 'Root A Game o...
# 1    ['Sçythe', 'Серп', '大鎌戦役', '鐮刀戰爭', '사이쓰', 'Кос...
# 2    ['Fesztáv', 'Flügelschlag', 'Na křídlech', 'Na...
# 3    ['Homályrév', '幽港迷城', '글룸헤이븐', 'Gloomhaven', '...
# 4    ['A Mars terraformálása', 'Mars: Teraformace',...
# ..                                                 ...
# 995  ['Snake Oil Collection Base Game Party Potion'...
# 996  ['Bob Ross: Art of Chill Game', 'Bob Ross Art ...
# 997  ['Study in Emerald A Kickstarter Edition', 'A ...
# 998  ['Le Case della Follia', "Les Demeures de l'Ép...
# 999  ['Kokoro Avenue of the Kodama', 'KOKORO AVENUE...
#
#                                                 images  \
# 0    {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 1    {'thumb': 'https://cdn.shopify.com/s/files/1/0...
# 2    {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 3    {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 4    {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# ..                                                 ...
# 995  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 996  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 997  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 998  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 999  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
#
#                                    description_preview cs_rating  \
# 0     Find adventure in this marvelous asymmetric g...       NaN
# 1      Scythe  gives players almost complete contro...       4.7
# 2       Wingspan   is a competitive, medium-weight,...       NaN
# 3      Gloomhaven  is a game of Euro-inspired tacti...       4.3
# 4     In the 2400s, mankind begins to terraform the...       4.7
# ..                                                 ...       ...
# 995   In the Old West, the wily snake oil salesman ...       4.1
# 996   Earn "chill points" by painting landscape fea...       NaN
# 997                                                NaN       NaN
# 998   Horrific monsters and spectral presences lurk...       NaN
# 999   The enchanted forest of the kodama is flouris...       4.3
#
#      sell_sheet_url  store_images_url  size_width
# 0               NaN               NaN         NaN
# 1               NaN               NaN         NaN
# 2               NaN               NaN         NaN
# 3               NaN               NaN         NaN
# 4               NaN               NaN         NaN
# ..              ...               ...         ...
# 995             NaN               NaN         NaN
# 996             NaN               NaN         NaN
# 997             NaN               NaN         NaN
# 998             NaN               NaN         NaN
# 999             NaN               NaN         NaN
#
# [1000 rows x 84 columns]

# %%
df.columns
# Out:
# Index(['id', 'handle', 'url', 'bga_edit_url', 'template_url', 'name', 'price',
#        'price_ca', 'price_uk', 'price_au', 'msrp', 'msrps', 'discount',
#        'year_published', 'min_players', 'max_players', 'player_counts',
#        'min_playtime', 'max_playtime', 'min_age', 'description', 'commentary',
#        'faq', 'thumb_url', 'image_url', 'matches_specs', 'specs', 'mechanics',
#        'categories', 'publishers', 'designers', 'primary_publisher',
#        'primary_designer', 'developers', 'related_to', 'related_as', 'artists',
#        'names', 'rules_url', 'amazon_rank', 'official_url', 'comment_count',
#        'num_user_ratings', 'average_user_rating', 'weight_amount',
#        'weight_units', 'size_height', 'size_depth', 'size_units',
#        'historical_low_prices', 'active', 'num_user_complexity_votes',
#        'average_learning_complexity', 'average_strategy_complexity', 'visits',
#        'lists', 'mentions', 'links', 'plays', 'rank', 'type', 'sku', 'upc',
#        'isbn', 'video_links', 'availability_status', 'num_distributors',
#        'trending_rank', 'listing_clicks', 'is_historical_low', 'skus',
#        'sku_objects', 'edit_url', 'players', 'playtime', 'msrp_text',
#        'price_text', 'tags', 'images', 'description_preview', 'cs_rating',
#        'sell_sheet_url', 'store_images_url', 'size_width'],
#       dtype='object')

# %% [markdown]
# ## Columns that stick out and may want to keep:
# name, price, year_published, min_players, max_players, player_counts, min_playtime, max_playtime, min_age, description, commentary, mechanics, categories, publishers, designers, primary_publisher, primary_designer, developers, amazon_rank, num_user_ratings, average_user_rating, rank, weight_amount, weight_units, size_height, size_depth, size_units, historical_low_prices, active, num_user_complexity_votes, average_learning_complexity, average_strategy_complexity, num_distributors, cs_rating

# %%
for col in df:
    print(col)
    print(df[col].isna().sum())
# Out:
# id
# 0
# handle
# 0
# url
# 0
# bga_edit_url
# 0
# template_url
# 0
# name
# 0
# price
# 0
# price_ca
# 0
# price_uk
# 0
# price_au
# 0
# msrp
# 1
# msrps
# 8
# discount
# 0
# year_published
# 17
# min_players
# 5
# max_players
# 5
# player_counts
# 5
# min_playtime
# 5
# max_playtime
# 5
# min_age
# 8
# description
# 22
# commentary
# 987
# faq
# 987
# thumb_url
# 0
# image_url
# 0
# matches_specs
# 1000
# specs
# 0
# mechanics
# 0
# categories
# 0
# publishers
# 0
# designers
# 0
# primary_publisher
# 1
# primary_designer
# 7
# developers
# 0
# related_to
# 0
# related_as
# 0
# artists
# 0
# names
# 0
# rules_url
# 540
# amazon_rank
# 227
# official_url
# 224
# comment_count
# 0
# num_user_ratings
# 0
# average_user_rating
# 0
# weight_amount
# 862
# weight_units
# 868
# size_height
# 748
# size_depth
# 851
# size_units
# 862
# historical_low_prices
# 15
# active
# 0
# num_user_complexity_votes
# 0
# average_learning_complexity
# 0
# average_strategy_complexity
# 0
# visits
# 0
# lists
# 0
# mentions
# 0
# links
# 0
# plays
# 0
# rank
# 0
# type
# 0
# sku
# 592
# upc
# 197
# isbn
# 1000
# video_links
# 940
# availability_status
# 934
# num_distributors
# 0
# trending_rank
# 0
# listing_clicks
# 0
# is_historical_low
# 0
# skus
# 2
# sku_objects
# 2
# edit_url
# 0
# players
# 5
# playtime
# 7
# msrp_text
# 25
# price_text
# 0
# tags
# 0
# images
# 0
# description_preview
# 22
# cs_rating
# 502
# sell_sheet_url
# 998
# store_images_url
# 998
# size_width
# 992

# %%
df.id.nunique()
# Out:
# 1000

# %% [markdown]
# ## Drop columns with a substantal amount of nulls

# %%
df=df.drop(columns=['size_width', 'store_images_url', 'sell_sheet_url', 'cs_rating', 'availability_status',
                    'video_links', 'isbn', 'upc', 'sku', 'size_units', 'size_depth', 'size_height',
                    'weight_units', 'weight_amount', 'rules_url', 'matches_specs', 'faq', 'commentary'])

# %%
df.columns
# Out:
# Index(['id', 'handle', 'url', 'bga_edit_url', 'template_url', 'name', 'price',
#        'price_ca', 'price_uk', 'price_au', 'msrp', 'msrps', 'discount',
#        'year_published', 'min_players', 'max_players', 'player_counts',
#        'min_playtime', 'max_playtime', 'min_age', 'description', 'thumb_url',
#        'image_url', 'specs', 'mechanics', 'categories', 'publishers',
#        'designers', 'primary_publisher', 'primary_designer', 'developers',
#        'related_to', 'related_as', 'artists', 'names', 'amazon_rank',
#        'official_url', 'comment_count', 'num_user_ratings',
#        'average_user_rating', 'historical_low_prices', 'active',
#        'num_user_complexity_votes', 'average_learning_complexity',
#        'average_strategy_complexity', 'visits', 'lists', 'mentions', 'links',
#        'plays', 'rank', 'type', 'num_distributors', 'trending_rank',
#        'listing_clicks', 'is_historical_low', 'skus', 'sku_objects',
#        'edit_url', 'players', 'playtime', 'msrp_text', 'price_text', 'tags',
#        'images', 'description_preview'],
#       dtype='object')

# %% [markdown]
# ## Drop Columns that I don't want

# %%
df.trending_rank.value_counts()
# Out:
# 0      963
# 20       1
# 69       1
# 30       1
# 93       1
# 39       1
# 2        1
# 44       1
# 57       1
# 10       1
# 82       1
# 46       1
# 4        1
# 95       1
# 58       1
# 31       1
# 49       1
# 17       1
# 27       1
# 50       1
# 62       1
# 81       1
# 65       1
# 90       1
# 28       1
# 68       1
# 51       1
# 45       1
# 19       1
# 11       1
# 55       1
# 98       1
# 73       1
# 86       1
# 38       1
# 92       1
# 25       1
# 100      1
# Name: trending_rank, dtype: int64

# %%
df=df.drop(columns=['url', 'bga_edit_url', 'template_url', 'discount', 'thumb_url', 'image_url',
                    'official_url', 'historical_low_prices', 'is_historical_low', 'skus', 'edit_url',
                    'images', 'msrps', 'sku_objects', 'tags', 'msrp_text', 'price_text', 'trending_rank',
                    'price_ca', 'price_uk', 'price_au', 'player_counts', 'players', 'playtime',
                    'visits', 'lists', 'mentions', 'links', 'plays', 'developers', 'related_to',
                    'related_as', 'names', 'comment_count', 'description', 'specs', 'handle', 'active',
                    'listing_clicks'])

# %% [markdown]
# ## drop visits, lists, mentions, links, and plays because if a high rated game is made it will naturally accumulate these due to popularity

# %%
pd.set_option('display.max_columns', 500)

# %%
df
# Out:
#              id                          name   price    msrp  year_published  \
# 0    TAAifFP590                          Root   45.00   60.00          2018.0
# 1    yqR4PtpO8X                        Scythe   54.39   90.00          2016.0
# 2    5H5JS0KLzK                      Wingspan   50.00   60.00          2019.0
# 3    RLlDWHh7hR                    Gloomhaven  105.97  140.00          2017.0
# 4    fDn9rQjH9O             Terraforming Mars   51.99   69.95          2016.0
# ..          ...                           ...     ...     ...             ...
# 995  utvG6nvnq5                     Snake Oil   19.99   19.95          2010.0
# 996  2LJTEmU5LY     Bob Ross the Art of Chill   24.46   31.99          2017.0
# 997  JBQPZrO0yC            A Study in Emerald  149.95    0.00          2013.0
# 998  kz2pqBlpT4           Mansions of Madness    5.89   99.95          2011.0
# 999  kgs5t2m5kv  Kokoro: Avenue of the Kodama   13.39   19.99          2017.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 0            2.0          4.0          60.0          90.0     10.0
# 1            1.0          5.0          90.0         120.0     14.0
# 2            1.0          5.0          40.0          70.0     10.0
# 3            1.0          4.0          60.0         150.0     12.0
# 4            1.0          5.0          90.0         120.0     12.0
# ..           ...          ...           ...           ...      ...
# 995          3.0         10.0          20.0          30.0     10.0
# 996          2.0          4.0          30.0          30.0     12.0
# 997          2.0          5.0          90.0          90.0     13.0
# 998          2.0          5.0         120.0         180.0     13.0
# 999          2.0          8.0          30.0          45.0     14.0
#
#                                              mechanics  \
# 0    [{'id': 'PGjmKGi26h', 'url': 'https://www.boar...
# 1    [{'id': 'Bc7R8pLoGk', 'url': 'https://www.boar...
# 2    [{'id': 'R0bGq4cAl4', 'url': 'https://www.boar...
# 3    [{'id': 'xuphiSlrxI', 'url': 'https://www.boar...
# 4    [{'id': '05zCZoLvQJ', 'url': 'https://www.boar...
# ..                                                 ...
# 995                                                 []
# 996  [{'id': 'oeg6wN9Eoc', 'url': 'https://www.boar...
# 997                                                 []
# 998  [{'id': 'R0bGq4cAl4', 'url': 'https://www.boar...
# 999  [{'id': 'MaXzmoZUoX', 'url': 'https://www.boar...
#
#                                             categories  \
# 0    [{'id': 'KUBCKBkGxV', 'url': 'https://www.boar...
# 1    [{'id': '85OKv8p5Ow', 'url': 'https://www.boar...
# 2    [{'id': 'MWoxgHrOJD', 'url': 'https://www.boar...
# 3    [{'id': 'KUBCKBkGxV', 'url': 'https://www.boar...
# 4    [{'id': 'zyj9ZK3mHB', 'url': 'https://www.boar...
# ..                                                 ...
# 995  [{'id': 'eX8uuNlQkQ', 'url': 'https://www.boar...
# 996                                                 []
# 997                                                 []
# 998  [{'id': 'g2Hwv8t0Y5', 'url': 'https://www.boar...
# 999  [{'id': 'vRbkg1W0AB', 'url': 'https://www.boar...
#
#                                             publishers  \
# 0    [{'id': 'jyc9bV7f9D', 'num_games': None, 'scor...
# 1    [{'id': 'njVFVNfJc7', 'num_games': None, 'scor...
# 2    [{'id': 'njVFVNfJc7', 'num_games': None, 'scor...
# 3    [{'id': 'VJ5nXRHPzv', 'num_games': None, 'scor...
# 4    [{'id': '9UanxBIwen', 'num_games': None, 'scor...
# ..                                                 ...
# 995  [{'id': 'YXGqYgPuvL', 'num_games': None, 'scor...
# 996  [{'id': 'XUf47NWGsH', 'num_games': None, 'scor...
# 997  [{'id': 'drLRBKM1hx', 'num_games': None, 'scor...
# 998  [{'id': 'fLH8tXTBBp', 'num_games': None, 'scor...
# 999  [{'id': 'Er8I3hmZPS', 'num_games': None, 'scor...
#
#                                              designers  \
# 0    [{'id': 'DJCmDFXmsh', 'num_games': None, 'scor...
# 1    [{'id': 'QIz5pAPzFk', 'num_games': None, 'scor...
# 2    [{'id': 'UBhK4cSEV6', 'num_games': None, 'scor...
# 3    [{'id': '7emo74yKS4', 'num_games': None, 'scor...
# 4    [{'id': 'B8c4NTLf9Z', 'num_games': None, 'scor...
# ..                                                 ...
# 995  [{'id': 'i0M0dBDiY9', 'num_games': None, 'scor...
# 996  [{'id': 'AJZLd7nMrz', 'num_games': None, 'scor...
# 997  [{'id': 'R9tODiQBST', 'num_games': None, 'scor...
# 998  [{'id': 'XuMPJXJGEy', 'num_games': None, 'scor...
# 999  [{'id': 'JxW1XliCPM', 'num_games': None, 'scor...
#
#                                      primary_publisher  \
# 0    {'id': 'jyc9bV7f9D', 'name': 'Leder Games', 'u...
# 1    {'id': 'njVFVNfJc7', 'name': 'Stonemaier Games...
# 2    {'id': 'njVFVNfJc7', 'name': 'Stonemaier Games...
# 3    {'id': 'VJ5nXRHPzv', 'name': 'Cephalofair Game...
# 4    {'id': '9UanxBIwen', 'name': 'FryxGames', 'url...
# ..                                                 ...
# 995  {'name': 'Snake Oil, LLC', 'id': 'YXGqYgPuvL',...
# 996  {'id': 'XUf47NWGsH', 'name': 'Big G Creative',...
# 997  {'name': 'Treefrog Games', 'id': 'drLRBKM1hx',...
# 998  {'id': 'fLH8tXTBBp', 'name': 'Fantasy Flight G...
# 999  {'id': 'Er8I3hmZPS', 'name': 'Indie Boards & C...
#
#                                       primary_designer  \
# 0    {'id': 'DJCmDFXmsh', 'name': 'Cole Wehrle', 'u...
# 1    {'id': 'QIz5pAPzFk', 'name': 'Jamey Stegmaier'...
# 2    {'id': 'UBhK4cSEV6', 'name': 'Elizabeth Hargra...
# 3    {'id': '7emo74yKS4', 'name': 'Isaac Childres',...
# 4    {'id': 'B8c4NTLf9Z', 'name': 'Jacob Fryxelius'...
# ..                                                 ...
# 995  {'name': 'Jeff Ochs', 'id': 'i0M0dBDiY9', 'url...
# 996  {'id': 'AJZLd7nMrz', 'name': 'Prospero Hall', ...
# 997  {'name': 'Martin Wallace', 'id': 'R9tODiQBST',...
# 998  {'id': 'XuMPJXJGEy', 'name': 'Corey Konieczka'...
# 999  {'id': 'JxW1XliCPM', 'name': 'Eilif Svensson',...
#
#                                                artists  amazon_rank  \
# 0                                      ['Kyle Ferrin']      16636.0
# 1                                   ['Jakub Różalski']       1583.0
# 2    ['Ana Maria Martinez Jaramillo', 'Natalia Roja...          NaN
# 3    ['Alexandr Elichev', 'Josh T. McDowell', 'Alva...          4.0
# 4                                  ['Isaac Fryxelius']       2818.0
# ..                                                 ...          ...
# 995         ['John Kovalic', 'Patricia Hayes Kaufman']      99429.0
# 996                                       ['Bob Ross']      12615.0
# 997                                    ['Anne Stokes']          NaN
# 998  ['Christopher Burdett', 'Anders Finér', 'Henni...          NaN
# 999                ['Kwanchai Moriya', 'Daniel Solis']     244208.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 0                 412             4.059395                         11
# 1                 763             4.213439                         17
# 2                 589             4.162919                         12
# 3                 491             4.351614                         10
# 4                 713             4.146214                         10
# ..                ...                  ...                        ...
# 995                67             3.130597                          0
# 996                64             3.370312                          1
# 997                30             3.433333                          0
# 998                68             3.252941                          0
# 999                58             3.312069                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 0                       3.818182                     3.636364     1  game
# 1                       3.117647                     3.235294     2  game
# 2                       2.500000                     2.833333     3  game
# 3                       3.900000                     3.600000     4  game
# 4                       3.000000                     3.300000     5  game
# ..                           ...                          ...   ...   ...
# 995                     0.000000                     0.000000   939  game
# 996                     3.000000                     2.000000   940  game
# 997                     0.000000                     0.000000   940  game
# 998                     0.000000                     0.000000   941  game
# 999                     0.000000                     0.000000   942  game
#
#      num_distributors                                description_preview
# 0                   6   Find adventure in this marvelous asymmetric g...
# 1                   9    Scythe  gives players almost complete contro...
# 2                  11     Wingspan   is a competitive, medium-weight,...
# 3                   5    Gloomhaven  is a game of Euro-inspired tacti...
# 4                   3   In the 2400s, mankind begins to terraform the...
# ..                ...                                                ...
# 995                 0   In the Old West, the wily snake oil salesman ...
# 996                 0   Earn "chill points" by painting landscape fea...
# 997                 0                                                NaN
# 998                 4   Horrific monsters and spectral presences lurk...
# 999                 0   The enchanted forest of the kodama is flouris...
#
# [1000 rows x 27 columns]

# %%
df.type.value_counts()
# Out:
# game         880
# expansion    119
# accessory      1
# Name: type, dtype: int64

# %%
mech=df['mechanics'][0]
mech
# Out:
# "[{'id': 'PGjmKGi26h', 'url': 'https://www.boardgameatlas.com/mechanic/PGjmKGi26h/undefined'}, {'id': 'ckCp1oTVMy', 'url': 'https://www.boardgameatlas.com/mechanic/ckCp1oTVMy/undefined'}, {'id': '05zCZoLvQJ', 'url': 'https://www.boardgameatlas.com/mechanic/05zCZoLvQJ/undefined'}, {'id': 'R0bGq4cAl4', 'url': 'https://www.boardgameatlas.com/mechanic/R0bGq4cAl4/undefined'}, {'id': 'yu3eas6v7A', 'url': 'https://www.boardgameatlas.com/mechanic/yu3eas6v7A/undefined'}, {'id': 'WPytek5P8l', 'url': 'https://www.boardgameatlas.com/mechanic/WPytek5P8l/undefined'}, {'id': 'MEAoOygZsA', 'url': 'https://www.boardgameatlas.com/mechanic/MEAoOygZsA/undefined'}, {'id': 'qZx4PEzKKz', 'url': 'https://www.boardgameatlas.com/mechanic/qZx4PEzKKz/undefined'}, {'id': 'XM2FYZmBHH', 'url': 'https://www.boardgameatlas.com/mechanic/XM2FYZmBHH/undefined'}]"

# %%
import env
import requests

# %%
url=f'https://api.boardgameatlas.com/api/game/mechanics?client_id={env.key}'

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data=response.json()

# %%
data
# Out:
# {'mechanics': [{'id': 'SWJGuaim9h',
#    'name': 'AI enemies',
#    'url': 'https://www.boardgameatlas.com/mechanic/SWJGuaim9h/ai-enemies'},
#   {'id': 'n1GtBt35Rd',
#    'name': 'Acting',
#    'url': 'https://www.boardgameatlas.com/mechanic/n1GtBt35Rd/acting'},
#   {'id': 'TEmgapaEg0',
#    'name': 'Action / Event',
#    'url': 'https://www.boardgameatlas.com/mechanic/TEmgapaEg0/action--event'},
#   {'id': 'PGjmKGi26h',
#    'name': 'Action / Movement Programming',
#    'url': 'https://www.boardgameatlas.com/mechanic/PGjmKGi26h/action--movement-programming'},
#   {'id': 'UAV3t3FxVI',
#    'name': 'Action Drafting',
#    'url': 'https://www.boardgameatlas.com/mechanic/UAV3t3FxVI/action-drafting'},
#   {'id': 'oeg6wN9Eoc',
#    'name': 'Action Point Allowance System',
#    'url': 'https://www.boardgameatlas.com/mechanic/oeg6wN9Eoc/action-point-allowance-system'},
#   {'id': 'ckCp1oTVMy',
#    'name': 'Action Queue',
#    'url': 'https://www.boardgameatlas.com/mechanic/ckCp1oTVMy/action-queue'},
#   {'id': 'EluAnyIJKY',
#    'name': 'Action Retrieval',
#    'url': 'https://www.boardgameatlas.com/mechanic/EluAnyIJKY/action-retrieval'},
#   {'id': 'Bc7R8pLoGk',
#    'name': 'Action Selection',
#    'url': 'https://www.boardgameatlas.com/mechanic/Bc7R8pLoGk/action-selection'},
#   {'id': 'j2A0uFmdgc',
#    'name': 'Action Timer',
#    'url': 'https://www.boardgameatlas.com/mechanic/j2A0uFmdgc/action-timer'},
#   {'id': 'LfQ9fgn7Zu',
#    'name': 'Action economy',
#    'url': 'https://www.boardgameatlas.com/mechanic/LfQ9fgn7Zu/action-economy'},
#   {'id': '9l8kOZQEEa',
#    'name': 'Added Mechanics',
#    'url': 'https://www.boardgameatlas.com/mechanic/9l8kOZQEEa/added-mechanics'},
#   {'id': 'klT5dZnO4G',
#    'name': 'Advantage Token',
#    'url': 'https://www.boardgameatlas.com/mechanic/klT5dZnO4G/advantage-token'},
#   {'id': 'Hef8hzPH7C',
#    'name': 'Alliances',
#    'url': 'https://www.boardgameatlas.com/mechanic/Hef8hzPH7C/alliances'},
#   {'id': 'TlGfAobFpp',
#    'name': 'App Driven',
#    'url': 'https://www.boardgameatlas.com/mechanic/TlGfAobFpp/app-driven'},
#   {'id': '05zCZoLvQJ',
#    'name': 'Area Control',
#    'url': 'https://www.boardgameatlas.com/mechanic/05zCZoLvQJ/area-control'},
#   {'id': '3te2oybNR4',
#    'name': 'Area Enclosure',
#    'url': 'https://www.boardgameatlas.com/mechanic/3te2oybNR4/area-enclosure'},
#   {'id': '9NBcz45nN7',
#    'name': 'Area Majority/ Influence',
#    'url': 'https://www.boardgameatlas.com/mechanic/9NBcz45nN7/area-majority-influence'},
#   {'id': 'bgGxE0pI2B',
#    'name': 'Area Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/bgGxE0pI2B/area-movement'},
#   {'id': 'zlsyLiomoR',
#    'name': 'Area development',
#    'url': 'https://www.boardgameatlas.com/mechanic/zlsyLiomoR/area-development'},
#   {'id': 'AZxlPpi5oq',
#    'name': 'Auction',
#    'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/auction'},
#   {'id': '7gpfubluzg',
#    'name': 'Auction: Dutch',
#    'url': 'https://www.boardgameatlas.com/mechanic/7gpfubluzg/auction-dutch'},
#   {'id': '6Lo2vLiex6',
#    'name': 'Auction: Sealed Bid',
#    'url': 'https://www.boardgameatlas.com/mechanic/6Lo2vLiex6/auction-sealed-bid'},
#   {'id': 'IAuH3ICIyC',
#    'name': 'Automatic Resource Growth',
#    'url': 'https://www.boardgameatlas.com/mechanic/IAuH3ICIyC/automatic-resource-growth'},
#   {'id': '1382oBW7iB',
#    'name': 'Bag Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/1382oBW7iB/bag-building'},
#   {'id': '3tuJiW3pps',
#    'name': 'Betting',
#    'url': 'https://www.boardgameatlas.com/mechanic/3tuJiW3pps/betting'},
#   {'id': 'tKZiGvSxAC',
#    'name': 'Bias',
#    'url': 'https://www.boardgameatlas.com/mechanic/tKZiGvSxAC/bias'},
#   {'id': 'issXRWXSLg',
#    'name': 'Bidding',
#    'url': 'https://www.boardgameatlas.com/mechanic/issXRWXSLg/bidding'},
#   {'id': '71HG4TJaoD',
#    'name': 'Bingo',
#    'url': 'https://www.boardgameatlas.com/mechanic/71HG4TJaoD/bingo'},
#   {'id': 'ZX3hYcF9H7',
#    'name': 'Bluffing',
#    'url': 'https://www.boardgameatlas.com/mechanic/ZX3hYcF9H7/bluffing'},
#   {'id': 'QFxeEMMQAM',
#    'name': 'Bribery',
#    'url': 'https://www.boardgameatlas.com/mechanic/QFxeEMMQAM/bribery'},
#   {'id': 'xuphiSlrxI',
#    'name': 'Campaign',
#    'url': 'https://www.boardgameatlas.com/mechanic/xuphiSlrxI/campaign'},
#   {'id': 'ml9upz5Me9',
#    'name': 'Campaign / Battle Card Driven',
#    'url': 'https://www.boardgameatlas.com/mechanic/ml9upz5Me9/campaign--battle-card-driven'},
#   {'id': 'NN3nIS4Anc',
#    'name': 'Card Crafting',
#    'url': 'https://www.boardgameatlas.com/mechanic/NN3nIS4Anc/card-crafting'},
#   {'id': 'iWODHwRGuU',
#    'name': 'Card Drafting',
#    'url': 'https://www.boardgameatlas.com/mechanic/iWODHwRGuU/card-drafting'},
#   {'id': 'ngCSHHk0H2',
#    'name': 'Card Placement',
#    'url': 'https://www.boardgameatlas.com/mechanic/ngCSHHk0H2/card-placement'},
#   {'id': 's0OA3pn2fn',
#    'name': 'Card Play Conflict Resolution',
#    'url': 'https://www.boardgameatlas.com/mechanic/s0OA3pn2fn/card-play-conflict-resolution'},
#   {'id': '6YTZ0juKWy',
#    'name': 'Catch the Leader',
#    'url': 'https://www.boardgameatlas.com/mechanic/6YTZ0juKWy/catch-the-leader'},
#   {'id': 'PzEJDypMgC',
#    'name': 'Chaining',
#    'url': 'https://www.boardgameatlas.com/mechanic/PzEJDypMgC/chaining'},
#   {'id': 'Oz9Z9e0GO5',
#    'name': 'Character Progression',
#    'url': 'https://www.boardgameatlas.com/mechanic/Oz9Z9e0GO5/character-progression'},
#   {'id': 'Gan96fffLL',
#    'name': 'Chit-Pull System',
#    'url': 'https://www.boardgameatlas.com/mechanic/Gan96fffLL/chitpull-system'},
#   {'id': '5VI7UEXztV',
#    'name': 'Closed Drafting',
#    'url': 'https://www.boardgameatlas.com/mechanic/5VI7UEXztV/closed-drafting'},
#   {'id': 'IcofZxFwqw',
#    'name': 'Command Cards',
#    'url': 'https://www.boardgameatlas.com/mechanic/IcofZxFwqw/command-cards'},
#   {'id': 'i8pEFk75OI',
#    'name': 'Commodity Speculation',
#    'url': 'https://www.boardgameatlas.com/mechanic/i8pEFk75OI/commodity-speculation'},
#   {'id': '0ez69aUfuJ',
#    'name': 'Communication Limits',
#    'url': 'https://www.boardgameatlas.com/mechanic/0ez69aUfuJ/communication-limits'},
#   {'id': 'Khp7U5pHZi',
#    'name': 'Competitive Play',
#    'url': 'https://www.boardgameatlas.com/mechanic/Khp7U5pHZi/competitive-play'},
#   {'id': 'pEHn0BKFZ8',
#    'name': 'Connections',
#    'url': 'https://www.boardgameatlas.com/mechanic/pEHn0BKFZ8/connections'},
#   {'id': 'jOAB6RhwBp',
#    'name': 'Contracts',
#    'url': 'https://www.boardgameatlas.com/mechanic/jOAB6RhwBp/contracts'},
#   {'id': '9mNukNBxfZ',
#    'name': 'Cooperative Play',
#    'url': 'https://www.boardgameatlas.com/mechanic/9mNukNBxfZ/cooperative-play'},
#   {'id': 'xVDf5dmJts',
#    'name': 'Crayon Rail System',
#    'url': 'https://www.boardgameatlas.com/mechanic/xVDf5dmJts/crayon-rail-system'},
#   {'id': '4ERmAGYVPL',
#    'name': 'Critical Hits and Failures',
#    'url': 'https://www.boardgameatlas.com/mechanic/4ERmAGYVPL/critical-hits-and-failures'},
#   {'id': 'J6TWltoYOF',
#    'name': 'Cube tower',
#    'url': 'https://www.boardgameatlas.com/mechanic/J6TWltoYOF/cube-tower'},
#   {'id': 'vZsDDAdOoe',
#    'name': 'Deck Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/vZsDDAdOoe/deck-building'},
#   {'id': 'VQQsdFilIf',
#    'name': 'Deck Constructing',
#    'url': 'https://www.boardgameatlas.com/mechanic/VQQsdFilIf/deck-constructing'},
#   {'id': 'M15c5LuzLT',
#    'name': 'Deck Un-building',
#    'url': 'https://www.boardgameatlas.com/mechanic/M15c5LuzLT/deck-un-building'},
#   {'id': 'GsNGxZFNCK',
#    'name': 'Deduction',
#    'url': 'https://www.boardgameatlas.com/mechanic/GsNGxZFNCK/deduction'},
#   {'id': '3BiR0iAjoo',
#    'name': 'Delayed Purchase',
#    'url': 'https://www.boardgameatlas.com/mechanic/3BiR0iAjoo/delayed-purchase'},
#   {'id': '5kvyChnWuO',
#    'name': 'Dexterity',
#    'url': 'https://www.boardgameatlas.com/mechanic/5kvyChnWuO/dexterity'},
#   {'id': 'edpczEaWCX',
#    'name': 'Dice Allocation',
#    'url': 'https://www.boardgameatlas.com/mechanic/edpczEaWCX/dice-allocation'},
#   {'id': 'lVSHu9efHv',
#    'name': 'Dice Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/lVSHu9efHv/dice-building'},
#   {'id': 'CGtkhRuesC',
#    'name': 'Dice Drafting',
#    'url': 'https://www.boardgameatlas.com/mechanic/CGtkhRuesC/dice-drafting'},
#   {'id': 'zw4KMn5rcD',
#    'name': 'Dice Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/zw4KMn5rcD/dice-movement'},
#   {'id': 'R0bGq4cAl4',
#    'name': 'Dice Rolling',
#    'url': 'https://www.boardgameatlas.com/mechanic/R0bGq4cAl4/dice-rolling'},
#   {'id': 'giTLx2kROa',
#    'name': 'Dice Tower Combat',
#    'url': 'https://www.boardgameatlas.com/mechanic/giTLx2kROa/dice-tower-combat'},
#   {'id': 'k44nxjXeXC',
#    'name': 'Die Icon Resolution',
#    'url': 'https://www.boardgameatlas.com/mechanic/k44nxjXeXC/die-icon-resolution'},
#   {'id': 'wV5peB05xs',
#    'name': 'Drafting',
#    'url': 'https://www.boardgameatlas.com/mechanic/wV5peB05xs/drafting'},
#   {'id': 'KfTS5BwIsu',
#    'name': 'Drawing',
#    'url': 'https://www.boardgameatlas.com/mechanic/KfTS5BwIsu/drawing'},
#   {'id': '6YMpwOGWmX',
#    'name': 'Drawing Pictures',
#    'url': 'https://www.boardgameatlas.com/mechanic/6YMpwOGWmX/drawing-pictures'},
#   {'id': 'PVJ8E0kXUE',
#    'name': 'Dynamic Currency',
#    'url': 'https://www.boardgameatlas.com/mechanic/PVJ8E0kXUE/dynamic-currency'},
#   {'id': 'fOkuHxnNFL',
#    'name': 'Elapsed Real Time Ending',
#    'url': 'https://www.boardgameatlas.com/mechanic/fOkuHxnNFL/elapsed-real-time-ending'},
#   {'id': 'YlqCkWPY0r',
#    'name': 'Enclosure',
#    'url': 'https://www.boardgameatlas.com/mechanic/YlqCkWPY0r/enclosure'},
#   {'id': '9ZlbQA8L5l',
#    'name': 'End Game Bonuses',
#    'url': 'https://www.boardgameatlas.com/mechanic/9ZlbQA8L5l/end-game-bonuses'},
#   {'id': 'yu3eas6v7A',
#    'name': 'Engine Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/yu3eas6v7A/engine-building'},
#   {'id': 'KFeIfeoFaK',
#    'name': 'Events',
#    'url': 'https://www.boardgameatlas.com/mechanic/KFeIfeoFaK/events'},
#   {'id': 'eTe5HBrJcK',
#    'name': 'Evolving Game Board',
#    'url': 'https://www.boardgameatlas.com/mechanic/eTe5HBrJcK/evolving-game-board'},
#   {'id': '5vzHcNSWye',
#    'name': 'Feeding Workers/Characters',
#    'url': 'https://www.boardgameatlas.com/mechanic/5vzHcNSWye/feeding-workers-characters'},
#   {'id': 'rUsVFpir1t',
#    'name': 'Finale Ending',
#    'url': 'https://www.boardgameatlas.com/mechanic/rUsVFpir1t/finale-ending'},
#   {'id': 'S0O9ucexPS',
#    'name': 'Flicking',
#    'url': 'https://www.boardgameatlas.com/mechanic/S0O9ucexPS/flicking'},
#   {'id': 'G9MDotCkNd',
#    'name': 'Flip and Write',
#    'url': 'https://www.boardgameatlas.com/mechanic/G9MDotCkNd/flip-and-write'},
#   {'id': '9NHXcmC2Zy',
#    'name': 'Follow',
#    'url': 'https://www.boardgameatlas.com/mechanic/9NHXcmC2Zy/follow'},
#   {'id': 'uztV12nNjt',
#    'name': 'Force Commitment',
#    'url': 'https://www.boardgameatlas.com/mechanic/uztV12nNjt/force-commitment'},
#   {'id': 'l5mXIMcD6N',
#    'name': 'Grid Coverage',
#    'url': 'https://www.boardgameatlas.com/mechanic/l5mXIMcD6N/grid-coverage'},
#   {'id': 'qu5BcGjAzk',
#    'name': 'Grid Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/qu5BcGjAzk/grid-movement'},
#   {'id': 'WPytek5P8l',
#    'name': 'Hand Management',
#    'url': 'https://www.boardgameatlas.com/mechanic/WPytek5P8l/hand-management'},
#   {'id': 'i3xnwJ7VPV',
#    'name': 'Hand-Eye Coordination',
#    'url': 'https://www.boardgameatlas.com/mechanic/i3xnwJ7VPV/handeye-coordination'},
#   {'id': '6CyVyXRn1C',
#    'name': 'Hex and Counter',
#    'url': 'https://www.boardgameatlas.com/mechanic/6CyVyXRn1C/hex-and-counter'},
#   {'id': 'BeD8NYAaSU',
#    'name': 'Hexagon Grid',
#    'url': 'https://www.boardgameatlas.com/mechanic/BeD8NYAaSU/hexagon-grid'},
#   {'id': 'aQZ40lKv8O',
#    'name': 'Hidden Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/aQZ40lKv8O/hidden-movement'},
#   {'id': 'dITGE93SCS',
#    'name': 'Hidden Objective',
#    'url': 'https://www.boardgameatlas.com/mechanic/dITGE93SCS/hidden-objective'},
#   {'id': 'U7vKyeRc0N',
#    'name': 'Hidden Roles',
#    'url': 'https://www.boardgameatlas.com/mechanic/U7vKyeRc0N/hidden-roles'},
#   {'id': 'Voqy2dgrIM',
#    'name': 'Hidden Traitor',
#    'url': 'https://www.boardgameatlas.com/mechanic/Voqy2dgrIM/hidden-traitor'},
#   {'id': 'MPiKlI6itI',
#    'name': 'Hidden Victory Points',
#    'url': 'https://www.boardgameatlas.com/mechanic/MPiKlI6itI/hidden-victory-points'},
#   {'id': 'CIvmpy01Iu',
#    'name': 'Highest-Lowest Scoring',
#    'url': 'https://www.boardgameatlas.com/mechanic/CIvmpy01Iu/highest-lowest-scoring'},
#   {'id': 'uEUdAVKex3',
#    'name': 'I Split, You Take',
#    'url': 'https://www.boardgameatlas.com/mechanic/uEUdAVKex3/i-split-you-take'},
#   {'id': 'uRfUbdbX9b',
#    'name': 'Impeded Speech',
#    'url': 'https://www.boardgameatlas.com/mechanic/uRfUbdbX9b/impeded-speech'},
#   {'id': '6RZAs0CCpF',
#    'name': 'Income',
#    'url': 'https://www.boardgameatlas.com/mechanic/6RZAs0CCpF/income'},
#   {'id': 'hXoDlzyWxx',
#    'name': 'Increased Value of Unchosen Resources',
#    'url': 'https://www.boardgameatlas.com/mechanic/hXoDlzyWxx/increased-value-of-unchosen-resources'},
#   {'id': 'DulpwAyknt',
#    'name': 'Interrupts',
#    'url': 'https://www.boardgameatlas.com/mechanic/DulpwAyknt/interrupts'},
#   {'id': 'Kc9VeRBF4i',
#    'name': 'Investment',
#    'url': 'https://www.boardgameatlas.com/mechanic/Kc9VeRBF4i/investment'},
#   {'id': 'iD9HiRqlaF',
#    'name': 'King of The Hill',
#    'url': 'https://www.boardgameatlas.com/mechanic/iD9HiRqlaF/king-of-the-hill'},
#   {'id': 'OpevqFAODe',
#    'name': 'Ladder Climbing',
#    'url': 'https://www.boardgameatlas.com/mechanic/OpevqFAODe/ladder-climbing'},
#   {'id': 'i4XLPK9XNM',
#    'name': 'Layering',
#    'url': 'https://www.boardgameatlas.com/mechanic/i4XLPK9XNM/layering'},
#   {'id': 'DwmsVEvNVd',
#    'name': 'Legacy',
#    'url': 'https://www.boardgameatlas.com/mechanic/DwmsVEvNVd/legacy'},
#   {'id': 'MaXzmoZUoX',
#    'name': 'Line Drawing',
#    'url': 'https://www.boardgameatlas.com/mechanic/MaXzmoZUoX/line-drawing'},
#   {'id': 'KixWJ4QQPE',
#    'name': 'Line of Sight',
#    'url': 'https://www.boardgameatlas.com/mechanic/KixWJ4QQPE/line-of-sight'},
#   {'id': 'LqtFDVjGEm',
#    'name': 'Loans',
#    'url': 'https://www.boardgameatlas.com/mechanic/LqtFDVjGEm/loans'},
#   {'id': 'XI7soCqc6x',
#    'name': 'Lose a Turn',
#    'url': 'https://www.boardgameatlas.com/mechanic/XI7soCqc6x/lose-a-turn'},
#   {'id': 'ar56ACXDNe',
#    'name': 'Mancala',
#    'url': 'https://www.boardgameatlas.com/mechanic/ar56ACXDNe/mancala'},
#   {'id': 'ZXn5ynKjNz',
#    'name': 'Map Addition',
#    'url': 'https://www.boardgameatlas.com/mechanic/ZXn5ynKjNz/map-addition'},
#   {'id': 'drYVt5pekY',
#    'name': 'Map Deformation',
#    'url': 'https://www.boardgameatlas.com/mechanic/drYVt5pekY/map-deformation'},
#   {'id': 'jvNWYGPDkQ',
#    'name': 'Map Reduction',
#    'url': 'https://www.boardgameatlas.com/mechanic/jvNWYGPDkQ/map-reduction'},
#   {'id': 'wPcKOr57ig',
#    'name': 'Market',
#    'url': 'https://www.boardgameatlas.com/mechanic/wPcKOr57ig/market'},
#   {'id': 'QtH2H2MXp6',
#    'name': 'Matching',
#    'url': 'https://www.boardgameatlas.com/mechanic/QtH2H2MXp6/matching'},
#   {'id': 'HBT0U46aiz',
#    'name': 'Measurement Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/HBT0U46aiz/measurement-movement'},
#   {'id': 'iK0HWpaNHg',
#    'name': 'Melding and Splaying',
#    'url': 'https://www.boardgameatlas.com/mechanic/iK0HWpaNHg/melding-and-splaying'},
#   {'id': 'r6yIFvyXDD',
#    'name': 'Memory',
#    'url': 'https://www.boardgameatlas.com/mechanic/r6yIFvyXDD/memory'},
#   {'id': 'U3zhCQH7Et',
#    'name': 'Modular Board',
#    'url': 'https://www.boardgameatlas.com/mechanic/U3zhCQH7Et/modular-board'},
#   {'id': 'yBC28ZgwFM',
#    'name': 'Move Through Deck',
#    'url': 'https://www.boardgameatlas.com/mechanic/yBC28ZgwFM/move-through-deck'},
#   {'id': 'V2rMEmnTCs',
#    'name': 'Move with Cards',
#    'url': 'https://www.boardgameatlas.com/mechanic/V2rMEmnTCs/move-with-cards'},
#   {'id': '3fLVBQG50Z',
#    'name': 'Movement Points',
#    'url': 'https://www.boardgameatlas.com/mechanic/3fLVBQG50Z/movement-points'},
#   {'id': 'Z9qTQxuyjC',
#    'name': 'Movement Template',
#    'url': 'https://www.boardgameatlas.com/mechanic/Z9qTQxuyjC/movement-template'},
#   {'id': 'si2GktB6YI',
#    'name': 'Moving Multiple Units',
#    'url': 'https://www.boardgameatlas.com/mechanic/si2GktB6YI/moving-multiple-units'},
#   {'id': 'rtLNCHIDxl',
#    'name': 'Multiple Maps',
#    'url': 'https://www.boardgameatlas.com/mechanic/rtLNCHIDxl/multiple-maps'},
#   {'id': 'NS4kKxKZHZ',
#    'name': 'Multiple-Lot Auction',
#    'url': 'https://www.boardgameatlas.com/mechanic/NS4kKxKZHZ/multiple-lot-auction'},
#   {'id': 'gcltnDjSRQ',
#    'name': 'Narrative Choice',
#    'url': 'https://www.boardgameatlas.com/mechanic/gcltnDjSRQ/narrative-choice'},
#   {'id': 'jMwUJLemr6',
#    'name': 'Negotiation',
#    'url': 'https://www.boardgameatlas.com/mechanic/jMwUJLemr6/negotiation'},
#   {'id': 'ohABM4GjbC',
#    'name': 'Network and Route Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/network-and-route-building'},
#   {'id': 'qxXud0DODh',
#    'name': 'Once per game ability',
#    'url': 'https://www.boardgameatlas.com/mechanic/qxXud0DODh/once-per-game-ability'},
#   {'id': 'fUnFqLGvxW',
#    'name': 'Open Drafting',
#    'url': 'https://www.boardgameatlas.com/mechanic/fUnFqLGvxW/open-drafting'},
#   {'id': '5UcCsstfvR',
#    'name': 'Order Counters',
#    'url': 'https://www.boardgameatlas.com/mechanic/5UcCsstfvR/order-counters'},
#   {'id': 'Pn9PAvCVrW',
#    'name': 'Order Fulfillment',
#    'url': 'https://www.boardgameatlas.com/mechanic/Pn9PAvCVrW/order-fulfillment'},
#   {'id': 'yQ4ZptdyD1',
#    'name': 'Ownership',
#    'url': 'https://www.boardgameatlas.com/mechanic/yQ4ZptdyD1/ownership'},
#   {'id': 'UHdPUeuqyZ',
#    'name': 'Paper and Pencil',
#    'url': 'https://www.boardgameatlas.com/mechanic/UHdPUeuqyZ/paper-and-pencil'},
#   {'id': 'GNtouC8NLm',
#    'name': 'Partnerships',
#    'url': 'https://www.boardgameatlas.com/mechanic/GNtouC8NLm/partnerships'},
#   {'id': '9YdRn9J9oZ',
#    'name': 'Pattern Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/9YdRn9J9oZ/pattern-building'},
#   {'id': 'VTBonQ4yuA',
#    'name': 'Pattern Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/VTBonQ4yuA/pattern-movement'},
#   {'id': 'uZJS07nXF5',
#    'name': 'Pattern Recognition',
#    'url': 'https://www.boardgameatlas.com/mechanic/uZJS07nXF5/pattern-recognition'},
#   {'id': 'J4MpJHpMIL',
#    'name': 'Physical Removal',
#    'url': 'https://www.boardgameatlas.com/mechanic/J4MpJHpMIL/physical-removal'},
#   {'id': 'BbTMRkwL0b',
#    'name': 'Pick-up and Deliver',
#    'url': 'https://www.boardgameatlas.com/mechanic/BbTMRkwL0b/pickup-and-deliver'},
#   {'id': 'rgPb6FsESH',
#    'name': 'Pieces as Map',
#    'url': 'https://www.boardgameatlas.com/mechanic/rgPb6FsESH/pieces-as-map'},
#   {'id': 'BGrhzIN69D',
#    'name': 'Player Elimination',
#    'url': 'https://www.boardgameatlas.com/mechanic/BGrhzIN69D/player-elimination'},
#   {'id': 'hChENqTxXH',
#    'name': 'Player Judge',
#    'url': 'https://www.boardgameatlas.com/mechanic/hChENqTxXH/player-judge'},
#   {'id': 'MEAoOygZsA',
#    'name': 'Point to Point Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/MEAoOygZsA/point-to-point-movement'},
#   {'id': 'ea1eaPBQn8',
#    'name': 'Pool Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/ea1eaPBQn8/pool-building'},
#   {'id': 'hmipYN1R1I',
#    'name': 'Press Your Luck',
#    'url': 'https://www.boardgameatlas.com/mechanic/hmipYN1R1I/press-your-luck'},
#   {'id': 'TKcedESdWT',
#    'name': "Prisoner's Dilemma",
#    'url': 'https://www.boardgameatlas.com/mechanic/TKcedESdWT/prisoner-s-dilemma'},
#   {'id': 'lbuV691zBC',
#    'name': 'Programmed Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/lbuV691zBC/programmed-movement'},
#   {'id': 'qZx4PEzKKz',
#    'name': 'Race',
#    'url': 'https://www.boardgameatlas.com/mechanic/qZx4PEzKKz/race'},
#   {'id': 'rpPPpJPbeZ',
#    'name': 'Random Production',
#    'url': 'https://www.boardgameatlas.com/mechanic/rpPPpJPbeZ/random-production'},
#   {'id': 'v9L0Bf86od',
#    'name': 'Ratio / Combat Results Table',
#    'url': 'https://www.boardgameatlas.com/mechanic/v9L0Bf86od/ratio--combat-results-table'},
#   {'id': 'Zppn45KSY4',
#    'name': 'Re-rolling and Locking',
#    'url': 'https://www.boardgameatlas.com/mechanic/Zppn45KSY4/re-rolling-and-locking'},
#   {'id': 'E9VKQ8uMSP',
#    'name': 'Real Time',
#    'url': 'https://www.boardgameatlas.com/mechanic/E9VKQ8uMSP/real-time'},
#   {'id': 'OihbT9eA8c',
#    'name': 'Relative Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/OihbT9eA8c/relative-movement'},
#   {'id': 'Rt6V388y6M',
#    'name': 'Resource Gathering',
#    'url': 'https://www.boardgameatlas.com/mechanic/Rt6V388y6M/resource-gathering'},
#   {'id': 'i1C9sRK8TS',
#    'name': 'Resource to Move',
#    'url': 'https://www.boardgameatlas.com/mechanic/i1C9sRK8TS/resource-to-move'},
#   {'id': 'j7x8jY4ay2',
#    'name': 'Rock-Paper-Scissors',
#    'url': 'https://www.boardgameatlas.com/mechanic/j7x8jY4ay2/rockpaperscissors'},
#   {'id': 'EVeAdboGUA',
#    'name': 'Role Playing',
#    'url': 'https://www.boardgameatlas.com/mechanic/EVeAdboGUA/role-playing'},
#   {'id': 'gRlslORtpI',
#    'name': 'Role Selection',
#    'url': 'https://www.boardgameatlas.com/mechanic/gRlslORtpI/role-selection'},
#   {'id': 'SwmT0qEFSc',
#    'name': 'Roles with Asymmetric Information',
#    'url': 'https://www.boardgameatlas.com/mechanic/SwmT0qEFSc/roles-with-asymmetric-information'},
#   {'id': 'mGBzR68m8Z',
#    'name': 'Roll / Spin and Move',
#    'url': 'https://www.boardgameatlas.com/mechanic/mGBzR68m8Z/roll--spin-and-move'},
#   {'id': 'zIPRS41oiN',
#    'name': 'Roll and Write',
#    'url': 'https://www.boardgameatlas.com/mechanic/zIPRS41oiN/roll-and-write'},
#   {'id': 'FA6HjbhdNW',
#    'name': 'Rondel',
#    'url': 'https://www.boardgameatlas.com/mechanic/FA6HjbhdNW/rondel'},
#   {'id': 'AO3hFg1Vwo',
#    'name': 'Scenario / Mission / Campaign Game',
#    'url': 'https://www.boardgameatlas.com/mechanic/AO3hFg1Vwo/scenario--mission--campaign-game'},
#   {'id': '7MwswcgliJ',
#    'name': 'Score and Reset Game',
#    'url': 'https://www.boardgameatlas.com/mechanic/7MwswcgliJ/score-and-reset-game'},
#   {'id': 'R3tFpadfxd',
#    'name': 'Secret Information',
#    'url': 'https://www.boardgameatlas.com/mechanic/R3tFpadfxd/secret-information'},
#   {'id': 'RwgEONzIzc',
#    'name': 'Secret Unit Deployment',
#    'url': 'https://www.boardgameatlas.com/mechanic/RwgEONzIzc/secret-unit-deployment'},
#   {'id': 'KBzOT0kC5a',
#    'name': 'Semi-Cooperative',
#    'url': 'https://www.boardgameatlas.com/mechanic/KBzOT0kC5a/semi-cooperative'},
#   {'id': 'lA3KUtVFCy',
#    'name': 'Set Collection',
#    'url': 'https://www.boardgameatlas.com/mechanic/lA3KUtVFCy/set-collection'},
#   {'id': 'Exm4wqdMPk',
#    'name': 'Shared Pieces',
#    'url': 'https://www.boardgameatlas.com/mechanic/Exm4wqdMPk/shared-pieces'},
#   {'id': 'vBsK2u85w8',
#    'name': 'Shedding',
#    'url': 'https://www.boardgameatlas.com/mechanic/vBsK2u85w8/shedding'},
#   {'id': 'eRe1jJCBFe',
#    'name': 'Simulation',
#    'url': 'https://www.boardgameatlas.com/mechanic/eRe1jJCBFe/simulation'},
#   {'id': 'DEvPj5twid',
#    'name': 'Simultaneous Play',
#    'url': 'https://www.boardgameatlas.com/mechanic/DEvPj5twid/simultaneous-play'},
#   {'id': 'za4PP1LH00',
#    'name': 'Simultaneous action selection',
#    'url': 'https://www.boardgameatlas.com/mechanic/za4PP1LH00/simultaneous-action-selection'},
#   {'id': '4RNcc2Le80',
#    'name': 'Singing',
#    'url': 'https://www.boardgameatlas.com/mechanic/4RNcc2Le80/singing'},
#   {'id': 'kuRNhFADjS',
#    'name': 'Skirmish',
#    'url': 'https://www.boardgameatlas.com/mechanic/kuRNhFADjS/skirmish'},
#   {'id': 'jA7onZMFVY',
#    'name': 'Slide / Push',
#    'url': 'https://www.boardgameatlas.com/mechanic/jA7onZMFVY/slide--push'},
#   {'id': 'x3wVCq1HEP',
#    'name': 'Social Deduction',
#    'url': 'https://www.boardgameatlas.com/mechanic/x3wVCq1HEP/social-deduction'},
#   {'id': 'uZR0NCIA6D',
#    'name': 'Solo / Solitaire Game',
#    'url': 'https://www.boardgameatlas.com/mechanic/uZR0NCIA6D/solo--solitaire-game'},
#   {'id': 'L8QFIjNObL',
#    'name': 'Solo mode (multiplayer game)',
#    'url': 'https://www.boardgameatlas.com/mechanic/L8QFIjNObL/solo-mode-multiplayer-game-'},
#   {'id': 'QWPVu14v5P',
#    'name': 'Spatial Reasoning',
#    'url': 'https://www.boardgameatlas.com/mechanic/QWPVu14v5P/spatial-reasoning'},
#   {'id': 'xzG9nBn4SV',
#    'name': 'Speed Matching',
#    'url': 'https://www.boardgameatlas.com/mechanic/xzG9nBn4SV/speed-matching'},
#   {'id': '0ZveDwHjpC',
#    'name': 'Spelling Words',
#    'url': 'https://www.boardgameatlas.com/mechanic/0ZveDwHjpC/spelling-words'},
#   {'id': 'm9IFaYKaOA',
#    'name': 'Square Grid',
#    'url': 'https://www.boardgameatlas.com/mechanic/m9IFaYKaOA/square-grid'},
#   {'id': 'QGpSz6qoPw',
#    'name': 'Stacking and Balancing',
#    'url': 'https://www.boardgameatlas.com/mechanic/QGpSz6qoPw/stacking-and-balancing'},
#   {'id': 'EJVFd5uZaH',
#    'name': 'Static Capture',
#    'url': 'https://www.boardgameatlas.com/mechanic/EJVFd5uZaH/static-capture'},
#   {'id': 'jbLrZb1xIb',
#    'name': 'Stock Holding',
#    'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/stock-holding'},
#   {'id': 'GUoWg3Mfh5',
#    'name': 'Storytelling',
#    'url': 'https://www.boardgameatlas.com/mechanic/GUoWg3Mfh5/storytelling'},
#   {'id': 'KbFMG5kwhn',
#    'name': 'Submit and Judge',
#    'url': 'https://www.boardgameatlas.com/mechanic/KbFMG5kwhn/submit-and-judge'},
#   {'id': 'xarBBVMST3',
#    'name': 'Sudden Death Ending',
#    'url': 'https://www.boardgameatlas.com/mechanic/xarBBVMST3/sudden-death-ending'},
#   {'id': 'xAoL3P3BIV',
#    'name': 'Survival',
#    'url': 'https://www.boardgameatlas.com/mechanic/xAoL3P3BIV/survival'},
#   {'id': 'u9IJEE1QBN',
#    'name': 'Tableau Building',
#    'url': 'https://www.boardgameatlas.com/mechanic/u9IJEE1QBN/tableau-building'},
#   {'id': 'T8JEFYwoqy',
#    'name': 'Take That',
#    'url': 'https://www.boardgameatlas.com/mechanic/T8JEFYwoqy/take-that'},
#   {'id': 'kNO1bm1siL',
#    'name': 'Take This',
#    'url': 'https://www.boardgameatlas.com/mechanic/kNO1bm1siL/take-this'},
#   {'id': 'Tb52O7Id9Q',
#    'name': 'Targeted Clues',
#    'url': 'https://www.boardgameatlas.com/mechanic/Tb52O7Id9Q/targeted-clues'},
#   {'id': '9jnCsVuRat',
#    'name': 'Teams',
#    'url': 'https://www.boardgameatlas.com/mechanic/9jnCsVuRat/teams'},
#   {'id': 'LzMEog842j',
#    'name': 'Tech Trees / Tech Tracks',
#    'url': 'https://www.boardgameatlas.com/mechanic/LzMEog842j/tech-trees--tech-tracks'},
#   {'id': 'HGcSWoywV0',
#    'name': 'Threat Progression',
#    'url': 'https://www.boardgameatlas.com/mechanic/HGcSWoywV0/threat-progression'},
#   {'id': 'IPy36VhU8T',
#    'name': 'Three Dimensional Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/IPy36VhU8T/three-dimensional-movement'},
#   {'id': '8PN2HE86wg',
#    'name': 'Tile Placement',
#    'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/tile-placement'},
#   {'id': 'JX9P0Lda4D',
#    'name': 'Tile movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/JX9P0Lda4D/tile-movement'},
#   {'id': 'cXd5KaXXZo',
#    'name': 'Time Track',
#    'url': 'https://www.boardgameatlas.com/mechanic/cXd5KaXXZo/time-track'},
#   {'id': 'wEBvff5T5c',
#    'name': 'Tower Defense',
#    'url': 'https://www.boardgameatlas.com/mechanic/wEBvff5T5c/tower-defense'},
#   {'id': 'gXBJh0WkGb',
#    'name': 'Track Movement',
#    'url': 'https://www.boardgameatlas.com/mechanic/gXBJh0WkGb/track-movement'},
#   {'id': 'AVY6EvSQTP',
#    'name': 'Trading',
#    'url': 'https://www.boardgameatlas.com/mechanic/AVY6EvSQTP/trading'},
#   {'id': 'tyTj0kxoRc',
#    'name': 'Traitor',
#    'url': 'https://www.boardgameatlas.com/mechanic/tyTj0kxoRc/traitor'},
#   {'id': '3GSQl800lk',
#    'name': 'Trick-taking',
#    'url': 'https://www.boardgameatlas.com/mechanic/3GSQl800lk/tricktaking'},
#   {'id': 'dq0UYF6HCv',
#    'name': 'Tug of War',
#    'url': 'https://www.boardgameatlas.com/mechanic/dq0UYF6HCv/tug-of-war'},
#   {'id': 'mckyPcVJ0c',
#    'name': 'Turn Order: Auction',
#    'url': 'https://www.boardgameatlas.com/mechanic/mckyPcVJ0c/turn-order-auction'},
#   {'id': '2hWNbfJ0wi',
#    'name': 'Turn Order: Claim Action',
#    'url': 'https://www.boardgameatlas.com/mechanic/2hWNbfJ0wi/turn-order-claim-action'},
#   {'id': 'U6W741PEHU',
#    'name': 'Turn Order: Pass Order',
#    'url': 'https://www.boardgameatlas.com/mechanic/U6W741PEHU/turn-order-pass-order'},
#   {'id': '1nmCkkoKaq',
#    'name': 'Turn Order: Progressive',
#    'url': 'https://www.boardgameatlas.com/mechanic/1nmCkkoKaq/turn-order-progressive'},
#   {'id': 'mIbXGXV7Ok',
#    'name': 'Turn Order: Random',
#    'url': 'https://www.boardgameatlas.com/mechanic/mIbXGXV7Ok/turn-order-random'},
#   {'id': 'EIsPHVVFC8',
#    'name': 'Turn Order: Roll Order',
#    'url': 'https://www.boardgameatlas.com/mechanic/EIsPHVVFC8/turn-order-roll-order'},
#   {'id': 'ghLZBAbqCB',
#    'name': 'Turn Order: Stat-Based',
#    'url': 'https://www.boardgameatlas.com/mechanic/ghLZBAbqCB/turn-order-stat-based'},
#   {'id': 'zzsE4jtI1b',
#    'name': 'Variable Phase Order',
#    'url': 'https://www.boardgameatlas.com/mechanic/zzsE4jtI1b/variable-phase-order'},
#   {'id': 'XM2FYZmBHH',
#    'name': 'Variable Player Powers',
#    'url': 'https://www.boardgameatlas.com/mechanic/XM2FYZmBHH/variable-player-powers'},
#   {'id': 'qdOpNsR6iU',
#    'name': 'Variable Setup',
#    'url': 'https://www.boardgameatlas.com/mechanic/qdOpNsR6iU/variable-setup'},
#   {'id': 'Rvs7NYbvo1',
#    'name': 'Victory Points as a Resource',
#    'url': 'https://www.boardgameatlas.com/mechanic/Rvs7NYbvo1/victory-points-as-a-resource'},
#   {'id': 'JYYdBW6UCE',
#    'name': 'Voting',
#    'url': 'https://www.boardgameatlas.com/mechanic/JYYdBW6UCE/voting'},
#   {'id': 'bbbmSiDpdR',
#    'name': 'Word Association',
#    'url': 'https://www.boardgameatlas.com/mechanic/bbbmSiDpdR/word-association'},
#   {'id': 'fBOTEBUAmV',
#    'name': 'Worker Placement',
#    'url': 'https://www.boardgameatlas.com/mechanic/fBOTEBUAmV/worker-placement'},
#   {'id': 'B30dz3Ljjx',
#    'name': 'Worker Placement with Dice Workers',
#    'url': 'https://www.boardgameatlas.com/mechanic/B30dz3Ljjx/worker-placement-with-dice-workers'},
#   {'id': 'PfgjF704uD',
#    'name': 'Worker Placement, Different Worker Types',
#    'url': 'https://www.boardgameatlas.com/mechanic/PfgjF704uD/worker-placement-different-worker-types'},
#   {'id': 'M7pWAuRX2d',
#    'name': 'Zone of Control',
#    'url': 'https://www.boardgameatlas.com/mechanic/M7pWAuRX2d/zone-of-control'}]}

# %%
data.keys()
# Out:
# dict_keys(['mechanics'])

# %%
mech= data['mechanics']

# %%
mech[0]
# Out:
# {'id': 'SWJGuaim9h',
#  'name': 'AI enemies',
#  'url': 'https://www.boardgameatlas.com/mechanic/SWJGuaim9h/ai-enemies'}

# %%
new_mech={}
for d in mech:
    new_mech[d['id']]=d['name']

# %%
new_mech
# Out:
# {'SWJGuaim9h': 'AI enemies',
#  'n1GtBt35Rd': 'Acting',
#  'TEmgapaEg0': 'Action / Event',
#  'PGjmKGi26h': 'Action / Movement Programming',
#  'UAV3t3FxVI': 'Action Drafting',
#  'oeg6wN9Eoc': 'Action Point Allowance System',
#  'ckCp1oTVMy': 'Action Queue',
#  'EluAnyIJKY': 'Action Retrieval',
#  'Bc7R8pLoGk': 'Action Selection',
#  'j2A0uFmdgc': 'Action Timer',
#  'LfQ9fgn7Zu': 'Action economy',
#  '9l8kOZQEEa': 'Added Mechanics',
#  'klT5dZnO4G': 'Advantage Token',
#  'Hef8hzPH7C': 'Alliances',
#  'TlGfAobFpp': 'App Driven',
#  '05zCZoLvQJ': 'Area Control',
#  '3te2oybNR4': 'Area Enclosure',
#  '9NBcz45nN7': 'Area Majority/ Influence',
#  'bgGxE0pI2B': 'Area Movement',
#  'zlsyLiomoR': 'Area development',
#  'AZxlPpi5oq': 'Auction',
#  '7gpfubluzg': 'Auction: Dutch',
#  '6Lo2vLiex6': 'Auction: Sealed Bid',
#  'IAuH3ICIyC': 'Automatic Resource Growth',
#  '1382oBW7iB': 'Bag Building',
#  '3tuJiW3pps': 'Betting',
#  'tKZiGvSxAC': 'Bias',
#  'issXRWXSLg': 'Bidding',
#  '71HG4TJaoD': 'Bingo',
#  'ZX3hYcF9H7': 'Bluffing',
#  'QFxeEMMQAM': 'Bribery',
#  'xuphiSlrxI': 'Campaign',
#  'ml9upz5Me9': 'Campaign / Battle Card Driven',
#  'NN3nIS4Anc': 'Card Crafting',
#  'iWODHwRGuU': 'Card Drafting',
#  'ngCSHHk0H2': 'Card Placement',
#  's0OA3pn2fn': 'Card Play Conflict Resolution',
#  '6YTZ0juKWy': 'Catch the Leader',
#  'PzEJDypMgC': 'Chaining',
#  'Oz9Z9e0GO5': 'Character Progression',
#  'Gan96fffLL': 'Chit-Pull System',
#  '5VI7UEXztV': 'Closed Drafting',
#  'IcofZxFwqw': 'Command Cards',
#  'i8pEFk75OI': 'Commodity Speculation',
#  '0ez69aUfuJ': 'Communication Limits',
#  'Khp7U5pHZi': 'Competitive Play',
#  'pEHn0BKFZ8': 'Connections',
#  'jOAB6RhwBp': 'Contracts',
#  '9mNukNBxfZ': 'Cooperative Play',
#  'xVDf5dmJts': 'Crayon Rail System',
#  '4ERmAGYVPL': 'Critical Hits and Failures',
#  'J6TWltoYOF': 'Cube tower',
#  'vZsDDAdOoe': 'Deck Building',
#  'VQQsdFilIf': 'Deck Constructing',
#  'M15c5LuzLT': 'Deck Un-building',
#  'GsNGxZFNCK': 'Deduction',
#  '3BiR0iAjoo': 'Delayed Purchase',
#  '5kvyChnWuO': 'Dexterity',
#  'edpczEaWCX': 'Dice Allocation',
#  'lVSHu9efHv': 'Dice Building',
#  'CGtkhRuesC': 'Dice Drafting',
#  'zw4KMn5rcD': 'Dice Movement',
#  'R0bGq4cAl4': 'Dice Rolling',
#  'giTLx2kROa': 'Dice Tower Combat',
#  'k44nxjXeXC': 'Die Icon Resolution',
#  'wV5peB05xs': 'Drafting',
#  'KfTS5BwIsu': 'Drawing',
#  '6YMpwOGWmX': 'Drawing Pictures',
#  'PVJ8E0kXUE': 'Dynamic Currency',
#  'fOkuHxnNFL': 'Elapsed Real Time Ending',
#  'YlqCkWPY0r': 'Enclosure',
#  '9ZlbQA8L5l': 'End Game Bonuses',
#  'yu3eas6v7A': 'Engine Building',
#  'KFeIfeoFaK': 'Events',
#  'eTe5HBrJcK': 'Evolving Game Board',
#  '5vzHcNSWye': 'Feeding Workers/Characters',
#  'rUsVFpir1t': 'Finale Ending',
#  'S0O9ucexPS': 'Flicking',
#  'G9MDotCkNd': 'Flip and Write',
#  '9NHXcmC2Zy': 'Follow',
#  'uztV12nNjt': 'Force Commitment',
#  'l5mXIMcD6N': 'Grid Coverage',
#  'qu5BcGjAzk': 'Grid Movement',
#  'WPytek5P8l': 'Hand Management',
#  'i3xnwJ7VPV': 'Hand-Eye Coordination',
#  '6CyVyXRn1C': 'Hex and Counter',
#  'BeD8NYAaSU': 'Hexagon Grid',
#  'aQZ40lKv8O': 'Hidden Movement',
#  'dITGE93SCS': 'Hidden Objective',
#  'U7vKyeRc0N': 'Hidden Roles',
#  'Voqy2dgrIM': 'Hidden Traitor',
#  'MPiKlI6itI': 'Hidden Victory Points',
#  'CIvmpy01Iu': 'Highest-Lowest Scoring',
#  'uEUdAVKex3': 'I Split, You Take',
#  'uRfUbdbX9b': 'Impeded Speech',
#  '6RZAs0CCpF': 'Income',
#  'hXoDlzyWxx': 'Increased Value of Unchosen Resources',
#  'DulpwAyknt': 'Interrupts',
#  'Kc9VeRBF4i': 'Investment',
#  'iD9HiRqlaF': 'King of The Hill',
#  'OpevqFAODe': 'Ladder Climbing',
#  'i4XLPK9XNM': 'Layering',
#  'DwmsVEvNVd': 'Legacy',
#  'MaXzmoZUoX': 'Line Drawing',
#  'KixWJ4QQPE': 'Line of Sight',
#  'LqtFDVjGEm': 'Loans',
#  'XI7soCqc6x': 'Lose a Turn',
#  'ar56ACXDNe': 'Mancala',
#  'ZXn5ynKjNz': 'Map Addition',
#  'drYVt5pekY': 'Map Deformation',
#  'jvNWYGPDkQ': 'Map Reduction',
#  'wPcKOr57ig': 'Market',
#  'QtH2H2MXp6': 'Matching',
#  'HBT0U46aiz': 'Measurement Movement',
#  'iK0HWpaNHg': 'Melding and Splaying',
#  'r6yIFvyXDD': 'Memory',
#  'U3zhCQH7Et': 'Modular Board',
#  'yBC28ZgwFM': 'Move Through Deck',
#  'V2rMEmnTCs': 'Move with Cards',
#  '3fLVBQG50Z': 'Movement Points',
#  'Z9qTQxuyjC': 'Movement Template',
#  'si2GktB6YI': 'Moving Multiple Units',
#  'rtLNCHIDxl': 'Multiple Maps',
#  'NS4kKxKZHZ': 'Multiple-Lot Auction',
#  'gcltnDjSRQ': 'Narrative Choice',
#  'jMwUJLemr6': 'Negotiation',
#  'ohABM4GjbC': 'Network and Route Building',
#  'qxXud0DODh': 'Once per game ability',
#  'fUnFqLGvxW': 'Open Drafting',
#  '5UcCsstfvR': 'Order Counters',
#  'Pn9PAvCVrW': 'Order Fulfillment',
#  'yQ4ZptdyD1': 'Ownership',
#  'UHdPUeuqyZ': 'Paper and Pencil',
#  'GNtouC8NLm': 'Partnerships',
#  '9YdRn9J9oZ': 'Pattern Building',
#  'VTBonQ4yuA': 'Pattern Movement',
#  'uZJS07nXF5': 'Pattern Recognition',
#  'J4MpJHpMIL': 'Physical Removal',
#  'BbTMRkwL0b': 'Pick-up and Deliver',
#  'rgPb6FsESH': 'Pieces as Map',
#  'BGrhzIN69D': 'Player Elimination',
#  'hChENqTxXH': 'Player Judge',
#  'MEAoOygZsA': 'Point to Point Movement',
#  'ea1eaPBQn8': 'Pool Building',
#  'hmipYN1R1I': 'Press Your Luck',
#  'TKcedESdWT': "Prisoner's Dilemma",
#  'lbuV691zBC': 'Programmed Movement',
#  'qZx4PEzKKz': 'Race',
#  'rpPPpJPbeZ': 'Random Production',
#  'v9L0Bf86od': 'Ratio / Combat Results Table',
#  'Zppn45KSY4': 'Re-rolling and Locking',
#  'E9VKQ8uMSP': 'Real Time',
#  'OihbT9eA8c': 'Relative Movement',
#  'Rt6V388y6M': 'Resource Gathering',
#  'i1C9sRK8TS': 'Resource to Move',
#  'j7x8jY4ay2': 'Rock-Paper-Scissors',
#  'EVeAdboGUA': 'Role Playing',
#  'gRlslORtpI': 'Role Selection',
#  'SwmT0qEFSc': 'Roles with Asymmetric Information',
#  'mGBzR68m8Z': 'Roll / Spin and Move',
#  'zIPRS41oiN': 'Roll and Write',
#  'FA6HjbhdNW': 'Rondel',
#  'AO3hFg1Vwo': 'Scenario / Mission / Campaign Game',
#  '7MwswcgliJ': 'Score and Reset Game',
#  'R3tFpadfxd': 'Secret Information',
#  'RwgEONzIzc': 'Secret Unit Deployment',
#  'KBzOT0kC5a': 'Semi-Cooperative',
#  'lA3KUtVFCy': 'Set Collection',
#  'Exm4wqdMPk': 'Shared Pieces',
#  'vBsK2u85w8': 'Shedding',
#  'eRe1jJCBFe': 'Simulation',
#  'DEvPj5twid': 'Simultaneous Play',
#  'za4PP1LH00': 'Simultaneous action selection',
#  '4RNcc2Le80': 'Singing',
#  'kuRNhFADjS': 'Skirmish',
#  'jA7onZMFVY': 'Slide / Push',
#  'x3wVCq1HEP': 'Social Deduction',
#  'uZR0NCIA6D': 'Solo / Solitaire Game',
#  'L8QFIjNObL': 'Solo mode (multiplayer game)',
#  'QWPVu14v5P': 'Spatial Reasoning',
#  'xzG9nBn4SV': 'Speed Matching',
#  '0ZveDwHjpC': 'Spelling Words',
#  'm9IFaYKaOA': 'Square Grid',
#  'QGpSz6qoPw': 'Stacking and Balancing',
#  'EJVFd5uZaH': 'Static Capture',
#  'jbLrZb1xIb': 'Stock Holding',
#  'GUoWg3Mfh5': 'Storytelling',
#  'KbFMG5kwhn': 'Submit and Judge',
#  'xarBBVMST3': 'Sudden Death Ending',
#  'xAoL3P3BIV': 'Survival',
#  'u9IJEE1QBN': 'Tableau Building',
#  'T8JEFYwoqy': 'Take That',
#  'kNO1bm1siL': 'Take This',
#  'Tb52O7Id9Q': 'Targeted Clues',
#  '9jnCsVuRat': 'Teams',
#  'LzMEog842j': 'Tech Trees / Tech Tracks',
#  'HGcSWoywV0': 'Threat Progression',
#  'IPy36VhU8T': 'Three Dimensional Movement',
#  '8PN2HE86wg': 'Tile Placement',
#  'JX9P0Lda4D': 'Tile movement',
#  'cXd5KaXXZo': 'Time Track',
#  'wEBvff5T5c': 'Tower Defense',
#  'gXBJh0WkGb': 'Track Movement',
#  'AVY6EvSQTP': 'Trading',
#  'tyTj0kxoRc': 'Traitor',
#  '3GSQl800lk': 'Trick-taking',
#  'dq0UYF6HCv': 'Tug of War',
#  'mckyPcVJ0c': 'Turn Order: Auction',
#  '2hWNbfJ0wi': 'Turn Order: Claim Action',
#  'U6W741PEHU': 'Turn Order: Pass Order',
#  '1nmCkkoKaq': 'Turn Order: Progressive',
#  'mIbXGXV7Ok': 'Turn Order: Random',
#  'EIsPHVVFC8': 'Turn Order: Roll Order',
#  'ghLZBAbqCB': 'Turn Order: Stat-Based',
#  'zzsE4jtI1b': 'Variable Phase Order',
#  'XM2FYZmBHH': 'Variable Player Powers',
#  'qdOpNsR6iU': 'Variable Setup',
#  'Rvs7NYbvo1': 'Victory Points as a Resource',
#  'JYYdBW6UCE': 'Voting',
#  'bbbmSiDpdR': 'Word Association',
#  'fBOTEBUAmV': 'Worker Placement',
#  'B30dz3Ljjx': 'Worker Placement with Dice Workers',
#  'PfgjF704uD': 'Worker Placement, Different Worker Types',
#  'M7pWAuRX2d': 'Zone of Control'}

# %%
def get_games(num=100, pages=1):
    limit=num
    for n in range(pages+1):
        pages=n*num
        url=f'https://api.boardgameatlas.com/api/search?limit={limit}&skip={pages}&pretty=true&client_id={env.key}'
        response = requests.get(url)
        data=response.json()
    games=pd.DataFrame(data['games'])
    return games

# %%
def get_games(num=100, pages=1):
    limit=num
    for n in range(pages+1):
        pages=n*num
        url=f'https://api.boardgameatlas.com/api/search?limit={limit}&skip={pages}&pretty=true&client_id={env.key}'
        response = requests.get(url)
        data=response.json()
    #games=pd.DataFrame(data['games'])
    return data

# %%
def all_games():
    a=get_games(num=100, pages=0)
    b=get_games(num=100, pages=1)
    c=get_games(num=100, pages=2)
    d=get_games(num=100, pages=3)
    e=get_games(num=100, pages=4)
    f=get_games(num=100, pages=5)
    g=get_games(num=100, pages=6)
    h=get_games(num=100, pages=7)
    i=get_games(num=100, pages=8)
    j=get_games(num=100, pages=9)
    df=pd.concat([a, b, c, d, e, f, g, h, i, j], ignore_index=True)
    return df

# %%
games=get_games()
games
# Out:
# {'games': [{'id': 'qZ7XdSFpaI',
#    'handle': 'magic-the-gathering',
#    'url': 'https://www.boardgameatlas.com/game/qZ7XdSFpaI/magic-the-gathering',
#    'bga_edit_url': 'https://www.boardgameatlas.com/game/qZ7XdSFpaI/edit',
#    'template_url': '/products/listing?objectId=qZ7XdSFpaI&product_line=Board Games&type=product',
#    'name': 'Magic: The Gathering',
#    'price': '144.99',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 1993,
#    'min_players': 2,
#    'max_players': 5,
#    'player_counts': [2, 3, 4, 5],
#    'min_playtime': 30,
#    'max_playtime': 60,
#    'min_age': 13,
#    'description': '<p>This entry is for discussion about Magic: the Gathering as a whole.</p>',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547674624929',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547674624929',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'WPytek5P8l',
#      'url': 'https://www.boardgameatlas.com/mechanic/WPytek5P8l/undefined'},
#     {'id': 'T8JEFYwoqy',
#      'url': 'https://www.boardgameatlas.com/mechanic/T8JEFYwoqy/undefined'}],
#    'categories': [{'id': 'eX8uuNlQkQ',
#      'url': 'https://www.boardgameatlas.com/category/eX8uuNlQkQ/undefined'},
#     {'id': 'vXxLT0FDTZ',
#      'url': 'https://www.boardgameatlas.com/category/vXxLT0FDTZ/undefined'}],
#    'publishers': [{'id': 'LjmghcBsOU',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/LjmghcBsOU/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': '4jZNieU4WU',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/4jZNieU4WU/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'Wizards of the Coast',
#     'id': 'LjmghcBsOU',
#     'url': 'https://www.boardgameatlas.com/publisher/LjmghcBsOU/wizards-of-the-coast'},
#    'primary_designer': {'name': 'Richard Garfield',
#     'id': '4jZNieU4WU',
#     'url': 'https://www.boardgameatlas.com/designer/4jZNieU4WU/richard-garfield'},
#    'developers': [],
#    'related_to': [],
#    'related_as': [],
#    'artists': ['Victor Adame',
#     'Miao Aili',
#     'Randis Albion',
#     'Rob Alexander',
#     'James Allen (I)',
#     'Dave Allsop',
#     'Scott Altmann',
#     'Ian Edward Ameling',
#     'Eric David Anderson',
#     'Chris J. Anderson',
#     'Dana Andrews',
#     'Glen Michael Angus',
#     'Chris Appelhans',
#     'Steve Argyle',
#     'Randy Asplund-Faith',
#     'Janet Aulisio',
#     'John Avon',
#     'Daren Bader',
#     'Volkan Baga',
#     'Scott Bailey',
#     'Drew Baker',
#     'Qi Baocheng',
#     'Julie Baroh',
#     'Tom Baxa',
#     'Edward Beard',
#     'Jr.',
#     'Patrick Beel',
#     'Jason Behnke',
#     'Steven Belledin',
#     'Melissa Benson',
#     'James Bernardin',
#     'Michael Bierek',
#     'Kristen Bishop',
#     'Joel Biske',
#     'Simon Bisley',
#     'Robert Bliss',
#     'Johann Bodin',
#     'Peter Bollinger',
#     'John Bolton',
#     'Paul Bonner',
#     'Zoltan Boros',
#     'Aaron Boyd',
#     'Whit Brachna',
#     'Noah Bradley',
#     'Jacques Bredy',
#     'Aleksi Briclot',
#     'Mark Brill',
#     'Kev Brockschmidt',
#     'Gerald Brom',
#     'Sue Ellen Brown',
#     'Ron Brown',
#     'Cornelius Brudi',
#     'Michael Bruinsma',
#     'Catherine Buck',
#     'Christopher Burdett',
#     'Wesley Burt',
#     'Jeffrey R. Busch',
#     'Clyde Caldwell',
#     'Matt Cavotta',
#     'Clint Cearley',
#     'Paul Chadwick',
#     'Doug Chaffee',
#     'Jason Chan (I)',
#     'David Cherry',
#     'Ron Chironna',
#     'Christine Choi',
#     'Scott Chou',
#     'Wang Chuxiong',
#     'Ciruelo',
#     'Trevor Claxton',
#     'D. J. Cleland-Hura',
#     'Bud Cook',
#     'Mitch Cotie',
#     'John Coulthart',
#     'Carl Critchlow',
#     'jD',
#     'Daarken',
#     'Qiao Dafu',
#     'Liz Danforth',
#     'Oriuzio "Dany Orizio" Daniele',
#     'Stephen A. Daniele',
#     'Mike Danza',
#     'Geof Darrow',
#     'Al Davidson',
#     'David Day',
#     'Nelson DeCastro',
#     'Blackie del Rio',
#     'Thomas Denmark',
#     'Eric Deschamps',
#     'Ai Desheng',
#     'Brian Despain',
#     'Dennis Detwiller',
#     'Dave DeVries',
#     'Chris Dien',
#     'Tony DiTerlizzi',
#     'Kevin Dobler',
#     'Dom!',
#     'Dominick Domingo',
#     'John Donahue',
#     'William Donohoe',
#     'Brandon Dorman'],
#    'names': [],
#    'rules_url': None,
#    'amazon_rank': 7923,
#    'official_url': 'http://www.wizards.com/magic/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 311,
#    'average_user_rating': 3.5669958658704637,
#    'historical_low_prices': [{'country': 'CA',
#      'date': '2021-12-15T17:24:23.799Z',
#      'price': 183.99,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2023-03-25T03:14:26.000Z',
#      'price': 144.99,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 897,
#    'lists': 511,
#    'mentions': 36,
#    'links': 1,
#    'plays': 132614,
#    'rank': 98,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'edit_url': '/products/listing-edit?objectId=qZ7XdSFpaI&product_line=Board Games&type=product',
#    'players': '2-5',
#    'playtime': '30-60',
#    'price_text': '$144.99',
#    'tags': ['Magic: Die Zusammenkunft',
#     'Magic: El Encuentro',
#     "Magic: L'Adunanza",
#     'マジック：ザ・ギャザリング',
#     '万智牌',
#     'Magic The Gathering'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1547674624929',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1547674624929',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1547674624929',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1547674624929',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547674624929'},
#    'description_preview': ' This entry is for discussion about Magic: the Gathering as a whole. '},
#   {'id': 'qYpZFGkKyD',
#    'handle': 'onitama',
#    'url': 'https://www.boardgameatlas.com/game/qYpZFGkKyD/onitama',
#    'bga_edit_url': 'https://www.boardgameatlas.com/game/qYpZFGkKyD/edit',
#    'template_url': '/products/listing?objectId=qYpZFGkKyD&product_line=Board Games&type=product',
#    'name': 'Onitama',
#    'price': '21.79',
#    'price_ca': '32.99',
#    'price_uk': '29.90',
#    'price_au': '42.95',
#    'msrp': 29.99,
#    'msrps': [{'country': 'US', 'price': 29.99},
#     {'country': 'UK', 'price': 27.99}],
#    'discount': '0.27',
#    'year_published': 2014,
#    'min_players': 2,
#    'max_players': 2,
#    'player_counts': [2],
#    'min_playtime': 15,
#    'max_playtime': 30,
#    'min_age': 8,
#    'description': '<div>\r\n<div>\r\n<div>\r\n<div>\r\n<div>\r\n<div>\r\n<div>\r\n<p>An Elegant and Simple Game of Martial Tactics. Carved into the crags of the mist-shrouded mountains of ancient Japan lies the Shrine of Onitama. It is a place of enlightenment and skill, a site dedicated to the spirits that guide the Schools of Martial Arts across the land.</p>\r\n<p>Onitama is a two-player abstract strategy game where you take on the role of a Master, guiding your monk followers, in an attempt to defeat your opponent. Armed only with several moves, your wit, and cunning, do you have the skill to be victorious?</p>\r\n<p>With multiple moves to make every game unique, the speed, the grace, and the unique play style of Onitama truly makes this an essential game for any gamer’s collection!</p>\r\n<h3>Multiple Paths to Victory</h3>\r\n<p>There are two methods to achieve victory in Onitama. The first is to capture your opponent’s Master, by landing on it with any of your pieces. The second is to move your Master across the board into your opponent’s Temple Arch space.</p>\r\n</div>\r\n</div>\r\n</div>\r\n</div>\r\n</div>\r\n</div>\r\n</div>',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'qu5BcGjAzk',
#      'url': 'https://www.boardgameatlas.com/mechanic/qu5BcGjAzk/undefined'},
#     {'id': 'WPytek5P8l',
#      'url': 'https://www.boardgameatlas.com/mechanic/WPytek5P8l/undefined'},
#     {'id': 'VTBonQ4yuA',
#      'url': 'https://www.boardgameatlas.com/mechanic/VTBonQ4yuA/undefined'}],
#    'categories': [{'id': 'a8NM5cugJX',
#      'url': 'https://www.boardgameatlas.com/category/a8NM5cugJX/undefined'}],
#    'publishers': [{'id': 'ke1fAdGIGF',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/ke1fAdGIGF/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'K0uJMQ5z5t',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/K0uJMQ5z5t/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'ke1fAdGIGF',
#     'name': 'Arcane Wonders',
#     'url': 'https://www.boardgameatlas.com/publisher/ke1fAdGIGF/arcane-wonders'},
#    'primary_designer': {'id': 'K0uJMQ5z5t',
#     'name': 'Shimpei Sato',
#     'url': 'https://www.boardgameatlas.com/designer/K0uJMQ5z5t/shimpei-sato'},
#    'developers': [],
#    'related_to': [],
#    'related_as': [],
#    'artists': ['Jun Kondo', 'Mariusz Szmerdt'],
#    'names': [],
#    'rules_url': 'http://www.arcanewonders.com/wp-content/uploads/2017/06/Onitama-Rulebook.pdf',
#    'amazon_rank': 6158,
#    'cs_rating': 4.5,
#    'official_url': 'http://www.arcanewonders.com/game/onitama/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'sell_sheet_url': None,
#    'store_images_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 334,
#    'average_user_rating': 3.6048577844311382,
#    'size_height': 3.8,
#    'historical_low_prices': [{'country': 'AU',
#      'date': '2021-11-18T18:44:28.746Z',
#      'price': 42.95,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2022-01-15T10:19:50.980Z',
#      'price': 27.95,
#      'isLow': False},
#     {'country': 'UK',
#      'date': '2023-03-25T15:27:12.448Z',
#      'price': 29.9,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2023-04-02T05:15:00.124Z',
#      'price': 21.79,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 2,
#    'average_learning_complexity': 1.5,
#    'average_strategy_complexity': 2.5,
#    'visits': 3692,
#    'lists': 987,
#    'mentions': 29,
#    'links': 11,
#    'plays': 2806,
#    'rank': 99,
#    'type': 'game',
#    'sku': 'AWGDTE02ON',
#    'upc': '853211004325',
#    'num_distributors': 1,
#    'trending_rank': 0,
#    'listing_clicks': 12,
#    'is_historical_low': False,
#    'skus': ['AWG DTE02ON',
#     '3558380047254',
#     '853211004325',
#     'AWGDTE02ONA',
#     'AWGDTE02ON',
#     'ARW-BG-ONI',
#     '0853211004325',
#     '86390',
#     'DE02ONAWG',
#     'AWGDT02ON',
#     '28709',
#     '2148756719',
#     '27952:120247',
#     '44376 #0343',
#     'AWGDTE020N',
#     'BG-000029-001',
#     'D0712_ONITAMA_SH',
#     'MDGON00109',
#     'PSIAWGDTE02ON',
#     'AWG-DTE020N',
#     'IG-ON01-FR',
#     'Ballarat|02dcd191-ae0b-11e8-ed44-7909c9b6ce2c',
#     '2149112629'],
#    'sku_objects': [{'name': 'Boarding School Games', 'sku': 'AWG DTE02ON'},
#     {'name': 'Imaginaire Shop', 'sku': '3558380047254'},
#     {'name': 'Boardgame Master', 'sku': '853211004325'},
#     {'name': 'Card Haus', 'sku': 'AWGDTE02ONA'},
#     {'name': 'More Than Meeples', 'sku': 'AWGDTE02ON'},
#     {'name': 'Board Gaming With Education', 'sku': 'ARW-BG-ONI'},
#     {'name': 'Imaginaire Shop', 'sku': '0853211004325'},
#     {'name': 'Game Shack Inc.', 'sku': '86390'},
#     {'name': 'Advent Games', 'sku': 'DE02ONAWG'},
#     {'name': 'Gumnut', 'sku': 'AWGDT02ON'},
#     {'name': 'Hanabee', 'sku': '28709'},
#     {'name': 'Noble Knight Games', 'sku': '2148756719'},
#     {'name': 'BoardGameCo', 'sku': '27952:120247'},
#     {'name': 'Funagain Games', 'sku': '44376 #0343'},
#     {'name': 'Wayland Games', 'sku': 'AWGDTE020N'},
#     {'name': 'Meeples and Milkshakes', 'sku': 'BG-000029-001'},
#     {'name': 'Gameology', 'sku': 'D0712_ONITAMA_SH'},
#     {'name': 'Mr. Dice Guy', 'sku': 'MDGON00109'},
#     {'name': 'Board Game Bandit', 'sku': 'PSIAWGDTE02ON'},
#     {'name': 'Philibert', 'sku': 'AWG-DTE020N'},
#     {'name': 'Philibert', 'sku': 'IG-ON01-FR'},
#     {'name': 'Guf', 'sku': 'Ballarat|02dcd191-ae0b-11e8-ed44-7909c9b6ce2c'},
#     {'name': 'Noble Knight Games', 'sku': '2149112629'}],
#    'edit_url': '/products/listing-edit?objectId=qYpZFGkKyD&product_line=Board Games&type=product',
#    'players': '2',
#    'playtime': '15-30',
#    'msrp_text': '$29.99',
#    'price_text': '$21.79',
#    'tags': ['Onitama',
#     'Onitama - Ding & Dent',
#     'Onitama (Minor Damage)',
#     'ONITAMA',
#     'ONITAMA BASE GAME ENGLISH',
#     'ONITAMA LIGHT AND SHADOW ENGLISH'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254202422-41gcsWWYm8L.jpg'},
#    'description_preview': ' \r\n \r\n \r\n \r\n \r\n \r\n \r\n An Elegant and Simple Game of Martial Tactics. Carved into the crags of the mist-shrouded mountains of ancient Japan lies the Shrine of Onitama. It is a place of enlightenment and skill, a site dedicated to the spirits that guide the Schools of Martial Arts across the land. \r\n Onitama is a two-player abstract strategy game where you take on the role of a Master, guiding your monk followers, in an attempt to defeat your opponent. Armed only with several moves, your wit, and cunning, do you have the skill to be victorious? \r\n With multiple moves to make every game unique, the speed, the grace, and the unique play style of Onitama truly makes this an essential game for any gamer’s collection! \r\n Multiple Paths to Victory \r\n There are two methods to achieve victory in Onitama. The first is to capture your opponent’s Master, by landing on it with any of your pieces. The second is to move your Master across the board into your opponent’s Temple Arch space. \r\n \r\n \r\n \r\n \r\n \r\n \r\n '},
#   {'id': 'rIuNKFl5nr',
#    'handle': 'isle-of-skye-from-chieftain-to-king',
#    'url': 'https://www.boardgameatlas.com/game/rIuNKFl5nr/isle-of-skye-from-chieftain-to-king',
#    'bga_edit_url': 'https://www.boardgameatlas.com/game/rIuNKFl5nr/edit',
#    'template_url': '/products/listing?objectId=rIuNKFl5nr&product_line=Board Games&type=product',
#    'name': 'Isle of Skye: From Chieftain to King',
#    'price': '30.99',
#    'price_ca': '29.99',
#    'price_uk': '0.00',
#    'price_au': '50.99',
#    'msrp': 39.99,
#    'msrps': [{'country': 'UK', 'price': 31.99},
#     {'country': 'US', 'price': 39.99}],
#    'discount': '0.23',
#    'year_published': 2015,
#    'min_players': 2,
#    'max_players': 5,
#    'player_counts': [2, 3, 4, 5],
#    'min_playtime': 30,
#    'max_playtime': 45,
#    'min_age': 8,
#    'description': "<p>Isle of Skye, one of the most beautiful places in the world: Soft sand beaches, gently sloping hills, impressive mountains: the landscape of Isle of Skye is breathtaking and fascinates everyone.<br /><br />In this tile-laying game 2 to 5 players are the chieftains of 5 famous clans. The players try to build their little kingdoms to score as many points as possible. But in each game only 4 of the 16 scoring cards will be scored. Each game is different and leads to different tactics and strategies.<br /><br />To have enough money is useful in all games: In each turn the players can buy a tile from another player. The seller determines the price, but to do it wisely is the most interesting part of this game: A high price will lead to wealth, if someone buys this tile, but if there's no buyer, the seller will lose the money spend on this tile.<br /><br />And in the end the player with the best kingdom will become the sovereign of the island, not the richest player!<br /><br />Isle of Skye is a gateway game for the whole family. With a playing time around 45 minutes , a huge variability and easy rules it's a perfect game for all players. The awesome illustrations by Klemens Franz brings all the athmosphere of the scottish island on your table.</p>",
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://media.miniaturemarket.com/media/catalog/product/m/f/mfg3509_1.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1629323055891.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'AZxlPpi5oq',
#      'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#     {'id': '3tuJiW3pps',
#      'url': 'https://www.boardgameatlas.com/mechanic/3tuJiW3pps/undefined'},
#     {'id': '6YTZ0juKWy',
#      'url': 'https://www.boardgameatlas.com/mechanic/6YTZ0juKWy/undefined'},
#     {'id': 'lA3KUtVFCy',
#      'url': 'https://www.boardgameatlas.com/mechanic/lA3KUtVFCy/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'},
#     {'id': '1nmCkkoKaq',
#      'url': 'https://www.boardgameatlas.com/mechanic/1nmCkkoKaq/undefined'}],
#    'categories': [{'id': 'N0TkEGfEsF',
#      'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/undefined'},
#     {'id': 'buDTYyPw4D',
#      'url': 'https://www.boardgameatlas.com/category/buDTYyPw4D/undefined'}],
#    'publishers': [{'id': 'oQcGa4viSd',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/oQcGa4viSd/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'UMssR9EGlp',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/UMssR9EGlp/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'GedanEKPsC',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/GedanEKPsC/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'b33BrKkCsN',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/b33BrKkCsN/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '1TaoBxZ3GH',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/1TaoBxZ3GH/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'MkcSSYvL2T',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/MkcSSYvL2T/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'TpnESfkdF4',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/TpnESfkdF4/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'r2R8bUHIRD',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/r2R8bUHIRD/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'LTwMCQ94er',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/LTwMCQ94er/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'T2jwhukCWf',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/T2jwhukCWf/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '7GTti1NuCH',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'zH3BOgq2fk',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/zH3BOgq2fk/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'I1p0OTIBOl',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/I1p0OTIBOl/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '5fMAEisHKq',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/5fMAEisHKq/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '1yT0BGJ6ha',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/1yT0BGJ6ha/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '9GlpSO4zcy',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/9GlpSO4zcy/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'o1odl6sd6C',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/o1odl6sd6C/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'EOYtkjv6Kn',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/EOYtkjv6Kn/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'oQcGa4viSd',
#     'name': 'Lookout Games',
#     'url': 'https://www.boardgameatlas.com/publisher/oQcGa4viSd/lookout-games'},
#    'primary_designer': {'id': 'o1odl6sd6C',
#     'name': 'Alexander Pfister',
#     'url': 'https://www.boardgameatlas.com/designer/o1odl6sd6C/alexander-pfister'},
#    'developers': [],
#    'related_to': [],
#    'related_as': [],
#    'artists': ['Klemens Franz'],
#    'names': [],
#    'rules_url': 'https://lookout-spiele.de/wp-content/uploads/IoS_Rules_web_EN.pdf',
#    'amazon_rank': 41789,
#    'cs_rating': 4.3,
#    'official_url': 'http://lookout-spiele.de/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 331,
#    'average_user_rating': 3.6364048338368575,
#    'historical_low_prices': [{'country': 'AU',
#      'date': '2021-02-16T04:45:52.460Z',
#      'price': 56.99,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2022-01-19T02:34:07.410Z',
#      'price': 42.49,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2022-12-04T13:26:06.712Z',
#      'price': 30.99,
#      'isLow': False},
#     {'country': 'UK',
#      'date': '2023-01-04T13:35:55.643Z',
#      'price': 25.44,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 2613,
#    'lists': 971,
#    'mentions': 25,
#    'links': 3,
#    'plays': 1982,
#    'rank': 100,
#    'type': 'game',
#    'sku': 'ASMLK3509',
#    'upc': '4260402315782',
#    'num_distributors': 4,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'skus': ['LK3509',
#     'LKGLK3509',
#     'MDGIS02424',
#     '029877035090',
#     'MFG3509',
#     '29373-VR',
#     '4260402315782',
#     '5250',
#     '87591',
#     '29373',
#     '2987703509',
#     '2148930328',
#     '44071 #0572',
#     '61664:64934',
#     'BG-001059-001',
#     'C0822_ISLEOFSKYE_M',
#     'FUN-IOSFR02-FR',
#     'LKGLK3509DD',
#     'DVG9003',
#     '2148935828',
#     '2148537319'],
#    'sku_objects': [{'name': 'Boarding School Games', 'sku': 'LK3509'},
#     {'name': 'Card Haus', 'sku': 'LKGLK3509'},
#     {'name': 'Mr. Dice Guy', 'sku': 'MDGIS02424'},
#     {'name': 'Good Games', 'sku': '029877035090'},
#     {'name': 'WoodForSheep Hobbies Ltd.', 'sku': 'MFG3509'},
#     {'name': 'Harvey Norman', 'sku': '29373-VR'},
#     {'name': 'Arctic Board Game', 'sku': '4260402315782'},
#     {'name': 'Dragon’s Den Games', 'sku': '5250'},
#     {'name': 'Game Shack Inc.', 'sku': '87591'},
#     {'name': 'Hanabee', 'sku': '29373'},
#     {'name': 'Games Paradise', 'sku': '2987703509'},
#     {'name': 'Noble Knight Games', 'sku': '2148930328'},
#     {'name': 'Funagain Games', 'sku': '44071 #0572'},
#     {'name': 'BoardGameCo', 'sku': '61664:64934'},
#     {'name': 'Meeples and Milkshakes', 'sku': 'BG-001059-001'},
#     {'name': 'Gameology', 'sku': 'C0822_ISLEOFSKYE_M'},
#     {'name': 'Philibert', 'sku': 'FUN-IOSFR02-FR'},
#     {'name': 'Card Haus', 'sku': 'LKGLK3509DD'},
#     {'name': 'Miniature Market', 'sku': 'DVG9003'},
#     {'name': 'Noble Knight Games', 'sku': '2148935828'},
#     {'name': 'Noble Knight Games', 'sku': '2148537319'}],
#    'edit_url': '/products/listing-edit?objectId=rIuNKFl5nr&product_line=Board Games&type=product',
#    'players': '2-5',
#    'playtime': '30-45',
#    'msrp_text': '$39.99',
#    'price_text': '$30.99',
#    'tags': ['Insula Skye: De la Căpetenie la Rege ',
#     'Isla de Skye: De Líder a Rey',
#     'Isle of Skye: Agli Albori del Regno',
#     'Isle of Skye: De Laird à Roi',
#     'Isle of Skye: De Líder a Rei',
#     'Isle of Skye: Vom Häuptling zum König',
#     'Isle of Skye: Ο Βασιλιάς της Σκωτίας',
#     'Ostrov Skye: Jak se náčelník stal králem',
#     'Skye',
#     'Skye szigete',
#     'Wyspa Skye',
#     'Остров скай: Из вождей в короли',
#     'アイル・オブ・スカイ:族長から王へ 日本語版',
#     '斯凱島',
#     'Isle of Skye: From Chieftan to King',
#     'Isle of Skye From Chieftain to King',
#     'Isle of Skye',
#     'Isle of Skye From Chieftain to King Dinged Dented 20 off at checkout',
#     'ISLE OF SKYE From Chieftain to King',
#     'ISLE OF SKYE FROM CHIEFTAIN TO KING',
#     'Isle Of Skye From Chieftain To King'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1629323055891.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1629323055891.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1629323055891.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1629323055891.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1629323055891.jpg'},
#    'description_preview': " Isle of Skye, one of the most beautiful places in the world: Soft sand beaches, gently sloping hills, impressive mountains: the landscape of Isle of Skye is breathtaking and fascinates everyone.  In this tile-laying game 2 to 5 players are the chieftains of 5 famous clans. The players try to build their little kingdoms to score as many points as possible. But in each game only 4 of the 16 scoring cards will be scored. Each game is different and leads to different tactics and strategies.  To have enough money is useful in all games: In each turn the players can buy a tile from another player. The seller determines the price, but to do it wisely is the most interesting part of this game: A high price will lead to wealth, if someone buys this tile, but if there's no buyer, the seller will lose the money spend on this tile.  And in the end the player with the best kingdom will become the sovereign of the island, not the richest player!  Isle of Skye is a gateway game for the whole family. With a playing time around 45 minutes , a huge variability and easy rules it's a perfect game for all players. The awesome illustrations by Klemens Franz brings all the athmosphere of the scottish island on your table. "},
#   {'id': 'A38ipJ48QE',
#    'handle': 'galaxy-trucker',
#    'url': 'https://www.boardgameatlas.com/game/A38ipJ48QE/galaxy-trucker',
#    'bga_edit_url': 'https://www.boardgameatlas.com/game/A38ipJ48QE/edit',
#    'template_url': '/products/listing?objectId=A38ipJ48QE&product_line=Board Games&type=product',
#    'name': 'Galaxy Trucker',
#    'price': '27.89',
#    'price_ca': '26.99',
#    'price_uk': '0.00',
#    'price_au': '49.95',
#    'msrp': 29.95,
#    'msrps': [{'country': 'US', 'price': 29.95},
#     {'country': 'CA', 'price': 50.95},
#     {'country': 'UK', 'price': 0},
#     {'country': 'AU', 'price': 60}],
#    'discount': '0.07',
#    'year_published': 2007,
#    'min_players': 2,
#    'max_players': 4,
#    'player_counts': [2, 3, 4],
#    'min_playtime': 60,
#    'max_playtime': 90,
#    'min_age': 14,
#    'description': "<p>Corporation Incorporated is an interplanetary construction firm that builds sewer systems and low-income housing on the less-developed planets of the Galaxy. For years, Corp Inc. Has tottered on the brink of bankruptcy: transporting building materials to the edge of the Galaxy, where the need for their services is greatest, is a risky business.<br /><br />The company was saved by a few visionaries on the board of directors. Instead of shipping materials to the Periphery, they reasoned, why not build the materials into spacecraft and let them ship themselves? Furthermore, why hire pilots if there are nut-cases who will do it for free?<br /><br />That's where you come in. Just sign the contract, and you gain unrestricted access to a Corp Inc. Warehouse. Build your own space ship from the available prefabricated components, and fly it to the Periphery. Of course, you may have to eat a loss, but any profits you make along the way are yours to keep, and Corporation Incorporated will pay you a bonus for quick delivery.<br /><br />It's possible that you will end up with an insurmountable debt and finish your days panhandling on the streets of Deneb III, but if Lady Luck should smile upon you, you just might find yourself among the 10 billion richest people in the Galaxy!</p>",
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'R0bGq4cAl4',
#      'url': 'https://www.boardgameatlas.com/mechanic/R0bGq4cAl4/undefined'},
#     {'id': 'KFeIfeoFaK',
#      'url': 'https://www.boardgameatlas.com/mechanic/KFeIfeoFaK/undefined'},
#     {'id': 'BbTMRkwL0b',
#      'url': 'https://www.boardgameatlas.com/mechanic/BbTMRkwL0b/undefined'},
#     {'id': 'E9VKQ8uMSP',
#      'url': 'https://www.boardgameatlas.com/mechanic/E9VKQ8uMSP/undefined'},
#     {'id': 'DEvPj5twid',
#      'url': 'https://www.boardgameatlas.com/mechanic/DEvPj5twid/undefined'},
#     {'id': '9jnCsVuRat',
#      'url': 'https://www.boardgameatlas.com/mechanic/9jnCsVuRat/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': 'TYnxiuiI3X',
#      'url': 'https://www.boardgameatlas.com/category/TYnxiuiI3X/undefined'},
#     {'id': 'WVMOS3s2pb',
#      'url': 'https://www.boardgameatlas.com/category/WVMOS3s2pb/undefined'},
#     {'id': '3B3QpKvXD3',
#      'url': 'https://www.boardgameatlas.com/category/3B3QpKvXD3/undefined'},
#     {'id': 'CWYOF9xu7O',
#      'url': 'https://www.boardgameatlas.com/category/CWYOF9xu7O/undefined'}],
#    'publishers': [{'id': '8eHESCflqX',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/8eHESCflqX/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': '3P2XFNApXh',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/3P2XFNApXh/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': '8eHESCflqX',
#     'name': 'Czech Games Edition',
#     'url': 'https://www.boardgameatlas.com/publisher/8eHESCflqX/czech-games-edition'},
#    'primary_designer': {'id': '3P2XFNApXh',
#     'name': 'Vlaada Chvátil',
#     'url': 'https://www.boardgameatlas.com/designer/3P2XFNApXh/vlaada-chvtil'},
#    'developers': [],
#    'related_to': [],
#    'related_as': [],
#    'artists': ['Tomáš Kučerovský', 'Radim Pech'],
#    'names': [],
#    'rules_url': 'https://czechgames.com/files/rules/galaxy-trucker-rules-en.pdf',
#    'amazon_rank': 11224,
#    'cs_rating': 4.2,
#    'official_url': 'https://czechgames.com/en/galaxy-trucker/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'sell_sheet_url': None,
#    'store_images_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 338,
#    'average_user_rating': 3.5933477469276283,
#    'size_height': 9,
#    'historical_low_prices': [{'country': 'AU',
#      'date': '2022-01-07T22:27:14.464Z',
#      'price': 49.95,
#      'isLow': False},
#     {'country': 'UK',
#      'date': '2022-03-18T11:12:14.824Z',
#      'price': 31.01,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2023-03-13T16:33:11.148Z',
#      'price': 26.99,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2023-04-03T00:09:52.596Z',
#      'price': 27.89,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 3,
#    'average_learning_complexity': 2.3333333333333335,
#    'average_strategy_complexity': 3,
#    'visits': 4218,
#    'lists': 947,
#    'mentions': 6,
#    'links': 4,
#    'plays': 1572,
#    'rank': 101,
#    'type': 'game',
#    'upc': '8594156310615',
#    'num_distributors': 1,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'skus': ['3760175510045',
#     'CGE00061',
#     'CGE00061-DD',
#     '79613',
#     '8594156310011',
#     'MDGGA02273',
#     '8594156310615',
#     '15686:176089',
#     '2149177774',
#     'BG-000436-001',
#     'CGE00001',
#     'MDGGA00024',
#     'RIOA08'],
#    'sku_objects': [{'name': 'Imaginaire Shop', 'sku': '3760175510045'},
#     {'name': 'Wayland Games', 'sku': 'CGE00061'},
#     {'name': 'Boardlandia', 'sku': 'CGE00061-DD'},
#     {'name': 'Game Shack Inc.', 'sku': '79613'},
#     {'name': 'Cardboard Memories Inc.', 'sku': '8594156310011'},
#     {'name': 'Mr. Dice Guy', 'sku': 'MDGGA02273'},
#     {'name': 'LVLUP GAMES', 'sku': '8594156310615'},
#     {'name': 'BoardGameCo', 'sku': '15686:176089'},
#     {'name': 'Noble Knight Games', 'sku': '2149177774'},
#     {'name': 'Meeples and Milkshakes', 'sku': 'BG-000436-001'},
#     {'name': 'Miniature Market', 'sku': 'CGE00001'},
#     {'name': 'Mr. Dice Guy', 'sku': 'MDGGA00024'},
#     {'name': 'Legendesque', 'sku': 'RIOA08'}],
#    'edit_url': '/products/listing-edit?objectId=A38ipJ48QE&product_line=Board Games&type=product',
#    'players': '2-4',
#    'playtime': '60-90',
#    'msrp_text': '$29.95',
#    'price_text': '$27.89',
#    'tags': ['Ciężarówką przez Galaktykę',
#     'Galaxis Roncsderbi',
#     'Galaxy Trucker: Aventuras en el Espacio',
#     'Galaxy Trucker: Aventuri în spațiu',
#     'Galaxy Trucker: Космические дальнобойщики',
#     '銀河卡車司機',
#     'Galaxy Trucker 2nd Edition w Spiele Hit Mark',
#     'Galaxy Trucker',
#     'Galaxy Trucker 2021 Edition'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254997948-517JqXFm1TL.jpg'},
#    'description_preview': " Corporation Incorporated is an interplanetary construction firm that builds sewer systems and low-income housing on the less-developed planets of the Galaxy. For years, Corp Inc. Has tottered on the brink of bankruptcy: transporting building materials to the edge of the Galaxy, where the need for their services is greatest, is a risky business.  The company was saved by a few visionaries on the board of directors. Instead of shipping materials to the Periphery, they reasoned, why not build the materials into spacecraft and let them ship themselves? Furthermore, why hire pilots if there are nut-cases who will do it for free?  That's where you come in. Just sign the contract, and you gain unrestricted access to a Corp Inc. Warehouse. Build your own space ship from the available prefabricated components, and fly it to the Periphery. Of course, you may have to eat a loss, but any profits you make along the way are yours to keep, and Corporation Incorporated will pay you a bonus for quick delivery.  It's possible that you will end up with an insurmountable debt and finish your days panhandling on the streets of Deneb III, but if Lady Luck should smile upon you, you just might find yourself among the 10 billion richest people in the Galaxy! "},
#   {'id': 'jBBIIYQmED',
#    'handle': 'the-voyages-of-marco-polo',
#    'url': 'https://www.boardgameatlas.com/game/jBBIIYQmED/the-voyages-of-marco-polo',
#    'bga_edit_url': 'https://www.boardgameatlas.com/game/jBBIIYQmED/edit',
#    'template_url': '/products/listing?objectId=jBBIIYQmED&product_line=Board Games&type=product',
#    'name': 'The Voyages of Marco Polo',
#    'price': '47.99',
#    'price_ca': '49.95',
#    'price_uk': '0.00',
#    'price_au': '81.99',
#    'msrp': 59.99,
#    'msrps': [{'country': 'US', 'price': 59.99},
#     {'country': 'CA', 'price': 67.99},
#     {'country': 'UK', 'price': 54.99}],
#    'discount': '0.20',
#    'year_published': 2015,
#    'min_players': 2,
#    'max_players': 4,
#    'player_counts': [2, 3, 4],
#    'min_playtime': 45,
#    'max_playtime': 90,
#    'min_age': 12,
#    'description': "<div>\r\n<p><strong>A Grand Voyage!</strong><br />The year is 1275, and Marco Polo has finally reached the court of Kublai Khan after four years of grueling travel over the Silk Road. Together with his father, Marco hoped to establish news trade routes to bring riches from the East back to Europe, and in <em>The Voyages of Marco Polo</em>, you will attempt to do the same.</p>\r\n<p>Players will attempt to recreate Marco Polo's famous journey over the Silk Road, playing as Marco and his father or one of their many associates from their travels, each with their own unique power. Collect points by completing contracts, visiting new cities, and reaching your final destination of Beijing and the court of Kublai Khan. Do you have what it takes to prosper? Find out in <em>The Voyages of Marco Polo</em>!<br /><br /><strong>Preparing to Set Out</strong><br /><em>The Voyages of Marco Polo</em> is a Dice Placement game. At the beginning of each Round, players will roll their dice and then take turns placing those dice in space on the board for various effects. Some spaces have the same effect no matter the number on the die placed there, but some spaces have different effects depending on their result of the roll. Some spaces even require you commit multiple dice and take the action based on the lowest number rolled among the dice placed there.</p>\r\n<p>Placing dice is how players move their merchants down the trade routes and toward Beijing, gather money to pay for goods and their travels, acquire resources to fulfill their contracts. And, spaces are limited! Once another player has filled a space, you'll need to spend more resources in order to take the same action, potentially setting your plan back or forcing you to readjust. Plan well and choose your actions wisely, and you may just find yourself ahead of the pack.<br /><br /><strong>Multiple Strategies</strong><br />There are many decisions to be made from round to round, and there are multiple avenues to victory in any given game. The roads you take to victory can change from game to game thanks to the special power of your character and the unique city bonuses used for each.<br /><br /><strong>Unique Powers<br /></strong> Each character has their own unique ability that can hugely impact your strategy as the game progresses. Raschid ad-Din allows you to choose the value of your dice rather than rolling them. Niccolo and Marco Polo give you an additional figure to move across the map and a camel at the beginning of every round. Take advantage of your special skills and leave your opponents in the dust!<br /><br /><strong>Different City Cards Every Game!<br /></strong> With 31 different city cards, every voyage will be unique. Plan your route carefully as you seek to take advantage of the bonuses each city has to offer. At the beginning of each game, the city bonus cards will be drawn randomly from the deck, providing new strategic opportunities and incredible replayability.</p>\r\n</div>",
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'jOAB6RhwBp',
#      'url': 'https://www.boardgameatlas.com/mechanic/jOAB6RhwBp/undefined'},
#     {'id': 'R0bGq4cAl4',
#      'url': 'https://www.boardgameatlas.com/mechanic/R0bGq4cAl4/undefined'},
#     {'id': 'wV5peB05xs',
#      'url': 'https://www.boardgameatlas.com/mechanic/wV5peB05xs/undefined'},
#     {'id': '6RZAs0CCpF',
#      'url': 'https://www.boardgameatlas.com/mechanic/6RZAs0CCpF/undefined'},
#     {'id': 'lA3KUtVFCy',
#      'url': 'https://www.boardgameatlas.com/mechanic/lA3KUtVFCy/undefined'},
#     {'id': 'XM2FYZmBHH',
#      'url': 'https://www.boardgameatlas.com/mechanic/XM2FYZmBHH/undefined'},
#     {'id': 'fBOTEBUAmV',
#      'url': 'https://www.boardgameatlas.com/mechanic/fBOTEBUAmV/undefined'},
#     {'id': 'B30dz3Ljjx',
#      'url': 'https://www.boardgameatlas.com/mechanic/B30dz3Ljjx/undefined'}],
#    'categories': [{'id': 'mavSOM8vjH',
#      'url': 'https://www.boardgameatlas.com/category/mavSOM8vjH/undefined'},
#     {'id': 'N0TkEGfEsF',
#      'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/undefined'},
#     {'id': 'QAYkTHK1Dd',
#      'url': 'https://www.boardgameatlas.com/category/QAYkTHK1Dd/undefined'}],
#    'publishers': [{'id': 'UPqP0MXLqj',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/UPqP0MXLqj/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'ja1W0hp62r',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/ja1W0hp62r/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'zQj37XE9iU',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/zQj37XE9iU/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '1HFd9t6DSV',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/1HFd9t6DSV/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'UPqP0MXLqj',
#     'name': 'Z-Man Games, Inc.',
#     'url': 'https://www.boardgameatlas.com/publisher/UPqP0MXLqj/zman-games-inc'},
#    'primary_designer': {'id': 'zQj37XE9iU',
#     'name': 'Daniele Tascini',
#     'url': 'https://www.boardgameatlas.com/designer/zQj37XE9iU/daniele-tascini'},
#    'developers': [],
#    'related_to': [],
#    'related_as': [],
#    'artists': ['Dennis Lohausen'],
#    'names': [],
#    'rules_url': 'https://www.zmangames.com/en/products/voyages-marco-polo/',
#    'amazon_rank': 156353,
#    'cs_rating': 4.5,
#    'official_url': 'https://www.zmangames.com/en/products/voyages-marco-polo/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'sell_sheet_url': None,
#    'store_images_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 265,
#    'average_user_rating': 3.928422781271838,
#    'size_height': 12.4,
#    'historical_low_prices': [{'country': 'UK',
#      'date': '2021-12-01T08:48:38.627Z',
#      'price': 43.73,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2022-01-10T14:04:04.758Z',
#      'price': 47.99,
#      'isLow': False},
#     {'country': 'AU',
#      'date': '2022-02-08T02:02:35.878Z',
#      'price': 81.99,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2023-02-04T11:10:36.192Z',
#      'price': 49.95,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 2,
#    'average_learning_complexity': 3.5,
#    'average_strategy_complexity': 4,
#    'visits': 2937,
#    'lists': 864,
#    'mentions': 34,
#    'links': 4,
#    'plays': 1973,
#    'rank': 102,
#    'type': 'game',
#    'sku': 'ZMG7590',
#    'upc': '681706715902',
#    'num_distributors': 3,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'skus': ['ZM7590',
#     'ZMGZM7590',
#     '681706715902',
#     '83359',
#     '180214R',
#     'ZMG71590',
#     'ZMG001',
#     '44896',
#     '1419839489',
#     '2148285421',
#     '2149281673',
#     '44187 #0435',
#     '4610871361',
#     '60953:165032',
#     'BG-000386-001',
#     'MDGTH01494',
#     '2149305528'],
#    'sku_objects': [{'name': 'Boarding School Games', 'sku': 'ZM7590'},
#     {'name': 'Card Haus', 'sku': 'ZMGZM7590'},
#     {'name': '401 Games', 'sku': '681706715902'},
#     {'name': 'Game Shack Inc.', 'sku': '83359'},
#     {'name': 'Dragon’s Den Games', 'sku': '180214R'},
#     {'name': 'Apt to Game', 'sku': 'ZMG71590'},
#     {'name': 'Advent Games', 'sku': 'ZMG001'},
#     {'name': 'Hanabee', 'sku': '44896'},
#     {'name': 'BoardGameBliss Inc', 'sku': '1419839489'},
#     {'name': 'Noble Knight Games', 'sku': '2148285421'},
#     {'name': 'Noble Knight Games', 'sku': '2149281673'},
#     {'name': 'Funagain Games', 'sku': '44187 #0435'},
#     {'name': 'BoardGameBliss Inc', 'sku': '4610871361'},
#     {'name': 'BoardGameCo', 'sku': '60953:165032'},
#     {'name': 'Meeples and Milkshakes', 'sku': 'BG-000386-001'},
#     {'name': 'Mr. Dice Guy', 'sku': 'MDGTH01494'},
#     {'name': 'Noble Knight Games', 'sku': '2149305528'}],
#    'edit_url': '/products/listing-edit?objectId=jBBIIYQmED&product_line=Board Games&type=product',
#    'players': '2-4',
#    'playtime': '45-90',
#    'msrp_text': '$59.99',
# ...
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/6wbg6EN7xD/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'nl3J7018LJ',
#     'name': 'CMON',
#     'url': 'https://www.boardgameatlas.com/publisher/nl3J7018LJ/cmon'},
#    'primary_designer': {'id': '6wbg6EN7xD',
#     'name': 'Reiner Knizia',
#     'url': 'https://www.boardgameatlas.com/designer/6wbg6EN7xD/reiner-knizia'},
#    'developers': [],
#    'related_to': [],
#    'related_as': [],
#    'artists': ['Carole Carrion',
#     'Manuel Carvalho',
#     'Chen Cheng-po',
#     'Mike Doyle (I)',
#     'Pete Fenlon',
#     'Paul Laane',
#     'Ramon Martins',
#     'Daniel Melim',
#     'Rafael Silveira',
#     'Sigrid Thaler',
#     'Zeilbeck & Natzeck Design Company'],
#    'names': [],
#    'rules_url': 'https://cmon-files.s3.amazonaws.com/pdf/assets_item/resource/80/MA_Rulebbok_Artbook_v18-low.pdf',
#    'amazon_rank': 64198,
#    'cs_rating': 4.5,
#    'official_url': 'https://cmon.com/product/modern-art/modern-art?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 195,
#    'average_user_rating': 3.685384615384614,
#    'weight_amount': 1.94,
#    'weight_units': 'lbs',
#    'size_height': 10,
#    'size_depth': 10,
#    'size_units': 'inches',
#    'historical_low_prices': [{'country': 'CA',
#      'date': '2021-12-13T19:31:33.222Z',
#      'price': 32.99,
#      'isLow': True},
#     {'country': 'AU',
#      'date': '2021-12-14T01:38:39.102Z',
#      'price': 41.99,
#      'isLow': False},
#     {'country': 'UK',
#      'date': '2022-03-23T00:10:59.530Z',
#      'price': 24.99,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2023-04-02T04:41:40.613Z',
#      'price': 23.59,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 1,
#    'average_learning_complexity': 2,
#    'average_strategy_complexity': 3,
#    'visits': 8146,
#    'lists': 881,
#    'mentions': 6,
#    'links': 4,
#    'plays': 776,
#    'rank': 190,
#    'type': 'game',
#    'upc': '889696005793',
#    'num_distributors': 4,
#    'trending_rank': 0,
#    'listing_clicks': 9,
#    'is_historical_low': False,
#    'skus': ['MDA001',
#     '2149210166',
#     'CMNMA001',
#     '889696005793',
#     '40552 #0',
#     'B-CG-CMNMDA001',
#     '51733',
#     'MOD01',
#     'COLMDA001',
#     '12430379221043',
#     '2148788040',
#     '25086:4879',
#     '871527',
#     'BG-000274-001',
#     'CMNMDA001',
#     'COLMDC001',
#     '2149109424',
#     '101127',
#     '2148900417',
#     'MDA001-DD',
#     '88771',
#     'MFG4402'],
#    'sku_objects': [{'name': 'Boarding School Games', 'sku': 'MDA001'},
#     {'name': 'Noble Knight Games', 'sku': '2149210166'},
#     {'name': 'Card Haus', 'sku': 'CMNMA001'},
#     {'name': '401 Games', 'sku': '889696005793'},
#     {'name': 'Funagain Games', 'sku': '40552 #0'},
#     {'name': 'Magic Madhouse', 'sku': 'B-CG-CMNMDA001'},
#     {'name': 'Game Shack Inc.', 'sku': '51733'},
#     {'name': 'Advent Games', 'sku': 'MOD01'},
#     {'name': 'Gumnut', 'sku': 'COLMDA001'},
#     {'name': 'BoardGameBliss Inc', 'sku': '12430379221043'},
#     {'name': 'Noble Knight Games', 'sku': '2148788040'},
#     {'name': 'BoardGameCo', 'sku': '25086:4879'},
#     {'name': 'BoardGameBliss Inc', 'sku': '871527'},
#     {'name': 'Meeples and Milkshakes', 'sku': 'BG-000274-001'},
#     {'name': 'Miniature Market', 'sku': 'CMNMDA001'},
#     {'name': 'Gumnut', 'sku': 'COLMDC001'},
#     {'name': 'Noble Knight Games', 'sku': '2149109424'},
#     {'name': 'BoardGameBliss Inc', 'sku': '101127'},
#     {'name': 'Noble Knight Games', 'sku': '2148900417'},
#     {'name': 'Boardlandia', 'sku': 'MDA001-DD'},
#     {'name': 'Hanabee', 'sku': '88771'},
#     {'name': 'Miniature Market', 'sku': 'MFG4402'}],
#    'edit_url': '/products/listing-edit?objectId=fmSDkAqJbH&product_line=Board Games&type=product',
#    'players': '3-5',
#    'playtime': '60-90',
#    'msrp_text': '$29.99',
#    'price_text': '$23.59',
#    'tags': ['Art Moderne',
#     'Arte Moderna',
#     'Современное искусство',
#     'スタンプス (Stamps)',
#     'モダンアート',
#     '現代藝術 (现代艺术)',
#     'Modern Art',
#     'Modern Art Board Game',
#     'Modern Art Printing',
#     'Mayfair Games Modern Art',
#     'Modern Art board game',
#     'MODERN ART',
#     'Modern Art 2nd Printing',
#     'Modern Art Chinese Edition',
#     'Modern Art German Edition',
#     'Modern Art 1st Printing',
#     'Modern Art CMON Edition',
#     'Modern Art 2017'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1629324166046.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1629324166046.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1629324166046.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1629324166046.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1629324166046.jpg'},
#    'description_preview': " Beauty is in the eye of the beholder, but in the high-stakes world of fine art auctions, there's nothing more beautiful than making a buck.  In Modern Art, players take on the role of curators, buying and selling paintings for their museum. Over the course of four rounds, they take part in a number of auctions, trying to get the best value for the pieces in their collection. Whoever makes the most money wins the game (and keeps their job). "},
#   {'id': '1EXtdJ7zva',
#    'handle': 'spyfall',
#    'url': 'https://www.boardgameatlas.com/game/1EXtdJ7zva/spyfall',
#    'bga_edit_url': 'https://www.boardgameatlas.com/game/1EXtdJ7zva/edit',
#    'template_url': '/products/listing?objectId=1EXtdJ7zva&product_line=Board Games&type=product',
#    'name': 'Spyfall',
#    'price': '16.99',
#    'price_ca': '24.49',
#    'price_uk': '0.00',
#    'price_au': '34.95',
#    'msrp': 24.95,
#    'msrps': [{'country': 'UK', 'price': 24.99},
#     {'country': 'US', 'price': 24.95}],
#    'discount': '0.32',
#    'year_published': 2014,
#    'min_players': 3,
#    'max_players': 8,
#    'player_counts': [3, 4, 5, 6, 7, 8],
#    'min_playtime': 15,
#    'max_playtime': 30,
#    'min_age': 13,
#    'description': "<p>Walk a mile in the shoes of a spy! Or was it a kilometer in clogs?<br /><br />SPYFALL is an easy-to-learn card game of bluffing, probing questions, clever answers, and suspicion. At the start of each round, players receive a secret card letting them know where they are - a casino, space station, pirate ship, circus, (30 unique locations!) - except that one player receives the SPY card instead of the location. The Spy doesn't know where he is, but wins the round if he can figure it out before he blows his cover!<br /><br />Players then start asking each other questions during the intense 8-minute rounds. Non-Spy players want to ask questions and give answers that prove to the other players that they know where they are. But watch out! If your questions and answers are too specific, the Spy will easily guess the location and win, so you need to practice a bit of subtlety. But if your questions and answers are too generic, you might be accused of being the Spy. The Spy will also sometimes be asked questions (just like any other player would) and have to come up with questions of his own, without knowing anything about where he is! If you listened carefully to the other players, you'll be able to come up with a plausible question or answer... hopefully.<br /><br />Once per round, each player may accuse another player of being the Spy. If all players agree, the game ends and that player's secret card is flipped up. If the Spy is captured, each of the Non-Spy players win the round. If a Non-Spy is revealed, the Spy wins. Finally, if the Spy figures out where he is, he can reveal his card and make a guess. If he's right, he wins the round. If not, the Non-Spy players win.<br /><br />The game is played over a series of rounds and points are awarded each round. A complete game is typically five rounds and the cards are randomly dealt each round. You could even be the Spy two rounds in a row! After the last round, the player with the most points is the winner.</p>",
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'n1GtBt35Rd',
#      'url': 'https://www.boardgameatlas.com/mechanic/n1GtBt35Rd/undefined'},
#     {'id': 'r6yIFvyXDD',
#      'url': 'https://www.boardgameatlas.com/mechanic/r6yIFvyXDD/undefined'},
#     {'id': 'EVeAdboGUA',
#      'url': 'https://www.boardgameatlas.com/mechanic/EVeAdboGUA/undefined'},
#     {'id': 'tyTj0kxoRc',
#      'url': 'https://www.boardgameatlas.com/mechanic/tyTj0kxoRc/undefined'},
#     {'id': 'JYYdBW6UCE',
#      'url': 'https://www.boardgameatlas.com/mechanic/JYYdBW6UCE/undefined'},
#     {'id': 'Tb52O7Id9Q',
#      'url': 'https://www.boardgameatlas.com/mechanic/Tb52O7Id9Q/undefined'}],
#    'categories': [{'id': 'PinhJrhnxU',
#      'url': 'https://www.boardgameatlas.com/category/PinhJrhnxU/undefined'},
#     {'id': 'bCBXJy9qDw',
#      'url': 'https://www.boardgameatlas.com/category/bCBXJy9qDw/undefined'},
#     {'id': 'TYnxiuiI3X',
#      'url': 'https://www.boardgameatlas.com/category/TYnxiuiI3X/undefined'},
#     {'id': 'X8J7RM6dxX',
#      'url': 'https://www.boardgameatlas.com/category/X8J7RM6dxX/undefined'},
#     {'id': 'Hc6vcim5DS',
#      'url': 'https://www.boardgameatlas.com/category/Hc6vcim5DS/undefined'}],
#    'publishers': [{'id': 'Td79E1RD7c',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/Td79E1RD7c/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'H9vKZxWHI6',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/H9vKZxWHI6/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'Td79E1RD7c',
#     'name': 'Cryptozoic Entertainment',
#     'url': 'https://www.boardgameatlas.com/publisher/Td79E1RD7c/cryptozoic-entertainment'},
#    'primary_designer': {'id': 'H9vKZxWHI6',
#     'name': 'Alexandr Ushan',
#     'url': 'https://www.boardgameatlas.com/designer/H9vKZxWHI6/alexandr-ushan'},
#    'developers': [],
#    'related_to': [],
#    'related_as': [],
#    'artists': ['Sergey Dulin', 'Uildrim'],
#    'names': [],
#    'rules_url': 'http://international.hobbyworld.ru/download/rules/international/Spyfall_rules_ENG.pdf',
#    'amazon_rank': 5851,
#    'cs_rating': 4.3,
#    'official_url': 'https://www.cryptozoic.com/spyfall?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 291,
#    'average_user_rating': 3.2709824135839902,
#    'historical_low_prices': [{'country': 'AU',
#      'date': '2021-02-16T04:20:01.736Z',
#      'price': 31.99,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2021-12-06T23:01:22.642Z',
#      'price': 24.95,
#      'isLow': False},
#     {'country': 'UK',
#      'date': '2022-08-19T02:51:02.430Z',
#      'price': 19.87,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2023-04-02T18:39:17.848Z',
#      'price': 16.99,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 3,
#    'average_learning_complexity': 1.3333333333333333,
#    'average_strategy_complexity': 2.6666666666666665,
#    'visits': 1551,
#    'lists': 666,
#    'mentions': 4,
#    'links': 6,
#    'plays': 2456,
#    'rank': 191,
#    'type': 'game',
#    'sku': 'CTZ01904',
#    'upc': '815442019042',
#    'num_distributors': 4,
#    'trending_rank': 0,
#    'listing_clicks': 4,
#    'is_historical_low': False,
#    'skus': ['CZE 19042',
#     'CZE01905',
#     '815442019042',
#     '2149084326',
#     '27505',
#     'CRY42019042',
#     'CRYPT001',
#     '82582',
#     'CRY01904',
#     '11332',
#     '2148658816',
#     '46158:163265',
#     'C0425_SPYFALL_SH',
#     'CTZ01904',
#     'CZE01904',
#     'CZE19042',
#     '44155 #0'],
#    'sku_objects': [{'name': 'Boarding School Games', 'sku': 'CZE 19042'},
#     {'name': 'Card Haus', 'sku': 'CZE01905'},
#     {'name': '401 Games', 'sku': '815442019042'},
#     {'name': 'Noble Knight Games', 'sku': '2149084326'},
#     {'name': 'Hanabee', 'sku': '27505'},
#     {'name': 'Gumnut', 'sku': 'CRY42019042'},
#     {'name': 'Advent Games', 'sku': 'CRYPT001'},
#     {'name': 'Game Shack Inc.', 'sku': '82582'},
#     {'name': 'WoodForSheep Hobbies Ltd.', 'sku': 'CRY01904'},
#     {'name': 'Dragon’s Den Games', 'sku': '11332'},
#     {'name': 'Noble Knight Games', 'sku': '2148658816'},
#     {'name': 'BoardGameCo', 'sku': '46158:163265'},
#     {'name': 'Gameology', 'sku': 'C0425_SPYFALL_SH'},
#     {'name': 'Legendesque', 'sku': 'CTZ01904'},
#     {'name': 'Miniature Market', 'sku': 'CZE01904'},
#     {'name': 'Board Game Bandit', 'sku': 'CZE19042'},
#     {'name': 'Funagain Games', 'sku': '44155 #0'}],
#    'edit_url': '/products/listing-edit?objectId=1EXtdJ7zva&product_line=Board Games&type=product',
#    'players': '3-8',
#    'playtime': '15-30',
#    'msrp_text': '$24.95',
#    'price_text': '$16.99',
#    'tags': ['Agent Trouble',
#     'Agent Undercover',
#     'El Espía (que se perdió)',
#     'Mamy Szpiega!',
#     'Superšpión',
#     'Κατάσκοπος',
#     'Находка для шпиона',
#     'スパイフォール',
#     '스파이폴',
#     'Spyfall'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559253470032-61I8X7DTQZL.jpg'},
#    'description_preview': " Walk a mile in the shoes of a spy! Or was it a kilometer in clogs?  SPYFALL is an easy-to-learn card game of bluffing, probing questions, clever answers, and suspicion. At the start of each round, players receive a secret card letting them know where they are - a casino, space station, pirate ship, circus, (30 unique locations!) - except that one player receives the SPY card instead of the location. The Spy doesn't know where he is, but wins the round if he can figure it out before he blows his cover!  Players then start asking each other questions during the intense 8-minute rounds. Non-Spy players want to ask questions and give answers that prove to the other players that they know where they are. But watch out! If your questions and answers are too specific, the Spy will easily guess the location and win, so you need to practice a bit of subtlety. But if your questions and answers are too generic, you might be accused of being the Spy. The Spy will also sometimes be asked questions (just like any other player would) and have to come up with questions of his own, without knowing anything about where he is! If you listened carefully to the other players, you'll be able to come up with a plausible question or answer... hopefully.  Once per round, each player may accuse another player of being the Spy. If all players agree, the game ends and that player's secret card is flipped up. If the Spy is captured, each of the Non-Spy players win the round. If a Non-Spy is revealed, the Spy wins. Finally, if the Spy figures out where he is, he can reveal his card and make a guess. If he's right, he wins the round. If not, the Non-Spy players win.  The game is played over a series of rounds and points are awarded each round. A complete game is typically five rounds and the cards are randomly dealt each round. You could even be the Spy two rounds in a row! After the last round, the player with the most points is the winner. "}],
#  'count': 152946}

# %%
games=games['games']

# %%
anything={'SWJGuaim9h': 'AI enemies'}

# %%
anything['one']= 2

# %%
anything
# Out:
# {'SWJGuaim9h': 'AI enemies', 'one': 2}

# %%
games
# Out:
# [{'id': 'qZ7XdSFpaI',
#   'handle': 'magic-the-gathering',
#   'url': 'https://www.boardgameatlas.com/game/qZ7XdSFpaI/magic-the-gathering',
#   'bga_edit_url': 'https://www.boardgameatlas.com/game/qZ7XdSFpaI/edit',
#   'template_url': '/products/listing?objectId=qZ7XdSFpaI&product_line=Board Games&type=product',
#   'name': 'Magic: The Gathering',
#   'price': '144.99',
#   'price_ca': '0.00',
#   'price_uk': '0.00',
#   'price_au': '0.00',
#   'msrp': 0,
#   'msrps': [{'country': 'US', 'price': 0}],
#   'discount': '0.00',
#   'year_published': 1993,
#   'min_players': 2,
#   'max_players': 5,
#   'player_counts': [2, 3, 4, 5],
#   'min_playtime': 30,
#   'max_playtime': 60,
#   'min_age': 13,
#   'description': '<p>This entry is for discussion about Magic: the Gathering as a whole.</p>',
#   'commentary': '',
#   'faq': '',
#   'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547674624929',
#   'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547674624929',
#   'matches_specs': None,
#   'specs': [],
#   'mechanics': [{'id': 'WPytek5P8l',
#     'url': 'https://www.boardgameatlas.com/mechanic/WPytek5P8l/undefined'},
#    {'id': 'T8JEFYwoqy',
#     'url': 'https://www.boardgameatlas.com/mechanic/T8JEFYwoqy/undefined'}],
#   'categories': [{'id': 'eX8uuNlQkQ',
#     'url': 'https://www.boardgameatlas.com/category/eX8uuNlQkQ/undefined'},
#    {'id': 'vXxLT0FDTZ',
#     'url': 'https://www.boardgameatlas.com/category/vXxLT0FDTZ/undefined'}],
#   'publishers': [{'id': 'LjmghcBsOU',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/LjmghcBsOU/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'designers': [{'id': '4jZNieU4WU',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/4jZNieU4WU/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'primary_publisher': {'name': 'Wizards of the Coast',
#    'id': 'LjmghcBsOU',
#    'url': 'https://www.boardgameatlas.com/publisher/LjmghcBsOU/wizards-of-the-coast'},
#   'primary_designer': {'name': 'Richard Garfield',
#    'id': '4jZNieU4WU',
#    'url': 'https://www.boardgameatlas.com/designer/4jZNieU4WU/richard-garfield'},
#   'developers': [],
#   'related_to': [],
#   'related_as': [],
#   'artists': ['Victor Adame',
#    'Miao Aili',
#    'Randis Albion',
#    'Rob Alexander',
#    'James Allen (I)',
#    'Dave Allsop',
#    'Scott Altmann',
#    'Ian Edward Ameling',
#    'Eric David Anderson',
#    'Chris J. Anderson',
#    'Dana Andrews',
#    'Glen Michael Angus',
#    'Chris Appelhans',
#    'Steve Argyle',
#    'Randy Asplund-Faith',
#    'Janet Aulisio',
#    'John Avon',
#    'Daren Bader',
#    'Volkan Baga',
#    'Scott Bailey',
#    'Drew Baker',
#    'Qi Baocheng',
#    'Julie Baroh',
#    'Tom Baxa',
#    'Edward Beard',
#    'Jr.',
#    'Patrick Beel',
#    'Jason Behnke',
#    'Steven Belledin',
#    'Melissa Benson',
#    'James Bernardin',
#    'Michael Bierek',
#    'Kristen Bishop',
#    'Joel Biske',
#    'Simon Bisley',
#    'Robert Bliss',
#    'Johann Bodin',
#    'Peter Bollinger',
#    'John Bolton',
#    'Paul Bonner',
#    'Zoltan Boros',
#    'Aaron Boyd',
#    'Whit Brachna',
#    'Noah Bradley',
#    'Jacques Bredy',
#    'Aleksi Briclot',
#    'Mark Brill',
#    'Kev Brockschmidt',
#    'Gerald Brom',
#    'Sue Ellen Brown',
#    'Ron Brown',
#    'Cornelius Brudi',
#    'Michael Bruinsma',
#    'Catherine Buck',
#    'Christopher Burdett',
#    'Wesley Burt',
#    'Jeffrey R. Busch',
#    'Clyde Caldwell',
#    'Matt Cavotta',
#    'Clint Cearley',
#    'Paul Chadwick',
#    'Doug Chaffee',
#    'Jason Chan (I)',
#    'David Cherry',
#    'Ron Chironna',
#    'Christine Choi',
#    'Scott Chou',
#    'Wang Chuxiong',
#    'Ciruelo',
#    'Trevor Claxton',
#    'D. J. Cleland-Hura',
#    'Bud Cook',
#    'Mitch Cotie',
#    'John Coulthart',
#    'Carl Critchlow',
#    'jD',
#    'Daarken',
#    'Qiao Dafu',
#    'Liz Danforth',
#    'Oriuzio "Dany Orizio" Daniele',
#    'Stephen A. Daniele',
#    'Mike Danza',
#    'Geof Darrow',
#    'Al Davidson',
#    'David Day',
#    'Nelson DeCastro',
#    'Blackie del Rio',
#    'Thomas Denmark',
#    'Eric Deschamps',
#    'Ai Desheng',
#    'Brian Despain',
#    'Dennis Detwiller',
#    'Dave DeVries',
#    'Chris Dien',
#    'Tony DiTerlizzi',
#    'Kevin Dobler',
#    'Dom!',
#    'Dominick Domingo',
#    'John Donahue',
#    'William Donohoe',
#    'Brandon Dorman'],
#   'names': [],
#   'rules_url': None,
#   'amazon_rank': 7923,
#   'official_url': 'http://www.wizards.com/magic/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#   'comment_count': 0,
#   'num_user_ratings': 311,
#   'average_user_rating': 3.5669958658704637,
#   'historical_low_prices': [{'country': 'CA',
#     'date': '2021-12-15T17:24:23.799Z',
#     'price': 183.99,
#     'isLow': False},
#    {'country': 'US',
#     'date': '2023-03-25T03:14:26.000Z',
#     'price': 144.99,
#     'isLow': False}],
#   'active': True,
#   'num_user_complexity_votes': 0,
#   'average_learning_complexity': 0,
#   'average_strategy_complexity': 0,
#   'visits': 897,
#   'lists': 511,
#   'mentions': 36,
#   'links': 1,
#   'plays': 132614,
#   'rank': 98,
#   'type': 'game',
#   'num_distributors': 0,
#   'trending_rank': 0,
#   'listing_clicks': 0,
#   'is_historical_low': False,
#   'edit_url': '/products/listing-edit?objectId=qZ7XdSFpaI&product_line=Board Games&type=product',
#   'players': '2-5',
#   'playtime': '30-60',
#   'price_text': '$144.99',
#   'tags': ['Magic: Die Zusammenkunft',
#    'Magic: El Encuentro',
#    "Magic: L'Adunanza",
#    'マジック：ザ・ギャザリング',
#    '万智牌',
#    'Magic The Gathering'],
#   'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1547674624929',
#    'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1547674624929',
#    'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1547674624929',
#    'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1547674624929',
#    'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547674624929'},
#   'description_preview': ' This entry is for discussion about Magic: the Gathering as a whole. '},
#  {'id': 'qYpZFGkKyD',
#   'handle': 'onitama',
#   'url': 'https://www.boardgameatlas.com/game/qYpZFGkKyD/onitama',
#   'bga_edit_url': 'https://www.boardgameatlas.com/game/qYpZFGkKyD/edit',
#   'template_url': '/products/listing?objectId=qYpZFGkKyD&product_line=Board Games&type=product',
#   'name': 'Onitama',
#   'price': '21.79',
#   'price_ca': '32.99',
#   'price_uk': '29.90',
#   'price_au': '42.95',
#   'msrp': 29.99,
#   'msrps': [{'country': 'US', 'price': 29.99},
#    {'country': 'UK', 'price': 27.99}],
#   'discount': '0.27',
#   'year_published': 2014,
#   'min_players': 2,
#   'max_players': 2,
#   'player_counts': [2],
#   'min_playtime': 15,
#   'max_playtime': 30,
#   'min_age': 8,
#   'description': '<div>\r\n<div>\r\n<div>\r\n<div>\r\n<div>\r\n<div>\r\n<div>\r\n<p>An Elegant and Simple Game of Martial Tactics. Carved into the crags of the mist-shrouded mountains of ancient Japan lies the Shrine of Onitama. It is a place of enlightenment and skill, a site dedicated to the spirits that guide the Schools of Martial Arts across the land.</p>\r\n<p>Onitama is a two-player abstract strategy game where you take on the role of a Master, guiding your monk followers, in an attempt to defeat your opponent. Armed only with several moves, your wit, and cunning, do you have the skill to be victorious?</p>\r\n<p>With multiple moves to make every game unique, the speed, the grace, and the unique play style of Onitama truly makes this an essential game for any gamer’s collection!</p>\r\n<h3>Multiple Paths to Victory</h3>\r\n<p>There are two methods to achieve victory in Onitama. The first is to capture your opponent’s Master, by landing on it with any of your pieces. The second is to move your Master across the board into your opponent’s Temple Arch space.</p>\r\n</div>\r\n</div>\r\n</div>\r\n</div>\r\n</div>\r\n</div>\r\n</div>',
#   'commentary': '',
#   'faq': '',
#   'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#   'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#   'matches_specs': None,
#   'specs': [],
#   'mechanics': [{'id': 'qu5BcGjAzk',
#     'url': 'https://www.boardgameatlas.com/mechanic/qu5BcGjAzk/undefined'},
#    {'id': 'WPytek5P8l',
#     'url': 'https://www.boardgameatlas.com/mechanic/WPytek5P8l/undefined'},
#    {'id': 'VTBonQ4yuA',
#     'url': 'https://www.boardgameatlas.com/mechanic/VTBonQ4yuA/undefined'}],
#   'categories': [{'id': 'a8NM5cugJX',
#     'url': 'https://www.boardgameatlas.com/category/a8NM5cugJX/undefined'}],
#   'publishers': [{'id': 'ke1fAdGIGF',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/ke1fAdGIGF/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'designers': [{'id': 'K0uJMQ5z5t',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/K0uJMQ5z5t/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'primary_publisher': {'id': 'ke1fAdGIGF',
#    'name': 'Arcane Wonders',
#    'url': 'https://www.boardgameatlas.com/publisher/ke1fAdGIGF/arcane-wonders'},
#   'primary_designer': {'id': 'K0uJMQ5z5t',
#    'name': 'Shimpei Sato',
#    'url': 'https://www.boardgameatlas.com/designer/K0uJMQ5z5t/shimpei-sato'},
#   'developers': [],
#   'related_to': [],
#   'related_as': [],
#   'artists': ['Jun Kondo', 'Mariusz Szmerdt'],
#   'names': [],
#   'rules_url': 'http://www.arcanewonders.com/wp-content/uploads/2017/06/Onitama-Rulebook.pdf',
#   'amazon_rank': 6158,
#   'cs_rating': 4.5,
#   'official_url': 'http://www.arcanewonders.com/game/onitama/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#   'sell_sheet_url': None,
#   'store_images_url': None,
#   'comment_count': 0,
#   'num_user_ratings': 334,
#   'average_user_rating': 3.6048577844311382,
#   'size_height': 3.8,
#   'historical_low_prices': [{'country': 'AU',
#     'date': '2021-11-18T18:44:28.746Z',
#     'price': 42.95,
#     'isLow': False},
#    {'country': 'CA',
#     'date': '2022-01-15T10:19:50.980Z',
#     'price': 27.95,
#     'isLow': False},
#    {'country': 'UK',
#     'date': '2023-03-25T15:27:12.448Z',
#     'price': 29.9,
#     'isLow': False},
#    {'country': 'US',
#     'date': '2023-04-02T05:15:00.124Z',
#     'price': 21.79,
#     'isLow': False}],
#   'active': True,
#   'num_user_complexity_votes': 2,
#   'average_learning_complexity': 1.5,
#   'average_strategy_complexity': 2.5,
#   'visits': 3692,
#   'lists': 987,
#   'mentions': 29,
#   'links': 11,
#   'plays': 2806,
#   'rank': 99,
#   'type': 'game',
#   'sku': 'AWGDTE02ON',
#   'upc': '853211004325',
#   'num_distributors': 1,
#   'trending_rank': 0,
#   'listing_clicks': 12,
#   'is_historical_low': False,
#   'skus': ['AWG DTE02ON',
#    '3558380047254',
#    '853211004325',
#    'AWGDTE02ONA',
#    'AWGDTE02ON',
#    'ARW-BG-ONI',
#    '0853211004325',
#    '86390',
#    'DE02ONAWG',
#    'AWGDT02ON',
#    '28709',
#    '2148756719',
#    '27952:120247',
#    '44376 #0343',
#    'AWGDTE020N',
#    'BG-000029-001',
#    'D0712_ONITAMA_SH',
#    'MDGON00109',
#    'PSIAWGDTE02ON',
#    'AWG-DTE020N',
#    'IG-ON01-FR',
#    'Ballarat|02dcd191-ae0b-11e8-ed44-7909c9b6ce2c',
#    '2149112629'],
#   'sku_objects': [{'name': 'Boarding School Games', 'sku': 'AWG DTE02ON'},
#    {'name': 'Imaginaire Shop', 'sku': '3558380047254'},
#    {'name': 'Boardgame Master', 'sku': '853211004325'},
#    {'name': 'Card Haus', 'sku': 'AWGDTE02ONA'},
#    {'name': 'More Than Meeples', 'sku': 'AWGDTE02ON'},
#    {'name': 'Board Gaming With Education', 'sku': 'ARW-BG-ONI'},
#    {'name': 'Imaginaire Shop', 'sku': '0853211004325'},
#    {'name': 'Game Shack Inc.', 'sku': '86390'},
#    {'name': 'Advent Games', 'sku': 'DE02ONAWG'},
#    {'name': 'Gumnut', 'sku': 'AWGDT02ON'},
#    {'name': 'Hanabee', 'sku': '28709'},
#    {'name': 'Noble Knight Games', 'sku': '2148756719'},
#    {'name': 'BoardGameCo', 'sku': '27952:120247'},
#    {'name': 'Funagain Games', 'sku': '44376 #0343'},
#    {'name': 'Wayland Games', 'sku': 'AWGDTE020N'},
#    {'name': 'Meeples and Milkshakes', 'sku': 'BG-000029-001'},
#    {'name': 'Gameology', 'sku': 'D0712_ONITAMA_SH'},
#    {'name': 'Mr. Dice Guy', 'sku': 'MDGON00109'},
#    {'name': 'Board Game Bandit', 'sku': 'PSIAWGDTE02ON'},
#    {'name': 'Philibert', 'sku': 'AWG-DTE020N'},
#    {'name': 'Philibert', 'sku': 'IG-ON01-FR'},
#    {'name': 'Guf', 'sku': 'Ballarat|02dcd191-ae0b-11e8-ed44-7909c9b6ce2c'},
#    {'name': 'Noble Knight Games', 'sku': '2149112629'}],
#   'edit_url': '/products/listing-edit?objectId=qYpZFGkKyD&product_line=Board Games&type=product',
#   'players': '2',
#   'playtime': '15-30',
#   'msrp_text': '$29.99',
#   'price_text': '$21.79',
#   'tags': ['Onitama',
#    'Onitama - Ding & Dent',
#    'Onitama (Minor Damage)',
#    'ONITAMA',
#    'ONITAMA BASE GAME ENGLISH',
#    'ONITAMA LIGHT AND SHADOW ENGLISH'],
#   'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#    'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#    'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#    'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559254202422-41gcsWWYm8L.jpg',
#    'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254202422-41gcsWWYm8L.jpg'},
#   'description_preview': ' \r\n \r\n \r\n \r\n \r\n \r\n \r\n An Elegant and Simple Game of Martial Tactics. Carved into the crags of the mist-shrouded mountains of ancient Japan lies the Shrine of Onitama. It is a place of enlightenment and skill, a site dedicated to the spirits that guide the Schools of Martial Arts across the land. \r\n Onitama is a two-player abstract strategy game where you take on the role of a Master, guiding your monk followers, in an attempt to defeat your opponent. Armed only with several moves, your wit, and cunning, do you have the skill to be victorious? \r\n With multiple moves to make every game unique, the speed, the grace, and the unique play style of Onitama truly makes this an essential game for any gamer’s collection! \r\n Multiple Paths to Victory \r\n There are two methods to achieve victory in Onitama. The first is to capture your opponent’s Master, by landing on it with any of your pieces. The second is to move your Master across the board into your opponent’s Temple Arch space. \r\n \r\n \r\n \r\n \r\n \r\n \r\n '},
#  {'id': 'rIuNKFl5nr',
#   'handle': 'isle-of-skye-from-chieftain-to-king',
#   'url': 'https://www.boardgameatlas.com/game/rIuNKFl5nr/isle-of-skye-from-chieftain-to-king',
#   'bga_edit_url': 'https://www.boardgameatlas.com/game/rIuNKFl5nr/edit',
#   'template_url': '/products/listing?objectId=rIuNKFl5nr&product_line=Board Games&type=product',
#   'name': 'Isle of Skye: From Chieftain to King',
#   'price': '30.99',
#   'price_ca': '29.99',
#   'price_uk': '0.00',
#   'price_au': '50.99',
#   'msrp': 39.99,
#   'msrps': [{'country': 'UK', 'price': 31.99},
#    {'country': 'US', 'price': 39.99}],
#   'discount': '0.23',
#   'year_published': 2015,
#   'min_players': 2,
#   'max_players': 5,
#   'player_counts': [2, 3, 4, 5],
#   'min_playtime': 30,
#   'max_playtime': 45,
#   'min_age': 8,
#   'description': "<p>Isle of Skye, one of the most beautiful places in the world: Soft sand beaches, gently sloping hills, impressive mountains: the landscape of Isle of Skye is breathtaking and fascinates everyone.<br /><br />In this tile-laying game 2 to 5 players are the chieftains of 5 famous clans. The players try to build their little kingdoms to score as many points as possible. But in each game only 4 of the 16 scoring cards will be scored. Each game is different and leads to different tactics and strategies.<br /><br />To have enough money is useful in all games: In each turn the players can buy a tile from another player. The seller determines the price, but to do it wisely is the most interesting part of this game: A high price will lead to wealth, if someone buys this tile, but if there's no buyer, the seller will lose the money spend on this tile.<br /><br />And in the end the player with the best kingdom will become the sovereign of the island, not the richest player!<br /><br />Isle of Skye is a gateway game for the whole family. With a playing time around 45 minutes , a huge variability and easy rules it's a perfect game for all players. The awesome illustrations by Klemens Franz brings all the athmosphere of the scottish island on your table.</p>",
#   'commentary': '',
#   'faq': '',
#   'thumb_url': 'https://media.miniaturemarket.com/media/catalog/product/m/f/mfg3509_1.jpg',
#   'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1629323055891.jpg',
#   'matches_specs': None,
#   'specs': [],
#   'mechanics': [{'id': 'AZxlPpi5oq',
#     'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#    {'id': '3tuJiW3pps',
#     'url': 'https://www.boardgameatlas.com/mechanic/3tuJiW3pps/undefined'},
#    {'id': '6YTZ0juKWy',
#     'url': 'https://www.boardgameatlas.com/mechanic/6YTZ0juKWy/undefined'},
#    {'id': 'lA3KUtVFCy',
#     'url': 'https://www.boardgameatlas.com/mechanic/lA3KUtVFCy/undefined'},
#    {'id': '8PN2HE86wg',
#     'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'},
#    {'id': '1nmCkkoKaq',
#     'url': 'https://www.boardgameatlas.com/mechanic/1nmCkkoKaq/undefined'}],
#   'categories': [{'id': 'N0TkEGfEsF',
#     'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/undefined'},
#    {'id': 'buDTYyPw4D',
#     'url': 'https://www.boardgameatlas.com/category/buDTYyPw4D/undefined'}],
#   'publishers': [{'id': 'oQcGa4viSd',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/oQcGa4viSd/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'UMssR9EGlp',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/UMssR9EGlp/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'GedanEKPsC',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/GedanEKPsC/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'b33BrKkCsN',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/b33BrKkCsN/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': '1TaoBxZ3GH',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/1TaoBxZ3GH/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'MkcSSYvL2T',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/MkcSSYvL2T/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'TpnESfkdF4',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/TpnESfkdF4/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'r2R8bUHIRD',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/r2R8bUHIRD/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'LTwMCQ94er',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/LTwMCQ94er/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'T2jwhukCWf',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/T2jwhukCWf/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': '7GTti1NuCH',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'zH3BOgq2fk',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/zH3BOgq2fk/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'I1p0OTIBOl',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/I1p0OTIBOl/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': '5fMAEisHKq',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/5fMAEisHKq/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': '1yT0BGJ6ha',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/1yT0BGJ6ha/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': '9GlpSO4zcy',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/9GlpSO4zcy/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'designers': [{'id': 'o1odl6sd6C',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/o1odl6sd6C/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'EOYtkjv6Kn',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/EOYtkjv6Kn/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'primary_publisher': {'id': 'oQcGa4viSd',
#    'name': 'Lookout Games',
#    'url': 'https://www.boardgameatlas.com/publisher/oQcGa4viSd/lookout-games'},
#   'primary_designer': {'id': 'o1odl6sd6C',
#    'name': 'Alexander Pfister',
#    'url': 'https://www.boardgameatlas.com/designer/o1odl6sd6C/alexander-pfister'},
#   'developers': [],
#   'related_to': [],
#   'related_as': [],
#   'artists': ['Klemens Franz'],
#   'names': [],
#   'rules_url': 'https://lookout-spiele.de/wp-content/uploads/IoS_Rules_web_EN.pdf',
#   'amazon_rank': 41789,
#   'cs_rating': 4.3,
#   'official_url': 'http://lookout-spiele.de/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#   'comment_count': 0,
#   'num_user_ratings': 331,
#   'average_user_rating': 3.6364048338368575,
#   'historical_low_prices': [{'country': 'AU',
#     'date': '2021-02-16T04:45:52.460Z',
#     'price': 56.99,
#     'isLow': False},
#    {'country': 'CA',
#     'date': '2022-01-19T02:34:07.410Z',
#     'price': 42.49,
#     'isLow': False},
#    {'country': 'US',
#     'date': '2022-12-04T13:26:06.712Z',
#     'price': 30.99,
#     'isLow': False},
#    {'country': 'UK',
#     'date': '2023-01-04T13:35:55.643Z',
#     'price': 25.44,
#     'isLow': False}],
#   'active': True,
#   'num_user_complexity_votes': 0,
#   'average_learning_complexity': 0,
#   'average_strategy_complexity': 0,
#   'visits': 2613,
#   'lists': 971,
#   'mentions': 25,
#   'links': 3,
#   'plays': 1982,
#   'rank': 100,
#   'type': 'game',
#   'sku': 'ASMLK3509',
#   'upc': '4260402315782',
#   'num_distributors': 4,
#   'trending_rank': 0,
#   'listing_clicks': 0,
#   'is_historical_low': False,
#   'skus': ['LK3509',
#    'LKGLK3509',
#    'MDGIS02424',
#    '029877035090',
#    'MFG3509',
#    '29373-VR',
#    '4260402315782',
#    '5250',
#    '87591',
#    '29373',
#    '2987703509',
#    '2148930328',
#    '44071 #0572',
#    '61664:64934',
#    'BG-001059-001',
#    'C0822_ISLEOFSKYE_M',
#    'FUN-IOSFR02-FR',
#    'LKGLK3509DD',
#    'DVG9003',
#    '2148935828',
#    '2148537319'],
#   'sku_objects': [{'name': 'Boarding School Games', 'sku': 'LK3509'},
#    {'name': 'Card Haus', 'sku': 'LKGLK3509'},
#    {'name': 'Mr. Dice Guy', 'sku': 'MDGIS02424'},
#    {'name': 'Good Games', 'sku': '029877035090'},
#    {'name': 'WoodForSheep Hobbies Ltd.', 'sku': 'MFG3509'},
#    {'name': 'Harvey Norman', 'sku': '29373-VR'},
#    {'name': 'Arctic Board Game', 'sku': '4260402315782'},
#    {'name': 'Dragon’s Den Games', 'sku': '5250'},
#    {'name': 'Game Shack Inc.', 'sku': '87591'},
#    {'name': 'Hanabee', 'sku': '29373'},
#    {'name': 'Games Paradise', 'sku': '2987703509'},
#    {'name': 'Noble Knight Games', 'sku': '2148930328'},
#    {'name': 'Funagain Games', 'sku': '44071 #0572'},
#    {'name': 'BoardGameCo', 'sku': '61664:64934'},
#    {'name': 'Meeples and Milkshakes', 'sku': 'BG-001059-001'},
#    {'name': 'Gameology', 'sku': 'C0822_ISLEOFSKYE_M'},
#    {'name': 'Philibert', 'sku': 'FUN-IOSFR02-FR'},
#    {'name': 'Card Haus', 'sku': 'LKGLK3509DD'},
#    {'name': 'Miniature Market', 'sku': 'DVG9003'},
#    {'name': 'Noble Knight Games', 'sku': '2148935828'},
#    {'name': 'Noble Knight Games', 'sku': '2148537319'}],
#   'edit_url': '/products/listing-edit?objectId=rIuNKFl5nr&product_line=Board Games&type=product',
#   'players': '2-5',
#   'playtime': '30-45',
#   'msrp_text': '$39.99',
#   'price_text': '$30.99',
#   'tags': ['Insula Skye: De la Căpetenie la Rege ',
#    'Isla de Skye: De Líder a Rey',
#    'Isle of Skye: Agli Albori del Regno',
#    'Isle of Skye: De Laird à Roi',
#    'Isle of Skye: De Líder a Rei',
#    'Isle of Skye: Vom Häuptling zum König',
#    'Isle of Skye: Ο Βασιλιάς της Σκωτίας',
#    'Ostrov Skye: Jak se náčelník stal králem',
#    'Skye',
#    'Skye szigete',
#    'Wyspa Skye',
#    'Остров скай: Из вождей в короли',
#    'アイル・オブ・スカイ:族長から王へ 日本語版',
#    '斯凱島',
#    'Isle of Skye: From Chieftan to King',
#    'Isle of Skye From Chieftain to King',
#    'Isle of Skye',
#    'Isle of Skye From Chieftain to King Dinged Dented 20 off at checkout',
#    'ISLE OF SKYE From Chieftain to King',
#    'ISLE OF SKYE FROM CHIEFTAIN TO KING',
#    'Isle Of Skye From Chieftain To King'],
#   'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1629323055891.jpg',
#    'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1629323055891.jpg',
#    'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1629323055891.jpg',
#    'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1629323055891.jpg',
#    'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1629323055891.jpg'},
#   'description_preview': " Isle of Skye, one of the most beautiful places in the world: Soft sand beaches, gently sloping hills, impressive mountains: the landscape of Isle of Skye is breathtaking and fascinates everyone.  In this tile-laying game 2 to 5 players are the chieftains of 5 famous clans. The players try to build their little kingdoms to score as many points as possible. But in each game only 4 of the 16 scoring cards will be scored. Each game is different and leads to different tactics and strategies.  To have enough money is useful in all games: In each turn the players can buy a tile from another player. The seller determines the price, but to do it wisely is the most interesting part of this game: A high price will lead to wealth, if someone buys this tile, but if there's no buyer, the seller will lose the money spend on this tile.  And in the end the player with the best kingdom will become the sovereign of the island, not the richest player!  Isle of Skye is a gateway game for the whole family. With a playing time around 45 minutes , a huge variability and easy rules it's a perfect game for all players. The awesome illustrations by Klemens Franz brings all the athmosphere of the scottish island on your table. "},
#  {'id': 'A38ipJ48QE',
#   'handle': 'galaxy-trucker',
#   'url': 'https://www.boardgameatlas.com/game/A38ipJ48QE/galaxy-trucker',
#   'bga_edit_url': 'https://www.boardgameatlas.com/game/A38ipJ48QE/edit',
#   'template_url': '/products/listing?objectId=A38ipJ48QE&product_line=Board Games&type=product',
#   'name': 'Galaxy Trucker',
#   'price': '27.89',
#   'price_ca': '26.99',
#   'price_uk': '0.00',
#   'price_au': '49.95',
#   'msrp': 29.95,
#   'msrps': [{'country': 'US', 'price': 29.95},
#    {'country': 'CA', 'price': 50.95},
#    {'country': 'UK', 'price': 0},
#    {'country': 'AU', 'price': 60}],
#   'discount': '0.07',
#   'year_published': 2007,
#   'min_players': 2,
#   'max_players': 4,
#   'player_counts': [2, 3, 4],
#   'min_playtime': 60,
#   'max_playtime': 90,
#   'min_age': 14,
#   'description': "<p>Corporation Incorporated is an interplanetary construction firm that builds sewer systems and low-income housing on the less-developed planets of the Galaxy. For years, Corp Inc. Has tottered on the brink of bankruptcy: transporting building materials to the edge of the Galaxy, where the need for their services is greatest, is a risky business.<br /><br />The company was saved by a few visionaries on the board of directors. Instead of shipping materials to the Periphery, they reasoned, why not build the materials into spacecraft and let them ship themselves? Furthermore, why hire pilots if there are nut-cases who will do it for free?<br /><br />That's where you come in. Just sign the contract, and you gain unrestricted access to a Corp Inc. Warehouse. Build your own space ship from the available prefabricated components, and fly it to the Periphery. Of course, you may have to eat a loss, but any profits you make along the way are yours to keep, and Corporation Incorporated will pay you a bonus for quick delivery.<br /><br />It's possible that you will end up with an insurmountable debt and finish your days panhandling on the streets of Deneb III, but if Lady Luck should smile upon you, you just might find yourself among the 10 billion richest people in the Galaxy!</p>",
#   'commentary': '',
#   'faq': '',
#   'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#   'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#   'matches_specs': None,
#   'specs': [],
#   'mechanics': [{'id': 'R0bGq4cAl4',
#     'url': 'https://www.boardgameatlas.com/mechanic/R0bGq4cAl4/undefined'},
#    {'id': 'KFeIfeoFaK',
#     'url': 'https://www.boardgameatlas.com/mechanic/KFeIfeoFaK/undefined'},
#    {'id': 'BbTMRkwL0b',
#     'url': 'https://www.boardgameatlas.com/mechanic/BbTMRkwL0b/undefined'},
#    {'id': 'E9VKQ8uMSP',
#     'url': 'https://www.boardgameatlas.com/mechanic/E9VKQ8uMSP/undefined'},
#    {'id': 'DEvPj5twid',
#     'url': 'https://www.boardgameatlas.com/mechanic/DEvPj5twid/undefined'},
#    {'id': '9jnCsVuRat',
#     'url': 'https://www.boardgameatlas.com/mechanic/9jnCsVuRat/undefined'},
#    {'id': '8PN2HE86wg',
#     'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#   'categories': [{'id': 'TYnxiuiI3X',
#     'url': 'https://www.boardgameatlas.com/category/TYnxiuiI3X/undefined'},
#    {'id': 'WVMOS3s2pb',
#     'url': 'https://www.boardgameatlas.com/category/WVMOS3s2pb/undefined'},
#    {'id': '3B3QpKvXD3',
#     'url': 'https://www.boardgameatlas.com/category/3B3QpKvXD3/undefined'},
#    {'id': 'CWYOF9xu7O',
#     'url': 'https://www.boardgameatlas.com/category/CWYOF9xu7O/undefined'}],
#   'publishers': [{'id': '8eHESCflqX',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/8eHESCflqX/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'designers': [{'id': '3P2XFNApXh',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/3P2XFNApXh/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'primary_publisher': {'id': '8eHESCflqX',
#    'name': 'Czech Games Edition',
#    'url': 'https://www.boardgameatlas.com/publisher/8eHESCflqX/czech-games-edition'},
#   'primary_designer': {'id': '3P2XFNApXh',
#    'name': 'Vlaada Chvátil',
#    'url': 'https://www.boardgameatlas.com/designer/3P2XFNApXh/vlaada-chvtil'},
#   'developers': [],
#   'related_to': [],
#   'related_as': [],
#   'artists': ['Tomáš Kučerovský', 'Radim Pech'],
#   'names': [],
#   'rules_url': 'https://czechgames.com/files/rules/galaxy-trucker-rules-en.pdf',
#   'amazon_rank': 11224,
#   'cs_rating': 4.2,
#   'official_url': 'https://czechgames.com/en/galaxy-trucker/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#   'sell_sheet_url': None,
#   'store_images_url': None,
#   'comment_count': 0,
#   'num_user_ratings': 338,
#   'average_user_rating': 3.5933477469276283,
#   'size_height': 9,
#   'historical_low_prices': [{'country': 'AU',
#     'date': '2022-01-07T22:27:14.464Z',
#     'price': 49.95,
#     'isLow': False},
#    {'country': 'UK',
#     'date': '2022-03-18T11:12:14.824Z',
#     'price': 31.01,
#     'isLow': False},
#    {'country': 'CA',
#     'date': '2023-03-13T16:33:11.148Z',
#     'price': 26.99,
#     'isLow': False},
#    {'country': 'US',
#     'date': '2023-04-03T00:09:52.596Z',
#     'price': 27.89,
#     'isLow': False}],
#   'active': True,
#   'num_user_complexity_votes': 3,
#   'average_learning_complexity': 2.3333333333333335,
#   'average_strategy_complexity': 3,
#   'visits': 4218,
#   'lists': 947,
#   'mentions': 6,
#   'links': 4,
#   'plays': 1572,
#   'rank': 101,
#   'type': 'game',
#   'upc': '8594156310615',
#   'num_distributors': 1,
#   'trending_rank': 0,
#   'listing_clicks': 0,
#   'is_historical_low': False,
#   'skus': ['3760175510045',
#    'CGE00061',
#    'CGE00061-DD',
#    '79613',
#    '8594156310011',
#    'MDGGA02273',
#    '8594156310615',
#    '15686:176089',
#    '2149177774',
#    'BG-000436-001',
#    'CGE00001',
#    'MDGGA00024',
#    'RIOA08'],
#   'sku_objects': [{'name': 'Imaginaire Shop', 'sku': '3760175510045'},
#    {'name': 'Wayland Games', 'sku': 'CGE00061'},
#    {'name': 'Boardlandia', 'sku': 'CGE00061-DD'},
#    {'name': 'Game Shack Inc.', 'sku': '79613'},
#    {'name': 'Cardboard Memories Inc.', 'sku': '8594156310011'},
#    {'name': 'Mr. Dice Guy', 'sku': 'MDGGA02273'},
#    {'name': 'LVLUP GAMES', 'sku': '8594156310615'},
#    {'name': 'BoardGameCo', 'sku': '15686:176089'},
#    {'name': 'Noble Knight Games', 'sku': '2149177774'},
#    {'name': 'Meeples and Milkshakes', 'sku': 'BG-000436-001'},
#    {'name': 'Miniature Market', 'sku': 'CGE00001'},
#    {'name': 'Mr. Dice Guy', 'sku': 'MDGGA00024'},
#    {'name': 'Legendesque', 'sku': 'RIOA08'}],
#   'edit_url': '/products/listing-edit?objectId=A38ipJ48QE&product_line=Board Games&type=product',
#   'players': '2-4',
#   'playtime': '60-90',
#   'msrp_text': '$29.95',
#   'price_text': '$27.89',
#   'tags': ['Ciężarówką przez Galaktykę',
#    'Galaxis Roncsderbi',
#    'Galaxy Trucker: Aventuras en el Espacio',
#    'Galaxy Trucker: Aventuri în spațiu',
#    'Galaxy Trucker: Космические дальнобойщики',
#    '銀河卡車司機',
#    'Galaxy Trucker 2nd Edition w Spiele Hit Mark',
#    'Galaxy Trucker',
#    'Galaxy Trucker 2021 Edition'],
#   'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#    'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#    'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#    'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559254997948-517JqXFm1TL.jpg',
#    'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559254997948-517JqXFm1TL.jpg'},
#   'description_preview': " Corporation Incorporated is an interplanetary construction firm that builds sewer systems and low-income housing on the less-developed planets of the Galaxy. For years, Corp Inc. Has tottered on the brink of bankruptcy: transporting building materials to the edge of the Galaxy, where the need for their services is greatest, is a risky business.  The company was saved by a few visionaries on the board of directors. Instead of shipping materials to the Periphery, they reasoned, why not build the materials into spacecraft and let them ship themselves? Furthermore, why hire pilots if there are nut-cases who will do it for free?  That's where you come in. Just sign the contract, and you gain unrestricted access to a Corp Inc. Warehouse. Build your own space ship from the available prefabricated components, and fly it to the Periphery. Of course, you may have to eat a loss, but any profits you make along the way are yours to keep, and Corporation Incorporated will pay you a bonus for quick delivery.  It's possible that you will end up with an insurmountable debt and finish your days panhandling on the streets of Deneb III, but if Lady Luck should smile upon you, you just might find yourself among the 10 billion richest people in the Galaxy! "},
#  {'id': 'jBBIIYQmED',
#   'handle': 'the-voyages-of-marco-polo',
#   'url': 'https://www.boardgameatlas.com/game/jBBIIYQmED/the-voyages-of-marco-polo',
#   'bga_edit_url': 'https://www.boardgameatlas.com/game/jBBIIYQmED/edit',
#   'template_url': '/products/listing?objectId=jBBIIYQmED&product_line=Board Games&type=product',
#   'name': 'The Voyages of Marco Polo',
#   'price': '47.99',
#   'price_ca': '49.95',
#   'price_uk': '0.00',
#   'price_au': '81.99',
#   'msrp': 59.99,
#   'msrps': [{'country': 'US', 'price': 59.99},
#    {'country': 'CA', 'price': 67.99},
#    {'country': 'UK', 'price': 54.99}],
#   'discount': '0.20',
#   'year_published': 2015,
#   'min_players': 2,
#   'max_players': 4,
#   'player_counts': [2, 3, 4],
#   'min_playtime': 45,
#   'max_playtime': 90,
#   'min_age': 12,
#   'description': "<div>\r\n<p><strong>A Grand Voyage!</strong><br />The year is 1275, and Marco Polo has finally reached the court of Kublai Khan after four years of grueling travel over the Silk Road. Together with his father, Marco hoped to establish news trade routes to bring riches from the East back to Europe, and in <em>The Voyages of Marco Polo</em>, you will attempt to do the same.</p>\r\n<p>Players will attempt to recreate Marco Polo's famous journey over the Silk Road, playing as Marco and his father or one of their many associates from their travels, each with their own unique power. Collect points by completing contracts, visiting new cities, and reaching your final destination of Beijing and the court of Kublai Khan. Do you have what it takes to prosper? Find out in <em>The Voyages of Marco Polo</em>!<br /><br /><strong>Preparing to Set Out</strong><br /><em>The Voyages of Marco Polo</em> is a Dice Placement game. At the beginning of each Round, players will roll their dice and then take turns placing those dice in space on the board for various effects. Some spaces have the same effect no matter the number on the die placed there, but some spaces have different effects depending on their result of the roll. Some spaces even require you commit multiple dice and take the action based on the lowest number rolled among the dice placed there.</p>\r\n<p>Placing dice is how players move their merchants down the trade routes and toward Beijing, gather money to pay for goods and their travels, acquire resources to fulfill their contracts. And, spaces are limited! Once another player has filled a space, you'll need to spend more resources in order to take the same action, potentially setting your plan back or forcing you to readjust. Plan well and choose your actions wisely, and you may just find yourself ahead of the pack.<br /><br /><strong>Multiple Strategies</strong><br />There are many decisions to be made from round to round, and there are multiple avenues to victory in any given game. The roads you take to victory can change from game to game thanks to the special power of your character and the unique city bonuses used for each.<br /><br /><strong>Unique Powers<br /></strong> Each character has their own unique ability that can hugely impact your strategy as the game progresses. Raschid ad-Din allows you to choose the value of your dice rather than rolling them. Niccolo and Marco Polo give you an additional figure to move across the map and a camel at the beginning of every round. Take advantage of your special skills and leave your opponents in the dust!<br /><br /><strong>Different City Cards Every Game!<br /></strong> With 31 different city cards, every voyage will be unique. Plan your route carefully as you seek to take advantage of the bonuses each city has to offer. At the beginning of each game, the city bonus cards will be drawn randomly from the deck, providing new strategic opportunities and incredible replayability.</p>\r\n</div>",
#   'commentary': '',
#   'faq': '',
#   'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#   'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#   'matches_specs': None,
#   'specs': [],
#   'mechanics': [{'id': 'jOAB6RhwBp',
#     'url': 'https://www.boardgameatlas.com/mechanic/jOAB6RhwBp/undefined'},
#    {'id': 'R0bGq4cAl4',
#     'url': 'https://www.boardgameatlas.com/mechanic/R0bGq4cAl4/undefined'},
#    {'id': 'wV5peB05xs',
#     'url': 'https://www.boardgameatlas.com/mechanic/wV5peB05xs/undefined'},
#    {'id': '6RZAs0CCpF',
#     'url': 'https://www.boardgameatlas.com/mechanic/6RZAs0CCpF/undefined'},
#    {'id': 'lA3KUtVFCy',
#     'url': 'https://www.boardgameatlas.com/mechanic/lA3KUtVFCy/undefined'},
#    {'id': 'XM2FYZmBHH',
#     'url': 'https://www.boardgameatlas.com/mechanic/XM2FYZmBHH/undefined'},
#    {'id': 'fBOTEBUAmV',
#     'url': 'https://www.boardgameatlas.com/mechanic/fBOTEBUAmV/undefined'},
#    {'id': 'B30dz3Ljjx',
#     'url': 'https://www.boardgameatlas.com/mechanic/B30dz3Ljjx/undefined'}],
#   'categories': [{'id': 'mavSOM8vjH',
#     'url': 'https://www.boardgameatlas.com/category/mavSOM8vjH/undefined'},
#    {'id': 'N0TkEGfEsF',
#     'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/undefined'},
#    {'id': 'QAYkTHK1Dd',
#     'url': 'https://www.boardgameatlas.com/category/QAYkTHK1Dd/undefined'}],
#   'publishers': [{'id': 'UPqP0MXLqj',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/UPqP0MXLqj/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': 'ja1W0hp62r',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/ja1W0hp62r/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'designers': [{'id': 'zQj37XE9iU',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/zQj37XE9iU/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}},
#    {'id': '1HFd9t6DSV',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/1HFd9t6DSV/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'primary_publisher': {'id': 'UPqP0MXLqj',
#    'name': 'Z-Man Games, Inc.',
#    'url': 'https://www.boardgameatlas.com/publisher/UPqP0MXLqj/zman-games-inc'},
#   'primary_designer': {'id': 'zQj37XE9iU',
#    'name': 'Daniele Tascini',
#    'url': 'https://www.boardgameatlas.com/designer/zQj37XE9iU/daniele-tascini'},
#   'developers': [],
#   'related_to': [],
#   'related_as': [],
#   'artists': ['Dennis Lohausen'],
#   'names': [],
#   'rules_url': 'https://www.zmangames.com/en/products/voyages-marco-polo/',
#   'amazon_rank': 156353,
#   'cs_rating': 4.5,
#   'official_url': 'https://www.zmangames.com/en/products/voyages-marco-polo/?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#   'sell_sheet_url': None,
#   'store_images_url': None,
#   'comment_count': 0,
#   'num_user_ratings': 265,
#   'average_user_rating': 3.928422781271838,
#   'size_height': 12.4,
#   'historical_low_prices': [{'country': 'UK',
#     'date': '2021-12-01T08:48:38.627Z',
#     'price': 43.73,
#     'isLow': False},
#    {'country': 'US',
#     'date': '2022-01-10T14:04:04.758Z',
#     'price': 47.99,
#     'isLow': False},
#    {'country': 'AU',
#     'date': '2022-02-08T02:02:35.878Z',
#     'price': 81.99,
#     'isLow': False},
#    {'country': 'CA',
#     'date': '2023-02-04T11:10:36.192Z',
#     'price': 49.95,
#     'isLow': False}],
#   'active': True,
#   'num_user_complexity_votes': 2,
#   'average_learning_complexity': 3.5,
#   'average_strategy_complexity': 4,
#   'visits': 2937,
#   'lists': 864,
#   'mentions': 34,
#   'links': 4,
#   'plays': 1973,
#   'rank': 102,
#   'type': 'game',
#   'sku': 'ZMG7590',
#   'upc': '681706715902',
#   'num_distributors': 3,
#   'trending_rank': 0,
#   'listing_clicks': 0,
#   'is_historical_low': False,
#   'skus': ['ZM7590',
#    'ZMGZM7590',
#    '681706715902',
#    '83359',
#    '180214R',
#    'ZMG71590',
#    'ZMG001',
#    '44896',
#    '1419839489',
#    '2148285421',
#    '2149281673',
#    '44187 #0435',
#    '4610871361',
#    '60953:165032',
#    'BG-000386-001',
#    'MDGTH01494',
#    '2149305528'],
#   'sku_objects': [{'name': 'Boarding School Games', 'sku': 'ZM7590'},
#    {'name': 'Card Haus', 'sku': 'ZMGZM7590'},
#    {'name': '401 Games', 'sku': '681706715902'},
#    {'name': 'Game Shack Inc.', 'sku': '83359'},
#    {'name': 'Dragon’s Den Games', 'sku': '180214R'},
#    {'name': 'Apt to Game', 'sku': 'ZMG71590'},
#    {'name': 'Advent Games', 'sku': 'ZMG001'},
#    {'name': 'Hanabee', 'sku': '44896'},
#    {'name': 'BoardGameBliss Inc', 'sku': '1419839489'},
#    {'name': 'Noble Knight Games', 'sku': '2148285421'},
#    {'name': 'Noble Knight Games', 'sku': '2149281673'},
#    {'name': 'Funagain Games', 'sku': '44187 #0435'},
#    {'name': 'BoardGameBliss Inc', 'sku': '4610871361'},
#    {'name': 'BoardGameCo', 'sku': '60953:165032'},
#    {'name': 'Meeples and Milkshakes', 'sku': 'BG-000386-001'},
#    {'name': 'Mr. Dice Guy', 'sku': 'MDGTH01494'},
#    {'name': 'Noble Knight Games', 'sku': '2149305528'}],
#   'edit_url': '/products/listing-edit?objectId=jBBIIYQmED&product_line=Board Games&type=product',
#   'players': '2-4',
#   'playtime': '45-90',
#   'msrp_text': '$59.99',
#   'price_text': '$47.99',
#   'tags': ['Auf den Spuren von Marco Polo ',
#    'Voyages of Marco Polo The',
#    'Voyages of Marco Polo The Collection Base Game 2 Expansions',
#    'The Voyages Of Marco Polo',
#    'THE VOYAGES OF MARCO POLO',
#    'The Voyages of Marco Polo',
#    'Sulle Tracce di Marco Polo'],
#   'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#    'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#    'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#    'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559255812091-61dG94U7KQL.jpg',
#    'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559255812091-61dG94U7KQL.jpg'},
# ...
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/nl3J7018LJ/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'designers': [{'id': '6wbg6EN7xD',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/6wbg6EN7xD/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'primary_publisher': {'id': 'nl3J7018LJ',
#    'name': 'CMON',
#    'url': 'https://www.boardgameatlas.com/publisher/nl3J7018LJ/cmon'},
#   'primary_designer': {'id': '6wbg6EN7xD',
#    'name': 'Reiner Knizia',
#    'url': 'https://www.boardgameatlas.com/designer/6wbg6EN7xD/reiner-knizia'},
#   'developers': [],
#   'related_to': [],
#   'related_as': [],
#   'artists': ['Carole Carrion',
#    'Manuel Carvalho',
#    'Chen Cheng-po',
#    'Mike Doyle (I)',
#    'Pete Fenlon',
#    'Paul Laane',
#    'Ramon Martins',
#    'Daniel Melim',
#    'Rafael Silveira',
#    'Sigrid Thaler',
#    'Zeilbeck & Natzeck Design Company'],
#   'names': [],
#   'rules_url': 'https://cmon-files.s3.amazonaws.com/pdf/assets_item/resource/80/MA_Rulebbok_Artbook_v18-low.pdf',
#   'amazon_rank': 64198,
#   'cs_rating': 4.5,
#   'official_url': 'https://cmon.com/product/modern-art/modern-art?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#   'comment_count': 0,
#   'num_user_ratings': 195,
#   'average_user_rating': 3.685384615384614,
#   'weight_amount': 1.94,
#   'weight_units': 'lbs',
#   'size_height': 10,
#   'size_depth': 10,
#   'size_units': 'inches',
#   'historical_low_prices': [{'country': 'CA',
#     'date': '2021-12-13T19:31:33.222Z',
#     'price': 32.99,
#     'isLow': True},
#    {'country': 'AU',
#     'date': '2021-12-14T01:38:39.102Z',
#     'price': 41.99,
#     'isLow': False},
#    {'country': 'UK',
#     'date': '2022-03-23T00:10:59.530Z',
#     'price': 24.99,
#     'isLow': False},
#    {'country': 'US',
#     'date': '2023-04-02T04:41:40.613Z',
#     'price': 23.59,
#     'isLow': False}],
#   'active': True,
#   'num_user_complexity_votes': 1,
#   'average_learning_complexity': 2,
#   'average_strategy_complexity': 3,
#   'visits': 8146,
#   'lists': 881,
#   'mentions': 6,
#   'links': 4,
#   'plays': 776,
#   'rank': 190,
#   'type': 'game',
#   'upc': '889696005793',
#   'num_distributors': 4,
#   'trending_rank': 0,
#   'listing_clicks': 9,
#   'is_historical_low': False,
#   'skus': ['MDA001',
#    '2149210166',
#    'CMNMA001',
#    '889696005793',
#    '40552 #0',
#    'B-CG-CMNMDA001',
#    '51733',
#    'MOD01',
#    'COLMDA001',
#    '12430379221043',
#    '2148788040',
#    '25086:4879',
#    '871527',
#    'BG-000274-001',
#    'CMNMDA001',
#    'COLMDC001',
#    '2149109424',
#    '101127',
#    '2148900417',
#    'MDA001-DD',
#    '88771',
#    'MFG4402'],
#   'sku_objects': [{'name': 'Boarding School Games', 'sku': 'MDA001'},
#    {'name': 'Noble Knight Games', 'sku': '2149210166'},
#    {'name': 'Card Haus', 'sku': 'CMNMA001'},
#    {'name': '401 Games', 'sku': '889696005793'},
#    {'name': 'Funagain Games', 'sku': '40552 #0'},
#    {'name': 'Magic Madhouse', 'sku': 'B-CG-CMNMDA001'},
#    {'name': 'Game Shack Inc.', 'sku': '51733'},
#    {'name': 'Advent Games', 'sku': 'MOD01'},
#    {'name': 'Gumnut', 'sku': 'COLMDA001'},
#    {'name': 'BoardGameBliss Inc', 'sku': '12430379221043'},
#    {'name': 'Noble Knight Games', 'sku': '2148788040'},
#    {'name': 'BoardGameCo', 'sku': '25086:4879'},
#    {'name': 'BoardGameBliss Inc', 'sku': '871527'},
#    {'name': 'Meeples and Milkshakes', 'sku': 'BG-000274-001'},
#    {'name': 'Miniature Market', 'sku': 'CMNMDA001'},
#    {'name': 'Gumnut', 'sku': 'COLMDC001'},
#    {'name': 'Noble Knight Games', 'sku': '2149109424'},
#    {'name': 'BoardGameBliss Inc', 'sku': '101127'},
#    {'name': 'Noble Knight Games', 'sku': '2148900417'},
#    {'name': 'Boardlandia', 'sku': 'MDA001-DD'},
#    {'name': 'Hanabee', 'sku': '88771'},
#    {'name': 'Miniature Market', 'sku': 'MFG4402'}],
#   'edit_url': '/products/listing-edit?objectId=fmSDkAqJbH&product_line=Board Games&type=product',
#   'players': '3-5',
#   'playtime': '60-90',
#   'msrp_text': '$29.99',
#   'price_text': '$23.59',
#   'tags': ['Art Moderne',
#    'Arte Moderna',
#    'Современное искусство',
#    'スタンプス (Stamps)',
#    'モダンアート',
#    '現代藝術 (现代艺术)',
#    'Modern Art',
#    'Modern Art Board Game',
#    'Modern Art Printing',
#    'Mayfair Games Modern Art',
#    'Modern Art board game',
#    'MODERN ART',
#    'Modern Art 2nd Printing',
#    'Modern Art Chinese Edition',
#    'Modern Art German Edition',
#    'Modern Art 1st Printing',
#    'Modern Art CMON Edition',
#    'Modern Art 2017'],
#   'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1629324166046.jpg',
#    'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1629324166046.jpg',
#    'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1629324166046.jpg',
#    'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1629324166046.jpg',
#    'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1629324166046.jpg'},
#   'description_preview': " Beauty is in the eye of the beholder, but in the high-stakes world of fine art auctions, there's nothing more beautiful than making a buck.  In Modern Art, players take on the role of curators, buying and selling paintings for their museum. Over the course of four rounds, they take part in a number of auctions, trying to get the best value for the pieces in their collection. Whoever makes the most money wins the game (and keeps their job). "},
#  {'id': '1EXtdJ7zva',
#   'handle': 'spyfall',
#   'url': 'https://www.boardgameatlas.com/game/1EXtdJ7zva/spyfall',
#   'bga_edit_url': 'https://www.boardgameatlas.com/game/1EXtdJ7zva/edit',
#   'template_url': '/products/listing?objectId=1EXtdJ7zva&product_line=Board Games&type=product',
#   'name': 'Spyfall',
#   'price': '16.99',
#   'price_ca': '24.49',
#   'price_uk': '0.00',
#   'price_au': '34.95',
#   'msrp': 24.95,
#   'msrps': [{'country': 'UK', 'price': 24.99},
#    {'country': 'US', 'price': 24.95}],
#   'discount': '0.32',
#   'year_published': 2014,
#   'min_players': 3,
#   'max_players': 8,
#   'player_counts': [3, 4, 5, 6, 7, 8],
#   'min_playtime': 15,
#   'max_playtime': 30,
#   'min_age': 13,
#   'description': "<p>Walk a mile in the shoes of a spy! Or was it a kilometer in clogs?<br /><br />SPYFALL is an easy-to-learn card game of bluffing, probing questions, clever answers, and suspicion. At the start of each round, players receive a secret card letting them know where they are - a casino, space station, pirate ship, circus, (30 unique locations!) - except that one player receives the SPY card instead of the location. The Spy doesn't know where he is, but wins the round if he can figure it out before he blows his cover!<br /><br />Players then start asking each other questions during the intense 8-minute rounds. Non-Spy players want to ask questions and give answers that prove to the other players that they know where they are. But watch out! If your questions and answers are too specific, the Spy will easily guess the location and win, so you need to practice a bit of subtlety. But if your questions and answers are too generic, you might be accused of being the Spy. The Spy will also sometimes be asked questions (just like any other player would) and have to come up with questions of his own, without knowing anything about where he is! If you listened carefully to the other players, you'll be able to come up with a plausible question or answer... hopefully.<br /><br />Once per round, each player may accuse another player of being the Spy. If all players agree, the game ends and that player's secret card is flipped up. If the Spy is captured, each of the Non-Spy players win the round. If a Non-Spy is revealed, the Spy wins. Finally, if the Spy figures out where he is, he can reveal his card and make a guess. If he's right, he wins the round. If not, the Non-Spy players win.<br /><br />The game is played over a series of rounds and points are awarded each round. A complete game is typically five rounds and the cards are randomly dealt each round. You could even be the Spy two rounds in a row! After the last round, the player with the most points is the winner.</p>",
#   'commentary': '',
#   'faq': '',
#   'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#   'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#   'matches_specs': None,
#   'specs': [],
#   'mechanics': [{'id': 'n1GtBt35Rd',
#     'url': 'https://www.boardgameatlas.com/mechanic/n1GtBt35Rd/undefined'},
#    {'id': 'r6yIFvyXDD',
#     'url': 'https://www.boardgameatlas.com/mechanic/r6yIFvyXDD/undefined'},
#    {'id': 'EVeAdboGUA',
#     'url': 'https://www.boardgameatlas.com/mechanic/EVeAdboGUA/undefined'},
#    {'id': 'tyTj0kxoRc',
#     'url': 'https://www.boardgameatlas.com/mechanic/tyTj0kxoRc/undefined'},
#    {'id': 'JYYdBW6UCE',
#     'url': 'https://www.boardgameatlas.com/mechanic/JYYdBW6UCE/undefined'},
#    {'id': 'Tb52O7Id9Q',
#     'url': 'https://www.boardgameatlas.com/mechanic/Tb52O7Id9Q/undefined'}],
#   'categories': [{'id': 'PinhJrhnxU',
#     'url': 'https://www.boardgameatlas.com/category/PinhJrhnxU/undefined'},
#    {'id': 'bCBXJy9qDw',
#     'url': 'https://www.boardgameatlas.com/category/bCBXJy9qDw/undefined'},
#    {'id': 'TYnxiuiI3X',
#     'url': 'https://www.boardgameatlas.com/category/TYnxiuiI3X/undefined'},
#    {'id': 'X8J7RM6dxX',
#     'url': 'https://www.boardgameatlas.com/category/X8J7RM6dxX/undefined'},
#    {'id': 'Hc6vcim5DS',
#     'url': 'https://www.boardgameatlas.com/category/Hc6vcim5DS/undefined'}],
#   'publishers': [{'id': 'Td79E1RD7c',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/publisher/Td79E1RD7c/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'designers': [{'id': 'H9vKZxWHI6',
#     'num_games': None,
#     'score': 9999999,
#     'game': {},
#     'url': 'https://www.boardgameatlas.com/designer/H9vKZxWHI6/undefined',
#     'images': {'thumb': None,
#      'small': None,
#      'medium': None,
#      'large': None,
#      'original': None}}],
#   'primary_publisher': {'id': 'Td79E1RD7c',
#    'name': 'Cryptozoic Entertainment',
#    'url': 'https://www.boardgameatlas.com/publisher/Td79E1RD7c/cryptozoic-entertainment'},
#   'primary_designer': {'id': 'H9vKZxWHI6',
#    'name': 'Alexandr Ushan',
#    'url': 'https://www.boardgameatlas.com/designer/H9vKZxWHI6/alexandr-ushan'},
#   'developers': [],
#   'related_to': [],
#   'related_as': [],
#   'artists': ['Sergey Dulin', 'Uildrim'],
#   'names': [],
#   'rules_url': 'http://international.hobbyworld.ru/download/rules/international/Spyfall_rules_ENG.pdf',
#   'amazon_rank': 5851,
#   'cs_rating': 4.3,
#   'official_url': 'https://www.cryptozoic.com/spyfall?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#   'comment_count': 0,
#   'num_user_ratings': 291,
#   'average_user_rating': 3.2709824135839902,
#   'historical_low_prices': [{'country': 'AU',
#     'date': '2021-02-16T04:20:01.736Z',
#     'price': 31.99,
#     'isLow': False},
#    {'country': 'CA',
#     'date': '2021-12-06T23:01:22.642Z',
#     'price': 24.95,
#     'isLow': False},
#    {'country': 'UK',
#     'date': '2022-08-19T02:51:02.430Z',
#     'price': 19.87,
#     'isLow': False},
#    {'country': 'US',
#     'date': '2023-04-02T18:39:17.848Z',
#     'price': 16.99,
#     'isLow': False}],
#   'active': True,
#   'num_user_complexity_votes': 3,
#   'average_learning_complexity': 1.3333333333333333,
#   'average_strategy_complexity': 2.6666666666666665,
#   'visits': 1551,
#   'lists': 666,
#   'mentions': 4,
#   'links': 6,
#   'plays': 2456,
#   'rank': 191,
#   'type': 'game',
#   'sku': 'CTZ01904',
#   'upc': '815442019042',
#   'num_distributors': 4,
#   'trending_rank': 0,
#   'listing_clicks': 4,
#   'is_historical_low': False,
#   'skus': ['CZE 19042',
#    'CZE01905',
#    '815442019042',
#    '2149084326',
#    '27505',
#    'CRY42019042',
#    'CRYPT001',
#    '82582',
#    'CRY01904',
#    '11332',
#    '2148658816',
#    '46158:163265',
#    'C0425_SPYFALL_SH',
#    'CTZ01904',
#    'CZE01904',
#    'CZE19042',
#    '44155 #0'],
#   'sku_objects': [{'name': 'Boarding School Games', 'sku': 'CZE 19042'},
#    {'name': 'Card Haus', 'sku': 'CZE01905'},
#    {'name': '401 Games', 'sku': '815442019042'},
#    {'name': 'Noble Knight Games', 'sku': '2149084326'},
#    {'name': 'Hanabee', 'sku': '27505'},
#    {'name': 'Gumnut', 'sku': 'CRY42019042'},
#    {'name': 'Advent Games', 'sku': 'CRYPT001'},
#    {'name': 'Game Shack Inc.', 'sku': '82582'},
#    {'name': 'WoodForSheep Hobbies Ltd.', 'sku': 'CRY01904'},
#    {'name': 'Dragon’s Den Games', 'sku': '11332'},
#    {'name': 'Noble Knight Games', 'sku': '2148658816'},
#    {'name': 'BoardGameCo', 'sku': '46158:163265'},
#    {'name': 'Gameology', 'sku': 'C0425_SPYFALL_SH'},
#    {'name': 'Legendesque', 'sku': 'CTZ01904'},
#    {'name': 'Miniature Market', 'sku': 'CZE01904'},
#    {'name': 'Board Game Bandit', 'sku': 'CZE19042'},
#    {'name': 'Funagain Games', 'sku': '44155 #0'}],
#   'edit_url': '/products/listing-edit?objectId=1EXtdJ7zva&product_line=Board Games&type=product',
#   'players': '3-8',
#   'playtime': '15-30',
#   'msrp_text': '$24.95',
#   'price_text': '$16.99',
#   'tags': ['Agent Trouble',
#    'Agent Undercover',
#    'El Espía (que se perdió)',
#    'Mamy Szpiega!',
#    'Superšpión',
#    'Κατάσκοπος',
#    'Находка для шпиона',
#    'スパイフォール',
#    '스파이폴',
#    'Spyfall'],
#   'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#    'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#    'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#    'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559253470032-61I8X7DTQZL.jpg',
#    'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559253470032-61I8X7DTQZL.jpg'},
#   'description_preview': " Walk a mile in the shoes of a spy! Or was it a kilometer in clogs?  SPYFALL is an easy-to-learn card game of bluffing, probing questions, clever answers, and suspicion. At the start of each round, players receive a secret card letting them know where they are - a casino, space station, pirate ship, circus, (30 unique locations!) - except that one player receives the SPY card instead of the location. The Spy doesn't know where he is, but wins the round if he can figure it out before he blows his cover!  Players then start asking each other questions during the intense 8-minute rounds. Non-Spy players want to ask questions and give answers that prove to the other players that they know where they are. But watch out! If your questions and answers are too specific, the Spy will easily guess the location and win, so you need to practice a bit of subtlety. But if your questions and answers are too generic, you might be accused of being the Spy. The Spy will also sometimes be asked questions (just like any other player would) and have to come up with questions of his own, without knowing anything about where he is! If you listened carefully to the other players, you'll be able to come up with a plausible question or answer... hopefully.  Once per round, each player may accuse another player of being the Spy. If all players agree, the game ends and that player's secret card is flipped up. If the Spy is captured, each of the Non-Spy players win the round. If a Non-Spy is revealed, the Spy wins. Finally, if the Spy figures out where he is, he can reveal his card and make a guess. If he's right, he wins the round. If not, the Non-Spy players win.  The game is played over a series of rounds and points are awarded each round. A complete game is typically five rounds and the cards are randomly dealt each round. You could even be the Spy two rounds in a row! After the last round, the player with the most points is the winner. "}]

# %%
game1=games[0]['mechanics']

# %%
game1
# Out:
# [{'id': 'WPytek5P8l',
#   'url': 'https://www.boardgameatlas.com/mechanic/WPytek5P8l/undefined'},
#  {'id': 'T8JEFYwoqy',
#   'url': 'https://www.boardgameatlas.com/mechanic/T8JEFYwoqy/undefined'}]

# %%
new_lis=[]
for i in game1:
    new_lis.append(i['id'])

# %%
new_lis
# Out:
# ['WPytek5P8l', 'T8JEFYwoqy']

# %%
pd.Series(new_lis).map(new_mech)
# Out:
# 0    Hand Management
# 1          Take That
# dtype: object

# %%
# get mechanics in list format for each entry. Replace mechanics col? function.apply()

# %%
pd.DataFrame(data)
# Out:
#                                              mechanics
# 0    {'id': 'SWJGuaim9h', 'name': 'AI enemies', 'ur...
# 1    {'id': 'n1GtBt35Rd', 'name': 'Acting', 'url': ...
# 2    {'id': 'TEmgapaEg0', 'name': 'Action / Event',...
# 3    {'id': 'PGjmKGi26h', 'name': 'Action / Movemen...
# 4    {'id': 'UAV3t3FxVI', 'name': 'Action Drafting'...
# ..                                                 ...
# 218  {'id': 'bbbmSiDpdR', 'name': 'Word Association...
# 219  {'id': 'fBOTEBUAmV', 'name': 'Worker Placement...
# 220  {'id': 'B30dz3Ljjx', 'name': 'Worker Placement...
# 221  {'id': 'PfgjF704uD', 'name': 'Worker Placement...
# 222  {'id': 'M7pWAuRX2d', 'name': 'Zone of Control'...
#
# [223 rows x 1 columns]

# %% [markdown]
# ## columns: mechanics, catagories, publishers, designers, pirmary_publisher, primary_designer, artists, description_preview will be used in nlp analysis

# %%
df.head()
# Out:
#            id               name   price    msrp  year_published  min_players  \
# 0  TAAifFP590               Root   45.00   60.00          2018.0          2.0
# 1  yqR4PtpO8X             Scythe   54.39   90.00          2016.0          1.0
# 2  5H5JS0KLzK           Wingspan   50.00   60.00          2019.0          1.0
# 3  RLlDWHh7hR         Gloomhaven  105.97  140.00          2017.0          1.0
# 4  fDn9rQjH9O  Terraforming Mars   51.99   69.95          2016.0          1.0
#
#    max_players  min_playtime  max_playtime  min_age  \
# 0          4.0          60.0          90.0     10.0
# 1          5.0          90.0         120.0     14.0
# 2          5.0          40.0          70.0     10.0
# 3          4.0          60.0         150.0     12.0
# 4          5.0          90.0         120.0     12.0
#
#                                            mechanics  \
# 0  [{'id': 'PGjmKGi26h', 'url': 'https://www.boar...
# 1  [{'id': 'Bc7R8pLoGk', 'url': 'https://www.boar...
# 2  [{'id': 'R0bGq4cAl4', 'url': 'https://www.boar...
# 3  [{'id': 'xuphiSlrxI', 'url': 'https://www.boar...
# 4  [{'id': '05zCZoLvQJ', 'url': 'https://www.boar...
#
#                                           categories  \
# 0  [{'id': 'KUBCKBkGxV', 'url': 'https://www.boar...
# 1  [{'id': '85OKv8p5Ow', 'url': 'https://www.boar...
# 2  [{'id': 'MWoxgHrOJD', 'url': 'https://www.boar...
# 3  [{'id': 'KUBCKBkGxV', 'url': 'https://www.boar...
# 4  [{'id': 'zyj9ZK3mHB', 'url': 'https://www.boar...
#
#                                           publishers  \
# 0  [{'id': 'jyc9bV7f9D', 'num_games': None, 'scor...
# 1  [{'id': 'njVFVNfJc7', 'num_games': None, 'scor...
# 2  [{'id': 'njVFVNfJc7', 'num_games': None, 'scor...
# 3  [{'id': 'VJ5nXRHPzv', 'num_games': None, 'scor...
# 4  [{'id': '9UanxBIwen', 'num_games': None, 'scor...
#
#                                            designers  \
# 0  [{'id': 'DJCmDFXmsh', 'num_games': None, 'scor...
# 1  [{'id': 'QIz5pAPzFk', 'num_games': None, 'scor...
# 2  [{'id': 'UBhK4cSEV6', 'num_games': None, 'scor...
# 3  [{'id': '7emo74yKS4', 'num_games': None, 'scor...
# 4  [{'id': 'B8c4NTLf9Z', 'num_games': None, 'scor...
#
#                                    primary_publisher  \
# 0  {'id': 'jyc9bV7f9D', 'name': 'Leder Games', 'u...
# 1  {'id': 'njVFVNfJc7', 'name': 'Stonemaier Games...
# 2  {'id': 'njVFVNfJc7', 'name': 'Stonemaier Games...
# 3  {'id': 'VJ5nXRHPzv', 'name': 'Cephalofair Game...
# 4  {'id': '9UanxBIwen', 'name': 'FryxGames', 'url...
#
#                                     primary_designer  \
# 0  {'id': 'DJCmDFXmsh', 'name': 'Cole Wehrle', 'u...
# 1  {'id': 'QIz5pAPzFk', 'name': 'Jamey Stegmaier'...
# 2  {'id': 'UBhK4cSEV6', 'name': 'Elizabeth Hargra...
# 3  {'id': '7emo74yKS4', 'name': 'Isaac Childres',...
# 4  {'id': 'B8c4NTLf9Z', 'name': 'Jacob Fryxelius'...
#
#                                              artists  amazon_rank  \
# 0                                    ['Kyle Ferrin']      16636.0
# 1                                 ['Jakub Różalski']       1583.0
# 2  ['Ana Maria Martinez Jaramillo', 'Natalia Roja...          NaN
# 3  ['Alexandr Elichev', 'Josh T. McDowell', 'Alva...          4.0
# 4                                ['Isaac Fryxelius']       2818.0
#
#    num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 0               412             4.059395                         11
# 1               763             4.213439                         17
# 2               589             4.162919                         12
# 3               491             4.351614                         10
# 4               713             4.146214                         10
#
#    average_learning_complexity  average_strategy_complexity  rank  type  \
# 0                     3.818182                     3.636364     1  game
# 1                     3.117647                     3.235294     2  game
# 2                     2.500000                     2.833333     3  game
# 3                     3.900000                     3.600000     4  game
# 4                     3.000000                     3.300000     5  game
#
#    num_distributors                                description_preview
# 0                 6   Find adventure in this marvelous asymmetric g...
# 1                 9    Scythe  gives players almost complete contro...
# 2                11     Wingspan   is a competitive, medium-weight,...
# 3                 5    Gloomhaven  is a game of Euro-inspired tacti...
# 4                 3   In the 2400s, mankind begins to terraform the...

# %%
df=df.drop(columns=['mechanics', 'categories', 'publishers', 'designers', 'primary_publisher', 'primary_designer',
                    'artists', 'description_preview'])

# %%
df
# Out:
#              id                          name   price    msrp  year_published  \
# 0    TAAifFP590                          Root   45.00   60.00          2018.0
# 1    yqR4PtpO8X                        Scythe   54.39   90.00          2016.0
# 2    5H5JS0KLzK                      Wingspan   50.00   60.00          2019.0
# 3    RLlDWHh7hR                    Gloomhaven  105.97  140.00          2017.0
# 4    fDn9rQjH9O             Terraforming Mars   51.99   69.95          2016.0
# ..          ...                           ...     ...     ...             ...
# 995  utvG6nvnq5                     Snake Oil   19.99   19.95          2010.0
# 996  2LJTEmU5LY     Bob Ross the Art of Chill   24.46   31.99          2017.0
# 997  JBQPZrO0yC            A Study in Emerald  149.95    0.00          2013.0
# 998  kz2pqBlpT4           Mansions of Madness    5.89   99.95          2011.0
# 999  kgs5t2m5kv  Kokoro: Avenue of the Kodama   13.39   19.99          2017.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 0            2.0          4.0          60.0          90.0     10.0
# 1            1.0          5.0          90.0         120.0     14.0
# 2            1.0          5.0          40.0          70.0     10.0
# 3            1.0          4.0          60.0         150.0     12.0
# 4            1.0          5.0          90.0         120.0     12.0
# ..           ...          ...           ...           ...      ...
# 995          3.0         10.0          20.0          30.0     10.0
# 996          2.0          4.0          30.0          30.0     12.0
# 997          2.0          5.0          90.0          90.0     13.0
# 998          2.0          5.0         120.0         180.0     13.0
# 999          2.0          8.0          30.0          45.0     14.0
#
#      amazon_rank  num_user_ratings  average_user_rating  \
# 0        16636.0               412             4.059395
# 1         1583.0               763             4.213439
# 2            NaN               589             4.162919
# 3            4.0               491             4.351614
# 4         2818.0               713             4.146214
# ..           ...               ...                  ...
# 995      99429.0                67             3.130597
# 996      12615.0                64             3.370312
# 997          NaN                30             3.433333
# 998          NaN                68             3.252941
# 999     244208.0                58             3.312069
#
#      num_user_complexity_votes  average_learning_complexity  \
# 0                           11                     3.818182
# 1                           17                     3.117647
# 2                           12                     2.500000
# 3                           10                     3.900000
# 4                           10                     3.000000
# ..                         ...                          ...
# 995                          0                     0.000000
# 996                          1                     3.000000
# 997                          0                     0.000000
# 998                          0                     0.000000
# 999                          0                     0.000000
#
#      average_strategy_complexity  rank  type  num_distributors
# 0                       3.636364     1  game                 6
# 1                       3.235294     2  game                 9
# 2                       2.833333     3  game                11
# 3                       3.600000     4  game                 5
# 4                       3.300000     5  game                 3
# ..                           ...   ...   ...               ...
# 995                     0.000000   939  game                 0
# 996                     2.000000   940  game                 0
# 997                     0.000000   940  game                 0
# 998                     0.000000   941  game                 4
# 999                     0.000000   942  game                 0
#
# [1000 rows x 19 columns]

# %%
df['amazon_rank'].isna().sum()
# Out:
# 227

# %%
df['amazon_rank'].min()
# Out:
# 4.0

# %%
df['amazon_rank'].max()
# Out:
# 2699068.0

# %%
# drop amazon rank because there is too high of variance and missing 25%+ of entries
df=df.drop(columns=['amazon_rank'])

# %%
df
# Out:
#              id                          name   price    msrp  year_published  \
# 0    TAAifFP590                          Root   45.00   60.00          2018.0
# 1    yqR4PtpO8X                        Scythe   54.39   90.00          2016.0
# 2    5H5JS0KLzK                      Wingspan   50.00   60.00          2019.0
# 3    RLlDWHh7hR                    Gloomhaven  105.97  140.00          2017.0
# 4    fDn9rQjH9O             Terraforming Mars   51.99   69.95          2016.0
# ..          ...                           ...     ...     ...             ...
# 995  utvG6nvnq5                     Snake Oil   19.99   19.95          2010.0
# 996  2LJTEmU5LY     Bob Ross the Art of Chill   24.46   31.99          2017.0
# 997  JBQPZrO0yC            A Study in Emerald  149.95    0.00          2013.0
# 998  kz2pqBlpT4           Mansions of Madness    5.89   99.95          2011.0
# 999  kgs5t2m5kv  Kokoro: Avenue of the Kodama   13.39   19.99          2017.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 0            2.0          4.0          60.0          90.0     10.0
# 1            1.0          5.0          90.0         120.0     14.0
# 2            1.0          5.0          40.0          70.0     10.0
# 3            1.0          4.0          60.0         150.0     12.0
# 4            1.0          5.0          90.0         120.0     12.0
# ..           ...          ...           ...           ...      ...
# 995          3.0         10.0          20.0          30.0     10.0
# 996          2.0          4.0          30.0          30.0     12.0
# 997          2.0          5.0          90.0          90.0     13.0
# 998          2.0          5.0         120.0         180.0     13.0
# 999          2.0          8.0          30.0          45.0     14.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 0                 412             4.059395                         11
# 1                 763             4.213439                         17
# 2                 589             4.162919                         12
# 3                 491             4.351614                         10
# 4                 713             4.146214                         10
# ..                ...                  ...                        ...
# 995                67             3.130597                          0
# 996                64             3.370312                          1
# 997                30             3.433333                          0
# 998                68             3.252941                          0
# 999                58             3.312069                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 0                       3.818182                     3.636364     1  game
# 1                       3.117647                     3.235294     2  game
# 2                       2.500000                     2.833333     3  game
# 3                       3.900000                     3.600000     4  game
# 4                       3.000000                     3.300000     5  game
# ..                           ...                          ...   ...   ...
# 995                     0.000000                     0.000000   939  game
# 996                     3.000000                     2.000000   940  game
# 997                     0.000000                     0.000000   940  game
# 998                     0.000000                     0.000000   941  game
# 999                     0.000000                     0.000000   942  game
#
#      num_distributors
# 0                   6
# 1                   9
# 2                  11
# 3                   5
# 4                   3
# ..                ...
# 995                 0
# 996                 0
# 997                 0
# 998                 4
# 999                 0
#
# [1000 rows x 18 columns]

# %%
for col in df:
    print(col)
    print(df[col].isna().sum())
# Out:
# id
# 0
# name
# 0
# price
# 0
# msrp
# 1
# year_published
# 17
# min_players
# 5
# max_players
# 5
# min_playtime
# 5
# max_playtime
# 5
# min_age
# 8
# num_user_ratings
# 0
# average_user_rating
# 0
# num_user_complexity_votes
# 0
# average_learning_complexity
# 0
# average_strategy_complexity
# 0
# rank
# 0
# type
# 0
# num_distributors
# 0

# %% [markdown]
# ## encode nulls

# %%
df[df['msrp'].isna()]
# Out:
#              id               name  price  msrp  year_published  min_players  \
# 252  dJz5fFkFEd  Russian Railroads    0.0   NaN          2013.0          2.0
#
#      max_players  min_playtime  max_playtime  min_age  num_user_ratings  \
# 252          4.0          90.0         120.0     12.0               150
#
#      average_user_rating  num_user_complexity_votes  \
# 252              3.84105                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 252                          0.0                          0.0   242  game
#
#      num_distributors
# 252                 0

# %%
df[df['price']==0]
# Out:
#              id                              name  price    msrp  \
# 139  NYMPJIwU5Y                             Kemet    0.0   69.99
# 140  zNDNB2oGkS                Tigris & Euphrates    0.0   59.95
# 146  uNNMm6GiSF                    Too Many Bones    0.0  129.95
# 161  Q8uHrAGl2m         San Juan (Second Edition)    0.0    0.00
# 171  7o1BvaDKoO                           Eclipse    0.0   84.99
# ..          ...                               ...    ...     ...
# 960  7KaqjuhjrV                             Linko    0.0   12.99
# 979  xObxcMZKmG  Fury of Dracula (Second Edition)    0.0   59.99
# 984  PLTmISGsdZ              Favor of the Pharaoh    0.0   59.95
# 990  YZYf5ea74i                         Elfenland    0.0   44.95
# 992  tyRIYbmPQL      Notre Dame: 10th Anniversary    0.0   44.99
#
#      year_published  min_players  max_players  min_playtime  max_playtime  \
# 139          2012.0          2.0          5.0          90.0         120.0
# 140          1997.0          2.0          4.0          90.0         120.0
# 146          2017.0          1.0          4.0          60.0          90.0
# 161          2014.0          2.0          4.0          45.0          60.0
# 171          2011.0          2.0          6.0          84.0          96.0
# ..              ...          ...          ...           ...           ...
# 960          2014.0          2.0          5.0          20.0          20.0
# 979          2005.0          2.0          5.0         120.0         180.0
# 984          2015.0          2.0          4.0          45.0          60.0
# 990          1998.0          2.0          6.0          60.0          60.0
# 992          2017.0          2.0          5.0          45.0          75.0
#
#      min_age  num_user_ratings  average_user_rating  \
# 139     10.0               221             3.786459
# 140     12.0               232             3.776435
# 146     12.0               102             4.231175
# 161     10.0               100             3.892250
# 171     13.0               226             3.760133
# ..       ...               ...                  ...
# 960     10.0                56             3.401786
# 979     14.0                64             3.378125
# 984     13.0                55             3.313333
# 990     10.0                64             3.318750
# 992     10.0                49             3.585204
#
#      num_user_complexity_votes  average_learning_complexity  \
# 139                          0                          0.0
# 140                          0                          0.0
# 146                          3                          4.0
# 161                          1                          2.0
# 171                          1                          4.0
# ..                         ...                          ...
# 960                          0                          0.0
# 979                          0                          0.0
# 984                          0                          0.0
# 990                          0                          0.0
# 992                          0                          0.0
#
#      average_strategy_complexity  rank  type  num_distributors
# 139                     0.000000   133  game                 1
# 140                     0.000000   134  game                 1
# 146                     3.333333   140  game                 2
# 161                     2.000000   154  game                 0
# 171                     5.000000   164  game                 0
# ..                           ...   ...   ...               ...
# 960                     0.000000   905  game                 0
# 979                     0.000000   923  game                 0
# 984                     0.000000   928  game                 1
# 990                     0.000000   934  game                 0
# 992                     0.000000   936  game                 0
#
# [143 rows x 18 columns]

# %%
df[df['msrp']==0]
# Out:
#              id                                               name   price  \
# 100  qZ7XdSFpaI                               Magic: The Gathering  144.99
# 161  Q8uHrAGl2m                          San Juan (Second Edition)    0.00
# 197  07sKc1TGJS                                          El Grande  209.95
# 311  eCHLF6iV78                            Dice Throne: Season One    0.00
# 417  ZYjgSCG6cv                           Wiz-War (eighth edition)    0.00
# 517  ofOoCiuPUu                         Dominion: Envoy Promo Card    0.00
# 563  J6PNFFOCZL  Arkham Horror: Curse of the Dark Pharaoh Expan...    0.00
# 571  sG1IfquFbA                  Merchant of Venus: Second Edition  219.99
# 574  Cj7DSFMCPL                Dominion: Walled Village Promo Card    0.00
# 597  8pL1hViz7A                                             Thebes   29.99
# 631  EHIBhxHOTU                                            Vikings  124.99
# 668  BAXA5JGFHz                                            On Tour    0.00
# 686  80yQ56cD2C                                        Palm Island    0.00
# 739  ZgDY1krVn7                                    War of the Ring    0.00
# 741  9A2dKB8XJt                      Descent: Journeys in the Dark    0.00
# 756  dDWvce91fM                               The Shipwreck Arcana    0.00
# 767  jOr4mS1C4H                                               Q.E.    0.00
# 768  iBIEAB4abV                                               Dune    0.00
# 796  4VtSwyMWwd                         Dominion: Stash Promo Card    0.00
# 816  0bYFxijrWJ                  Dominion: Black Market Promo Card    0.00
# 901  TH8zODkr1a              Kingsburg: To Forge A Realm Expansion    0.00
# 920  jLaEaWfKBb                                            Madeira  318.27
# 941  hDyzXWsTHg                           Citadels:  The Dark City    0.00
# 997  JBQPZrO0yC                                 A Study in Emerald  149.95
#
#      msrp  year_published  min_players  max_players  min_playtime  \
# 100   0.0          1993.0          2.0          5.0          30.0
# 161   0.0          2014.0          2.0          4.0          45.0
# 197   0.0          1995.0          2.0          5.0          60.0
# 311   0.0          2018.0          2.0          6.0          20.0
# 417   0.0          2012.0          2.0          4.0          30.0
# 517   0.0          2008.0          2.0          4.0          30.0
# 563   0.0          2006.0          1.0          8.0         240.0
# 571   0.0          2012.0          1.0          4.0         120.0
# 574   0.0          2011.0          2.0          4.0          30.0
# 597   0.0             NaN          NaN          NaN           NaN
# 631   0.0             NaN          NaN          NaN           NaN
# 668   0.0          2019.0          1.0          4.0          15.0
# 686   0.0          2018.0          1.0          2.0          15.0
# 739   0.0          2004.0          2.0          4.0         120.0
# 741   0.0          2005.0          2.0          5.0         120.0
# 756   0.0          2017.0          2.0          5.0          10.0
# 767   0.0          2019.0          3.0          5.0          45.0
# 768   0.0          1979.0          2.0          6.0          60.0
# 796   0.0          2010.0          2.0          4.0          30.0
# 816   0.0          2009.0          2.0          4.0          30.0
# 901   0.0             NaN          NaN          NaN           NaN
# 920   0.0          2013.0          2.0          4.0          60.0
# 941   0.0          2004.0          2.0          8.0          60.0
# 997   0.0          2013.0          2.0          5.0          90.0
#
#      max_playtime  min_age  num_user_ratings  average_user_rating  \
# 100          60.0     13.0               310             3.567212
# 161          60.0     10.0               100             3.892250
# 197         120.0     12.0               199             3.866332
# 311          40.0      8.0                84             3.693452
# 417          60.0     14.0                43             3.563953
# 517          30.0     10.0                34             3.691176
# 563         240.0     12.0                27             3.616667
# 571         240.0     14.0                57             3.520000
# 574          30.0     10.0                24             3.673611
# 597           NaN      NaN                92             3.520875
# 631           NaN      NaN                87             3.541954
# 668          25.0      7.0                71             3.636620
# 686          15.0     10.0                65             3.530769
# 739         120.0     12.0                61             4.008361
# 741         240.0     13.0                55             3.611818
# 756          30.0     12.0                62             3.633065
# 767          45.0      NaN                53             3.757604
# 768         180.0     12.0                52             3.793269
# 796          30.0     10.0                26             3.557692
# 816          30.0     10.0                40             3.515000
# 901           NaN      NaN                51             3.867647
# 920         150.0     12.0                51             3.852941
# 941          60.0     10.0                53             3.438005
# 997          90.0     13.0                30             3.433333
#
#      num_user_complexity_votes  average_learning_complexity  \
# 100                          0                          0.0
# 161                          1                          2.0
# 197                          0                          0.0
# 311                          0                          0.0
# 417                          0                          0.0
# 517                          0                          0.0
# 563                          0                          0.0
# 571                          0                          0.0
# 574                          0                          0.0
# 597                          0                          0.0
# 631                          0                          0.0
# 668                          0                          0.0
# 686                          0                          0.0
# 739                          0                          0.0
# 741                          0                          0.0
# 756                          1                          2.0
# 767                          1                          2.0
# 768                          0                          0.0
# 796                          0                          0.0
# 816                          0                          0.0
# 901                          0                          0.0
# 920                          0                          0.0
# 941                          0                          0.0
# 997                          0                          0.0
#
#      average_strategy_complexity  rank       type  num_distributors
# 100                          0.0    98       game                 0
# 161                          2.0   154       game                 0
# 197                          0.0   189       game                 0
# 311                          0.0   296       game                 0
# 417                          0.0   395       game                 1
# 517                          0.0   486  expansion                 0
# 563                          0.0   530  expansion                 0
# 571                          0.0   537       game                 0
# 574                          0.0   539  expansion                 0
# 597                          0.0   562       game                 0
# 631                          0.0   595       game                 0
# 668                          0.0   631       game                 1
# 686                          0.0   648       game                 0
# 739                          0.0   699       game                 0
# 741                          0.0   700       game                 0
# 756                          3.0   714       game                 0
# 767                          3.0   725       game                 0
# 768                          0.0   726       game                 0
# 796                          0.0   752  expansion                 0
# 816                          0.0   769  expansion                 0
# 901                          0.0   851       game                 0
# 920                          0.0   869       game                 0
# 941                          0.0   888  expansion                 0
# 997                          0.0   940       game                 0

# %%
msrpmean= pd.DataFrame(df['msrp'].dropna())

# %%
msrpmean
# Out:
#        msrp
# 0     60.00
# 1     90.00
# 2     60.00
# 3    140.00
# 4     69.95
# ..      ...
# 995   19.95
# 996   31.99
# 997    0.00
# 998   99.95
# 999   19.99
#
# [999 rows x 1 columns]

# %%
msrpmean[msrpmean['msrp']!=0].mean()
# Out:
# msrp    47.428995
# dtype: float64

# %% [markdown]
# ## replace the msrp null and zero values with the mean msrp of 47.43

# %%
df['msrp']= df['msrp'].fillna(47.43)

# %%
df['msrp'].isna().sum()
# Out:
# 0

# %%
msrp_col=df['msrp']

# %%
msrp_col.replace(to_replace=0, value=47.43, inplace=True)

# %%
df
# Out:
#              id                          name   price    msrp  year_published  \
# 0    TAAifFP590                          Root   45.00   60.00          2018.0
# 1    yqR4PtpO8X                        Scythe   54.39   90.00          2016.0
# 2    5H5JS0KLzK                      Wingspan   50.00   60.00          2019.0
# 3    RLlDWHh7hR                    Gloomhaven  105.97  140.00          2017.0
# 4    fDn9rQjH9O             Terraforming Mars   51.99   69.95          2016.0
# ..          ...                           ...     ...     ...             ...
# 995  utvG6nvnq5                     Snake Oil   19.99   19.95          2010.0
# 996  2LJTEmU5LY     Bob Ross the Art of Chill   24.46   31.99          2017.0
# 997  JBQPZrO0yC            A Study in Emerald  149.95   47.43          2013.0
# 998  kz2pqBlpT4           Mansions of Madness    5.89   99.95          2011.0
# 999  kgs5t2m5kv  Kokoro: Avenue of the Kodama   13.39   19.99          2017.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 0            2.0          4.0          60.0          90.0     10.0
# 1            1.0          5.0          90.0         120.0     14.0
# 2            1.0          5.0          40.0          70.0     10.0
# 3            1.0          4.0          60.0         150.0     12.0
# 4            1.0          5.0          90.0         120.0     12.0
# ..           ...          ...           ...           ...      ...
# 995          3.0         10.0          20.0          30.0     10.0
# 996          2.0          4.0          30.0          30.0     12.0
# 997          2.0          5.0          90.0          90.0     13.0
# 998          2.0          5.0         120.0         180.0     13.0
# 999          2.0          8.0          30.0          45.0     14.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 0                 412             4.059395                         11
# 1                 763             4.213439                         17
# 2                 589             4.162919                         12
# 3                 491             4.351614                         10
# 4                 713             4.146214                         10
# ..                ...                  ...                        ...
# 995                67             3.130597                          0
# 996                64             3.370312                          1
# 997                30             3.433333                          0
# 998                68             3.252941                          0
# 999                58             3.312069                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 0                       3.818182                     3.636364     1  game
# 1                       3.117647                     3.235294     2  game
# 2                       2.500000                     2.833333     3  game
# 3                       3.900000                     3.600000     4  game
# 4                       3.000000                     3.300000     5  game
# ..                           ...                          ...   ...   ...
# 995                     0.000000                     0.000000   939  game
# 996                     3.000000                     2.000000   940  game
# 997                     0.000000                     0.000000   940  game
# 998                     0.000000                     0.000000   941  game
# 999                     0.000000                     0.000000   942  game
#
#      num_distributors
# 0                   6
# 1                   9
# 2                  11
# 3                   5
# 4                   3
# ..                ...
# 995                 0
# 996                 0
# 997                 0
# 998                 4
# 999                 0
#
# [1000 rows x 18 columns]

# %%
price_avg=df[(df['msrp']!=47.43) & (df['price']!=0)]

# %%
price_avg['price'].mean()
# Out:
# 51.22747058823519

# %%
price_avg['msrp'].mean()
# Out:
# 46.14354117647071

# %%
price_avg
# Out:
#              id                          name   price    msrp  year_published  \
# 0    TAAifFP590                          Root   45.00   60.00          2018.0
# 1    yqR4PtpO8X                        Scythe   54.39   90.00          2016.0
# 2    5H5JS0KLzK                      Wingspan   50.00   60.00          2019.0
# 3    RLlDWHh7hR                    Gloomhaven  105.97  140.00          2017.0
# 4    fDn9rQjH9O             Terraforming Mars   51.99   69.95          2016.0
# ..          ...                           ...     ...     ...             ...
# 994  ToHciXSlx4          Omen: A Reign of War    9.97   29.99          2011.0
# 995  utvG6nvnq5                     Snake Oil   19.99   19.95          2010.0
# 996  2LJTEmU5LY     Bob Ross the Art of Chill   24.46   31.99          2017.0
# 998  kz2pqBlpT4           Mansions of Madness    5.89   99.95          2011.0
# 999  kgs5t2m5kv  Kokoro: Avenue of the Kodama   13.39   19.99          2017.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 0            2.0          4.0          60.0          90.0     10.0
# 1            1.0          5.0          90.0         120.0     14.0
# 2            1.0          5.0          40.0          70.0     10.0
# 3            1.0          4.0          60.0         150.0     12.0
# 4            1.0          5.0          90.0         120.0     12.0
# ..           ...          ...           ...           ...      ...
# 994          2.0          2.0          30.0          30.0     12.0
# 995          3.0         10.0          20.0          30.0     10.0
# 996          2.0          4.0          30.0          30.0     12.0
# 998          2.0          5.0         120.0         180.0     13.0
# 999          2.0          8.0          30.0          45.0     14.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 0                 412             4.059395                         11
# 1                 763             4.213439                         17
# 2                 589             4.162919                         12
# 3                 491             4.351614                         10
# 4                 713             4.146214                         10
# ..                ...                  ...                        ...
# 994                45             3.730556                          1
# 995                67             3.130597                          0
# 996                64             3.370312                          1
# 998                68             3.252941                          0
# 999                58             3.312069                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 0                       3.818182                     3.636364     1  game
# 1                       3.117647                     3.235294     2  game
# 2                       2.500000                     2.833333     3  game
# 3                       3.900000                     3.600000     4  game
# 4                       3.000000                     3.300000     5  game
# ..                           ...                          ...   ...   ...
# 994                     2.000000                     3.000000   938  game
# 995                     0.000000                     0.000000   939  game
# 996                     3.000000                     2.000000   940  game
# 998                     0.000000                     0.000000   941  game
# 999                     0.000000                     0.000000   942  game
#
#      num_distributors
# 0                   6
# 1                   9
# 2                  11
# 3                   5
# 4                   3
# ..                ...
# 994                 1
# 995                 0
# 996                 0
# 998                 4
# 999                 0
#
# [850 rows x 18 columns]

# %%
price_avg.price.max()
# Out:
# 1138.31

# %%
price_avg[price_avg['price']==1138.31]
# Out:
#              id                    name    price   msrp  year_published  \
# 479  J9W6vjCo0I  Kingdom Death: Monster  1138.31  400.0          2015.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 479          1.0          4.0          60.0         180.0     17.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 479                75                 3.97                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 479                          0.0                          0.0   452  game
#
#      num_distributors
# 479                 0

# %%
price_avg=price_avg[price_avg['name']!='Kingdom Death: Monster']

# %%
price_avg['price'].mean()
# Out:
# 49.9470435806831

# %%
price_avg['price'].median()
# Out:
# 31.91

# %%
price_avg['msrp'].mean()
# Out:
# 45.72674911660794

# %%
price_avg['msrp'].median()
# Out:
# 39.99

# %%
price_avg.sort_values(by='price', ascending=False)
# Out:
#              id                                   name   price   msrp  \
# 355  3KNI7IpaI8            Tales of the Arabian Nights  982.14  59.99
# 669  y4lxyGDCJP                Discworld: Ankh-Morpork  604.18  24.99
# 129  YIBcOZqGkI   Battlestar Galactica: The Board Game  599.99  50.00
# 123  kDvbzBiavI                      The 7th Continent  565.32  69.99
# 186  WCk1e4pjrp                   Shadows Over Camelot  554.66  59.99
# ..          ...                                    ...     ...    ...
# 662  qmcl21WSOV                  Terror In Meeple City    0.30  56.00
# 525  pqUKdUsnjR  Fireball Island: The Curse of Vul-Kar    0.30  74.95
# 185  Q3EWjC8Dm7                               Smash Up    0.30  34.99
# 304  emXlF6hhuP                            Fog of Love    0.30  49.99
# 705  oXhtRrAVuT                             Jump Drive    0.25  24.95
#
#      year_published  min_players  max_players  min_playtime  max_playtime  \
# 355          2009.0          1.0          6.0         120.0         120.0
# 669          2011.0          2.0          4.0          60.0          60.0
# 129          2008.0          3.0          6.0         120.0         180.0
# 123          2017.0          1.0          4.0           5.0        1000.0
# 186          2005.0          3.0          7.0          60.0          90.0
# ..              ...          ...          ...           ...           ...
# 662          2013.0          2.0          4.0          45.0          60.0
# 525          2018.0          2.0          4.0          30.0          60.0
# 185          2012.0          2.0          4.0          45.0          60.0
# 304          2017.0          2.0          2.0          60.0         120.0
# 705          2017.0          2.0          4.0          30.0          45.0
#
#      min_age  num_user_ratings  average_user_rating  \
# 355     12.0               144             3.424861
# 669     11.0                84             3.465595
# 129     10.0               276             3.671715
# 123     14.0               213             3.977358
# 186      8.0               269             3.385230
# ..       ...               ...                  ...
# 662      8.0               104             3.211058
# 525      7.0                87             3.551276
# 185     12.0               337             3.062494
# 304     17.0               157             3.435828
# 705     13.0                92             3.273804
#
#      num_user_complexity_votes  average_learning_complexity  \
# 355                          1                          2.0
# 669                          0                          0.0
# 129                          1                          3.0
# 123                          1                          2.0
# 186                          0                          0.0
# ..                         ...                          ...
# 662                          0                          0.0
# 525                          0                          0.0
# 185                          2                          2.5
# 304                          2                          2.5
# 705                          0                          0.0
#
#      average_strategy_complexity  rank  type  num_distributors
# 355                          2.0   338  game                 1
# 669                          0.0   632  game                 0
# 129                          3.0   124  game                 0
# 123                          2.0   118  game                 0
# 186                          0.0   179  game                 0
# ..                           ...   ...   ...               ...
# 662                          0.0   625  game                 0
# 525                          0.0   494  game                 1
# 185                          2.5   178  game                 5
# 304                          3.0   289  game                 7
# 705                          0.0   667  game                 5
#
# [849 rows x 18 columns]

# %%
price_avg[price_avg['price']>price_avg['msrp']]
# Out:
#              id                     name   price   msrp  year_published  \
# 12   VNBC6yq1WO  The Castles of Burgundy  156.09  41.99          2011.0
# 19   3IPVIROfvl        Brass: Birmingham  161.00  69.99          2018.0
# 22   9iBOPn3lES                Patchwork   27.16  19.99          2014.0
# 24   VibNUMwsqr                Santorini   37.36  29.95          2016.0
# 30   T5lx9elSDt              Love Letter   11.99   9.99          2012.0
# ..          ...                      ...     ...    ...             ...
# 982  H29lsC6Bjn               Blokus Duo   16.89  14.99          2005.0
# 987  u9yP8FTkHJ                  Outlive  112.34  74.99          2017.0
# 991  SrgH7JrRiX             Civilization  256.94  59.95          1980.0
# 993  Xc7cj3lAkF            Tumblin' Dice   90.95  89.99          2004.0
# 995  utvG6nvnq5                Snake Oil   19.99  19.95          2010.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 12           2.0          4.0          30.0          90.0     12.0
# 19           2.0          4.0         120.0         180.0     14.0
# 22           2.0          2.0          15.0          30.0      8.0
# 24           2.0          4.0          15.0          30.0      8.0
# 30           2.0          4.0          20.0          20.0     10.0
# ..           ...          ...           ...           ...      ...
# 982          2.0          2.0          15.0          15.0      5.0
# 987          2.0          6.0          15.0          30.0      8.0
# 991          2.0          7.0         360.0         360.0     12.0
# 993          2.0          4.0          45.0          45.0     13.0
# 995          3.0         10.0          20.0          30.0     10.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 12                606             4.174752                          5
# 19                265             4.330200                          2
# 22                603             3.722653                          2
# 24                519             3.703488                          6
# 30                666             3.435916                          0
# ..                ...                  ...                        ...
# 982                64             3.243750                          0
# 987                34             3.801471                          1
# 991                47             3.708085                          0
# 993                65             3.465385                          0
# 995                67             3.130597                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 12                           2.6                     3.200000    13  game
# 19                           3.5                     3.500000    20  game
# 22                           1.5                     2.000000    23  game
# 24                           1.5                     2.833333    25  game
# 30                           0.0                     0.000000    31  game
# ..                           ...                          ...   ...   ...
# 982                          0.0                     0.000000   926  game
# 987                          3.0                     3.000000   931  game
# 991                          0.0                     0.000000   935  game
# 993                          0.0                     0.000000   937  game
# 995                          0.0                     0.000000   939  game
#
#      num_distributors
# 12                  1
# 19                  1
# 22                  6
# 24                  2
# 30                  5
# ..                ...
# 982                 0
# 987                 0
# 991                 0
# 993                 2
# 995                 0
#
# [174 rows x 18 columns]

# %% [markdown]
# ## It is strange that games would be priced over msrp

# %%
df
# Out:
#              id                          name   price    msrp  year_published  \
# 0    TAAifFP590                          Root   45.00   60.00          2018.0
# 1    yqR4PtpO8X                        Scythe   54.39   90.00          2016.0
# 2    5H5JS0KLzK                      Wingspan   50.00   60.00          2019.0
# 3    RLlDWHh7hR                    Gloomhaven  105.97  140.00          2017.0
# 4    fDn9rQjH9O             Terraforming Mars   51.99   69.95          2016.0
# ..          ...                           ...     ...     ...             ...
# 995  utvG6nvnq5                     Snake Oil   19.99   19.95          2010.0
# 996  2LJTEmU5LY     Bob Ross the Art of Chill   24.46   31.99          2017.0
# 997  JBQPZrO0yC            A Study in Emerald  149.95   47.43          2013.0
# 998  kz2pqBlpT4           Mansions of Madness    5.89   99.95          2011.0
# 999  kgs5t2m5kv  Kokoro: Avenue of the Kodama   13.39   19.99          2017.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 0            2.0          4.0          60.0          90.0     10.0
# 1            1.0          5.0          90.0         120.0     14.0
# 2            1.0          5.0          40.0          70.0     10.0
# 3            1.0          4.0          60.0         150.0     12.0
# 4            1.0          5.0          90.0         120.0     12.0
# ..           ...          ...           ...           ...      ...
# 995          3.0         10.0          20.0          30.0     10.0
# 996          2.0          4.0          30.0          30.0     12.0
# 997          2.0          5.0          90.0          90.0     13.0
# 998          2.0          5.0         120.0         180.0     13.0
# 999          2.0          8.0          30.0          45.0     14.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 0                 412             4.059395                         11
# 1                 763             4.213439                         17
# 2                 589             4.162919                         12
# 3                 491             4.351614                         10
# 4                 713             4.146214                         10
# ..                ...                  ...                        ...
# 995                67             3.130597                          0
# 996                64             3.370312                          1
# 997                30             3.433333                          0
# 998                68             3.252941                          0
# 999                58             3.312069                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 0                       3.818182                     3.636364     1  game
# 1                       3.117647                     3.235294     2  game
# 2                       2.500000                     2.833333     3  game
# 3                       3.900000                     3.600000     4  game
# 4                       3.000000                     3.300000     5  game
# ..                           ...                          ...   ...   ...
# 995                     0.000000                     0.000000   939  game
# 996                     3.000000                     2.000000   940  game
# 997                     0.000000                     0.000000   940  game
# 998                     0.000000                     0.000000   941  game
# 999                     0.000000                     0.000000   942  game
#
#      num_distributors
# 0                   6
# 1                   9
# 2                  11
# 3                   5
# 4                   3
# ..                ...
# 995                 0
# 996                 0
# 997                 0
# 998                 4
# 999                 0
#
# [1000 rows x 18 columns]

# %%
df['price'].isna().sum()
# Out:
# 0

# %%
for col in df:
    print(col)
    print(df[col].isna().sum())
# Out:
# id
# 0
# name
# 0
# price
# 0
# msrp
# 0
# year_published
# 17
# min_players
# 5
# max_players
# 5
# min_playtime
# 5
# max_playtime
# 5
# min_age
# 8
# num_user_ratings
# 0
# average_user_rating
# 0
# num_user_complexity_votes
# 0
# average_learning_complexity
# 0
# average_strategy_complexity
# 0
# rank
# 0
# type
# 0
# num_distributors
# 0

# %% [markdown]
# ## Fill year_published manually by looking up published date online

# %%
ypub=df[df['year_published'].isna()]

# %%
ypub
# Out:
#              id                                               name   price  \
# 114  z7Hu0AyCn3  Legendary Marvel Deckbuilding Game: Fantastic ...   16.99
# 396  MZ2vpUOBmk       Summoner Wars: Guild Dwarves vs Cave Goblins   27.99
# 558  UPodZGkoS0                                              Macao    0.00
# 586  GcjkTYQGRp           Raiders of the North Sea: Hall of Heroes   21.95
# 594  A1XBjjf52o                          Battlelore Second Edition   63.99
# 597  8pL1hViz7A                                             Thebes   29.99
# 602  SmCrd1Fys2                      Dominion: Dark Ages Expansion   30.19
# 631  EHIBhxHOTU                                            Vikings  124.99
# 651  Ss9AWHi4zD                                  Dominion: Alchemy   21.99
# 775  BhwBOPlccN                                         Age of War    0.00
# 808  gXI1WyU9bz                                         Flip Ships    0.00
# 823  vTr88vkdDh                       Machi Koro: Harbor Expansion    0.00
# 848  g8GGoWIH0z                                  Clash of Cultures   59.95
# 856  0Z20rVZ9GQ                                      Axis & Allies   46.95
# 865  Orr9pXvEaP       Cosmic Encounter: Cosmic Incursion Expansion   22.39
# 901  TH8zODkr1a              Kingsburg: To Forge A Realm Expansion    0.00
# 910  KrOSnDs7qp                     Blood Rage: Mystics of Midgard   19.79
#
#       msrp  year_published  min_players  max_players  min_playtime  \
# 114  19.99             NaN          1.0          5.0          45.0
# 396  24.95             NaN          2.0          4.0          30.0
# 558  44.95             NaN          NaN          NaN           NaN
# 586  35.00             NaN          2.0          4.0         180.0
# 594  79.95             NaN          2.0          2.0          60.0
# 597  47.43             NaN          NaN          NaN           NaN
# 602  44.95             NaN          2.0          4.0          30.0
# 631  47.43             NaN          NaN          NaN           NaN
# 651  21.49             NaN          2.0          4.0          24.0
# 775  12.95             NaN          2.0          6.0          15.0
# 808  40.00             NaN          1.0          4.0          30.0
# 823  19.99             NaN          2.0          5.0          20.0
# 848  79.99             NaN          2.0          4.0         180.0
# 856  40.00             NaN          2.0          2.0          90.0
# 865  24.95             NaN          3.0          6.0          90.0
# 901  47.43             NaN          NaN          NaN           NaN
# 910  24.95             NaN          2.0          5.0          60.0
#
#      max_playtime  min_age  num_user_ratings  average_user_rating  \
# 114          60.0     14.0                39             3.894231
# 396          45.0      9.0                28             3.700357
# 558           NaN      NaN                88             3.606250
# 586         240.0     12.0                57             4.091404
# 594          90.0     10.0                75             3.707143
# 597           NaN      NaN                92             3.520875
# 602          45.0     13.0                82             3.858858
# 631           NaN      NaN                87             3.541954
# 651          30.0      8.0                98             3.295238
# 775          30.0     14.0                98             3.010008
# 808          45.0      8.0                54             3.479847
# 823          30.0     10.0                82             3.158537
# 848         240.0     14.0                52             3.718173
# 856          90.0     12.0               101             2.943812
# 865         120.0     12.0                48             3.822917
# 901           NaN      NaN                51             3.867647
# 910          90.0     13.0                34             4.058824
#
#      num_user_complexity_votes  average_learning_complexity  \
# 114                          0                     0.000000
# 396                          0                     0.000000
# 558                          0                     0.000000
# 586                          0                     0.000000
# 594                          0                     0.000000
# 597                          0                     0.000000
# 602                          0                     0.000000
# 631                          0                     0.000000
# 651                          0                     0.000000
# 775                          3                     1.333333
# 808                          0                     0.000000
# 823                          0                     0.000000
# 848                          0                     0.000000
# 856                          1                     2.000000
# 865                          1                     3.000000
# 901                          0                     0.000000
# 910                          0                     0.000000
#
#      average_strategy_complexity  rank       type  num_distributors
# 114                     0.000000   110  expansion                 6
# 396                     0.000000   375       game                 1
# 558                     0.000000   526       game                 0
# 586                     0.000000   551  expansion                 3
# 594                     0.000000   559       game                 0
# 597                     0.000000   562       game                 0
# 602                     0.000000   567  expansion                 7
# 631                     0.000000   595       game                 0
# 651                     0.000000   615  expansion                 6
# 775                     1.666667   733       game                 1
# 808                     0.000000   762       game                 0
# 823                     0.000000   776  expansion                 0
# 848                     0.000000   800       game                 1
# 856                     2.000000   808       game                 0
# 865                     3.000000   816  expansion                 2
# 901                     0.000000   851       game                 0
# 910                     0.000000   860  expansion                 1

# %% [markdown]
# ## Drop entries that have null values across multiple categories

# %%
df=df.drop([597, 631, 901, 558])

# %%
ypub=df[df['year_published'].isna()]
ypub
# Out:
#              id                                               name  price  \
# 114  z7Hu0AyCn3  Legendary Marvel Deckbuilding Game: Fantastic ...  16.99
# 396  MZ2vpUOBmk       Summoner Wars: Guild Dwarves vs Cave Goblins  27.99
# 586  GcjkTYQGRp           Raiders of the North Sea: Hall of Heroes  21.95
# 594  A1XBjjf52o                          Battlelore Second Edition  63.99
# 602  SmCrd1Fys2                      Dominion: Dark Ages Expansion  30.19
# 651  Ss9AWHi4zD                                  Dominion: Alchemy  21.99
# 775  BhwBOPlccN                                         Age of War   0.00
# 808  gXI1WyU9bz                                         Flip Ships   0.00
# 823  vTr88vkdDh                       Machi Koro: Harbor Expansion   0.00
# 848  g8GGoWIH0z                                  Clash of Cultures  59.95
# 856  0Z20rVZ9GQ                                      Axis & Allies  46.95
# 865  Orr9pXvEaP       Cosmic Encounter: Cosmic Incursion Expansion  22.39
# 910  KrOSnDs7qp                     Blood Rage: Mystics of Midgard  19.79
#
#       msrp  year_published  min_players  max_players  min_playtime  \
# 114  19.99             NaN          1.0          5.0          45.0
# 396  24.95             NaN          2.0          4.0          30.0
# 586  35.00             NaN          2.0          4.0         180.0
# 594  79.95             NaN          2.0          2.0          60.0
# 602  44.95             NaN          2.0          4.0          30.0
# 651  21.49             NaN          2.0          4.0          24.0
# 775  12.95             NaN          2.0          6.0          15.0
# 808  40.00             NaN          1.0          4.0          30.0
# 823  19.99             NaN          2.0          5.0          20.0
# 848  79.99             NaN          2.0          4.0         180.0
# 856  40.00             NaN          2.0          2.0          90.0
# 865  24.95             NaN          3.0          6.0          90.0
# 910  24.95             NaN          2.0          5.0          60.0
#
#      max_playtime  min_age  num_user_ratings  average_user_rating  \
# 114          60.0     14.0                39             3.894231
# 396          45.0      9.0                28             3.700357
# 586         240.0     12.0                57             4.091404
# 594          90.0     10.0                75             3.707143
# 602          45.0     13.0                82             3.858858
# 651          30.0      8.0                98             3.295238
# 775          30.0     14.0                98             3.010008
# 808          45.0      8.0                54             3.479847
# 823          30.0     10.0                82             3.158537
# 848         240.0     14.0                52             3.718173
# 856          90.0     12.0               101             2.943812
# 865         120.0     12.0                48             3.822917
# 910          90.0     13.0                34             4.058824
#
#      num_user_complexity_votes  average_learning_complexity  \
# 114                          0                     0.000000
# 396                          0                     0.000000
# 586                          0                     0.000000
# 594                          0                     0.000000
# 602                          0                     0.000000
# 651                          0                     0.000000
# 775                          3                     1.333333
# 808                          0                     0.000000
# 823                          0                     0.000000
# 848                          0                     0.000000
# 856                          1                     2.000000
# 865                          1                     3.000000
# 910                          0                     0.000000
#
#      average_strategy_complexity  rank       type  num_distributors
# 114                     0.000000   110  expansion                 6
# 396                     0.000000   375       game                 1
# 586                     0.000000   551  expansion                 3
# 594                     0.000000   559       game                 0
# 602                     0.000000   567  expansion                 7
# 651                     0.000000   615  expansion                 6
# 775                     1.666667   733       game                 1
# 808                     0.000000   762       game                 0
# 823                     0.000000   776  expansion                 0
# 848                     0.000000   800       game                 1
# 856                     2.000000   808       game                 0
# 865                     3.000000   816  expansion                 2
# 910                     0.000000   860  expansion                 1

# %%
ypub['name'][114]
# Out:
# 'Legendary Marvel Deckbuilding Game: Fantastic Four Expansion'

# %%
years=[2013, 2009, 2018, 2013, 2012, 2010, 2007, 2017, 2012, 2012, 1981, 2010, 2015]
for y in years:
    ypub.fillna(y, limit=1, inplace=True)
# Out:
# /var/folders/qf/t052sdrx70bffjpl89m9_hz00000gn/T/ipykernel_17605/2565055803.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ypub.fillna(y, limit=1, inplace=True)

# %%
ypub
# Out:
#              id                                               name  price  \
# 114  z7Hu0AyCn3  Legendary Marvel Deckbuilding Game: Fantastic ...  16.99
# 396  MZ2vpUOBmk       Summoner Wars: Guild Dwarves vs Cave Goblins  27.99
# 586  GcjkTYQGRp           Raiders of the North Sea: Hall of Heroes  21.95
# 594  A1XBjjf52o                          Battlelore Second Edition  63.99
# 602  SmCrd1Fys2                      Dominion: Dark Ages Expansion  30.19
# 651  Ss9AWHi4zD                                  Dominion: Alchemy  21.99
# 775  BhwBOPlccN                                         Age of War   0.00
# 808  gXI1WyU9bz                                         Flip Ships   0.00
# 823  vTr88vkdDh                       Machi Koro: Harbor Expansion   0.00
# 848  g8GGoWIH0z                                  Clash of Cultures  59.95
# 856  0Z20rVZ9GQ                                      Axis & Allies  46.95
# 865  Orr9pXvEaP       Cosmic Encounter: Cosmic Incursion Expansion  22.39
# 910  KrOSnDs7qp                     Blood Rage: Mystics of Midgard  19.79
#
#       msrp  year_published  min_players  max_players  min_playtime  \
# 114  19.99          2013.0          1.0          5.0          45.0
# 396  24.95          2009.0          2.0          4.0          30.0
# 586  35.00          2018.0          2.0          4.0         180.0
# 594  79.95          2013.0          2.0          2.0          60.0
# 602  44.95          2012.0          2.0          4.0          30.0
# 651  21.49          2010.0          2.0          4.0          24.0
# 775  12.95          2007.0          2.0          6.0          15.0
# 808  40.00          2017.0          1.0          4.0          30.0
# 823  19.99          2012.0          2.0          5.0          20.0
# 848  79.99          2012.0          2.0          4.0         180.0
# 856  40.00          1981.0          2.0          2.0          90.0
# 865  24.95          2010.0          3.0          6.0          90.0
# 910  24.95          2015.0          2.0          5.0          60.0
#
#      max_playtime  min_age  num_user_ratings  average_user_rating  \
# 114          60.0     14.0                39             3.894231
# 396          45.0      9.0                28             3.700357
# 586         240.0     12.0                57             4.091404
# 594          90.0     10.0                75             3.707143
# 602          45.0     13.0                82             3.858858
# 651          30.0      8.0                98             3.295238
# 775          30.0     14.0                98             3.010008
# 808          45.0      8.0                54             3.479847
# 823          30.0     10.0                82             3.158537
# 848         240.0     14.0                52             3.718173
# 856          90.0     12.0               101             2.943812
# 865         120.0     12.0                48             3.822917
# 910          90.0     13.0                34             4.058824
#
#      num_user_complexity_votes  average_learning_complexity  \
# 114                          0                     0.000000
# 396                          0                     0.000000
# 586                          0                     0.000000
# 594                          0                     0.000000
# 602                          0                     0.000000
# 651                          0                     0.000000
# 775                          3                     1.333333
# 808                          0                     0.000000
# 823                          0                     0.000000
# 848                          0                     0.000000
# 856                          1                     2.000000
# 865                          1                     3.000000
# 910                          0                     0.000000
#
#      average_strategy_complexity  rank       type  num_distributors
# 114                     0.000000   110  expansion                 6
# 396                     0.000000   375       game                 1
# 586                     0.000000   551  expansion                 3
# 594                     0.000000   559       game                 0
# 602                     0.000000   567  expansion                 7
# 651                     0.000000   615  expansion                 6
# 775                     1.666667   733       game                 1
# 808                     0.000000   762       game                 0
# 823                     0.000000   776  expansion                 0
# 848                     0.000000   800       game                 1
# 856                     2.000000   808       game                 0
# 865                     3.000000   816  expansion                 2
# 910                     0.000000   860  expansion                 1

# %%
years=[2013, 2009, 2018, 2013, 2012, 2010, 2007, 2017, 2012, 2012, 1981, 2010, 2015]
for y in years:
    df['year_published'].fillna(y, limit=1, inplace=True)

# %%
df[df['name']=='Blood Rage: Mystics of Midgard']
# Out:
#              id                            name  price   msrp  year_published  \
# 910  KrOSnDs7qp  Blood Rage: Mystics of Midgard  19.79  24.95          2015.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 910          2.0          5.0          60.0          90.0     13.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 910                34             4.058824                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  \
# 910                          0.0                          0.0   860
#
#           type  num_distributors
# 910  expansion                 1

# %%
df[df['name']=='Summoner Wars: Guild Dwarves vs Cave Goblins']
# Out:
#              id                                          name  price   msrp  \
# 396  MZ2vpUOBmk  Summoner Wars: Guild Dwarves vs Cave Goblins  27.99  24.95
#
#      year_published  min_players  max_players  min_playtime  max_playtime  \
# 396          2009.0          2.0          4.0          30.0          45.0
#
#      min_age  num_user_ratings  average_user_rating  \
# 396      9.0                28             3.700357
#
#      num_user_complexity_votes  average_learning_complexity  \
# 396                          0                          0.0
#
#      average_strategy_complexity  rank  type  num_distributors
# 396                          0.0   375  game                 1

# %%
for col in df:
    print(col)
    print(df[col].isna().sum())
# Out:
# id
# 0
# name
# 0
# price
# 0
# msrp
# 0
# year_published
# 0
# min_players
# 1
# max_players
# 1
# min_playtime
# 1
# max_playtime
# 1
# min_age
# 4
# num_user_ratings
# 0
# average_user_rating
# 0
# num_user_complexity_votes
# 0
# average_learning_complexity
# 0
# average_strategy_complexity
# 0
# rank
# 0
# type
# 0
# num_distributors
# 0

# %%
df[df['min_players'].isna()]
# Out:
#              id     name  price   msrp  year_published  min_players  \
# 977  jqer4AvMyC  Mancala  13.48  11.95           700.0          NaN
#
#      max_players  min_playtime  max_playtime  min_age  num_user_ratings  \
# 977          NaN           NaN           NaN      NaN                89
#
#      average_user_rating  num_user_complexity_votes  \
# 977             2.914607                          1
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 977                          2.0                          3.0   921  game
#
#      num_distributors
# 977                 1

# %%
df.drop([977], inplace=True)

# %%
df
# Out:
#              id                          name   price    msrp  year_published  \
# 0    TAAifFP590                          Root   45.00   60.00          2018.0
# 1    yqR4PtpO8X                        Scythe   54.39   90.00          2016.0
# 2    5H5JS0KLzK                      Wingspan   50.00   60.00          2019.0
# 3    RLlDWHh7hR                    Gloomhaven  105.97  140.00          2017.0
# 4    fDn9rQjH9O             Terraforming Mars   51.99   69.95          2016.0
# ..          ...                           ...     ...     ...             ...
# 995  utvG6nvnq5                     Snake Oil   19.99   19.95          2010.0
# 996  2LJTEmU5LY     Bob Ross the Art of Chill   24.46   31.99          2017.0
# 997  JBQPZrO0yC            A Study in Emerald  149.95   47.43          2013.0
# 998  kz2pqBlpT4           Mansions of Madness    5.89   99.95          2011.0
# 999  kgs5t2m5kv  Kokoro: Avenue of the Kodama   13.39   19.99          2017.0
#
#      min_players  max_players  min_playtime  max_playtime  min_age  \
# 0            2.0          4.0          60.0          90.0     10.0
# 1            1.0          5.0          90.0         120.0     14.0
# 2            1.0          5.0          40.0          70.0     10.0
# 3            1.0          4.0          60.0         150.0     12.0
# 4            1.0          5.0          90.0         120.0     12.0
# ..           ...          ...           ...           ...      ...
# 995          3.0         10.0          20.0          30.0     10.0
# 996          2.0          4.0          30.0          30.0     12.0
# 997          2.0          5.0          90.0          90.0     13.0
# 998          2.0          5.0         120.0         180.0     13.0
# 999          2.0          8.0          30.0          45.0     14.0
#
#      num_user_ratings  average_user_rating  num_user_complexity_votes  \
# 0                 412             4.059395                         11
# 1                 763             4.213439                         17
# 2                 589             4.162919                         12
# 3                 491             4.351614                         10
# 4                 713             4.146214                         10
# ..                ...                  ...                        ...
# 995                67             3.130597                          0
# 996                64             3.370312                          1
# 997                30             3.433333                          0
# 998                68             3.252941                          0
# 999                58             3.312069                          0
#
#      average_learning_complexity  average_strategy_complexity  rank  type  \
# 0                       3.818182                     3.636364     1  game
# 1                       3.117647                     3.235294     2  game
# 2                       2.500000                     2.833333     3  game
# 3                       3.900000                     3.600000     4  game
# 4                       3.000000                     3.300000     5  game
# ..                           ...                          ...   ...   ...
# 995                     0.000000                     0.000000   939  game
# 996                     3.000000                     2.000000   940  game
# 997                     0.000000                     0.000000   940  game
# 998                     0.000000                     0.000000   941  game
# 999                     0.000000                     0.000000   942  game
#
#      num_distributors
# 0                   6
# 1                   9
# 2                  11
# 3                   5
# 4                   3
# ..                ...
# 995                 0
# 996                 0
# 997                 0
# 998                 4
# 999                 0
#
# [995 rows x 18 columns]

# %%
df.min_players.isna().sum()
# Out:
# 0

# %%
df[df['min_age'].isna()]
# Out:
#              id                                      name   price   msrp  \
# 524  xc8SQv6LCk                                  Pipeline   46.99  69.99
# 614  lRtY2IAF74  The Lord of the Rings: The Confrontation  251.67  34.95
# 767  jOr4mS1C4H                                      Q.E.    0.00  47.43
#
#      year_published  min_players  max_players  min_playtime  max_playtime  \
# 524          2019.0          2.0          4.0         120.0         120.0
# 614          2005.0          2.0          2.0          30.0          30.0
# 767          2019.0          3.0          5.0          45.0          45.0
#
#      min_age  num_user_ratings  average_user_rating  \
# 524      NaN                60             3.845033
# 614      NaN                81             3.650000
# 767      NaN                53             3.757604
#
#      num_user_complexity_votes  average_learning_complexity  \
# 524                          0                          0.0
# 614                          0                          0.0
# 767                          1                          2.0
#
#      average_strategy_complexity  rank  type  num_distributors
# 524                          0.0   493  game                 1
# 614                          0.0   578  game                 0
# 767                          3.0   725  game                 0

# %%
ages= [12, 12, 13]
for y in ages:
    df['min_age'].fillna(y, limit=1, inplace=True)

# %%
for col in df:
    print(col)
    print(df[col].isna().sum())
# Out:
# id
# 0
# name
# 0
# price
# 0
# msrp
# 0
# year_published
# 0
# min_players
# 0
# max_players
# 0
# min_playtime
# 0
# max_playtime
# 0
# min_age
# 0
# num_user_ratings
# 0
# average_user_rating
# 0
# num_user_complexity_votes
# 0
# average_learning_complexity
# 0
# average_strategy_complexity
# 0
# rank
# 0
# type
# 0
# num_distributors
# 0

# %%
df.describe().T
# Out:
#                              count         mean         std          min  \
# price                        995.0    44.797005   78.793065     0.000000
# msrp                         995.0    47.467166   31.344074     4.990000
# year_published               995.0  2010.820101   40.389313  1475.000000
# min_players                  995.0     1.877387    0.702855     1.000000
# max_players                  995.0     5.331658    6.405053     1.000000
# min_playtime                 995.0    52.537688   37.061227     5.000000
# max_playtime                 995.0    82.148744   63.323544     0.000000
# min_age                      995.0    11.097487    2.359438     3.000000
# num_user_ratings             995.0   143.658291  131.271777    23.000000
# average_user_rating          995.0     3.591510    0.322338     1.975753
# num_user_complexity_votes    995.0     1.025126    1.846845     0.000000
# average_learning_complexity  995.0     1.110965    1.324773     0.000000
# average_strategy_complexity  995.0     1.269464    1.473046     0.000000
# rank                         995.0   471.414070  271.495818     1.000000
# num_distributors             995.0     2.311558    2.211962     0.000000
#
#                                      25%          50%          75%      max
# price                          13.990000    27.990000    46.540000  1138.31
# msrp                           25.000000    42.990000    59.990000   400.00
# year_published               2009.000000  2014.000000  2017.000000  3000.00
# min_players                     1.000000     2.000000     2.000000     6.00
# max_players                     4.000000     5.000000     6.000000   100.00
# min_playtime                   30.000000    45.000000    60.000000   360.00
# max_playtime                   45.000000    60.000000   120.000000  1000.00
# min_age                        10.000000    12.000000    13.000000    18.00
# num_user_ratings               63.500000    97.000000   178.000000   991.00
# average_user_rating             3.399797     3.604272     3.789392     4.55
# num_user_complexity_votes       0.000000     0.000000     1.000000    17.00
# average_learning_complexity     0.000000     0.000000     2.000000     5.00
# average_strategy_complexity     0.000000     0.000000     3.000000     5.00
# rank                          238.500000   469.000000   706.500000   942.00
# num_distributors                0.000000     2.000000     4.000000    13.00

# %%
df.shape
# Out:
# (995, 18)

# %%
df.head(1)
# Out:
#            id  name  price  msrp  year_published  min_players  max_players  \
# 0  TAAifFP590  Root   45.0  60.0          2018.0          2.0          4.0
#
#    min_playtime  max_playtime  min_age  num_user_ratings  average_user_rating  \
# 0          60.0          90.0     10.0               412             4.059395
#
#    num_user_complexity_votes  average_learning_complexity  \
# 0                         11                     3.818182
#
#    average_strategy_complexity  rank  type  num_distributors
# 0                     3.636364     1  game                 6

# %%
df[(df['price']==0)&(df['num_distributors']>0)]
# Out:
#              id                                               name  price  \
# 139  NYMPJIwU5Y                                              Kemet    0.0
# 140  zNDNB2oGkS                                 Tigris & Euphrates    0.0
# 146  uNNMm6GiSF                                     Too Many Bones    0.0
# 303  UErVHNWdNr                                          Kingsburg    0.0
# 327  x0sk1fJyaz                                          Roborally    0.0
# 352  zMCUEhrOan                                        Viticulture    0.0
# 374  dzxIDVujmq                                      Broom Service    0.0
# 376  gOTObAtSjb                          Vast: The Crystal Caverns    0.0
# 380  B8AeSW2TWP                                  7 Wonders: Cities    0.0
# 397  fQ8NGxSBVH                                     Dixit: Odyssey    0.0
# 401  7TsBpyt02g                                          Stockpile    0.0
# 417  ZYjgSCG6cv                           Wiz-War (eighth edition)    0.0
# 438  BUuV8FEwsq                                    Thurn and Taxis    0.0
# 469  QtV8B2Ln9d                                       Age of Steam    0.0
# 484  Uqq7wGK2Dv                          Baseball Highlights: 2045    0.0
# 513  WKm8ApKkOk                                           Celestia    0.0
# 516  uZT3Rb75jp                                        Specter Ops    0.0
# 530  vYo3EteAcZ                                        Condottiere    0.0
# 615  CSWZgC2TUk                                A Few Acres of Snow    0.0
# 620  fMsqOx6Onh                                    Betrayal Legacy    0.0
# 626  TGhVamZQWF                                Love Letter: Batman    0.0
# 657  zwkPOweM8V   Arkham Horror: Black Goat of the Woods Expansion    0.0
# 668  BAXA5JGFHz                                            On Tour    0.0
# 671  d1TPKWYUq5                               XCOM: The Board Game    0.0
# 676  KyUv6rMZ14                  Freedom: The Underground Railroad    0.0
# 694  C84M5MPi9r                                  Circle the Wagons    0.0
# 732  uCpzeP9aHx                                 Battle for Rokugan    0.0
# 738  N3HM8L2IOD                           Rhino Hero: Super Battle    0.0
# 754  xR5jNzIUUf                         Heroes of Land, Air, & Sea    0.0
# 763  KiFtnFIIjd                                     Bruxelles 1893    0.0
# 775  BhwBOPlccN                                         Age of War    0.0
# 782  Qg93YtpycK                                     Shadow Hunters    0.0
# 788  H1AkmnsGIx                                      The Reckoners    0.0
# 793  8Z9ya4Yrtj                                         BattleLore    0.0
# 829  te414m48Z5                                      Meeple Circus    0.0
# 877  R4Lps8yyhu                                   Medieval Academy    0.0
# 883  FOcv6nf9s9                                     Pax Porfiriana    0.0
# 908  5676mzAY6o                                      Brew Crafters    0.0
# 922  oIloYBXUny  Legendary: A Marvel Deck Building Game - Villains    0.0
# 923  dtiSgObq7u                                    Ricochet Robots    0.0
# 952  RsQzuBzeZ4                          Runebound (Third Edition)    0.0
# 955  9IMuR0npjy                                           Get Bit!    0.0
# 984  PLTmISGsdZ                               Favor of the Pharaoh    0.0
#
#        msrp  year_published  min_players  max_players  min_playtime  \
# 139   69.99          2012.0          2.0          5.0          90.0
# 140   59.95          1997.0          2.0          4.0          90.0
# 146  129.95          2017.0          1.0          4.0          60.0
# 303   59.99          2007.0          2.0          5.0          90.0
# 327   50.00          1994.0          2.0          8.0          45.0
# 352   60.00          2013.0          2.0          6.0          90.0
# 374   45.00          2015.0          2.0          5.0          30.0
# 376   60.00          2016.0          1.0          5.0          75.0
# 380   34.99          2012.0          2.0          8.0          36.0
# 397   36.99          2011.0          3.0         12.0          30.0
# 401   49.95          2015.0          2.0          5.0          45.0
# 417   47.43          2012.0          2.0          4.0          30.0
# 438  124.95          2006.0          2.0          4.0          60.0
# 469   59.99          2002.0          2.0          6.0         120.0
# 484   39.99          2015.0          1.0          4.0          45.0
# 513   39.95          2015.0          2.0          6.0          30.0
# 516   49.95          2015.0          2.0          5.0          60.0
# 530   29.99          1995.0          2.0          6.0          30.0
# 615   99.95          2011.0          2.0          2.0          60.0
# 620   75.00          2018.0          3.0          5.0          45.0
# 626   10.99          2015.0          2.0          4.0          20.0
# 657   21.29          2008.0          1.0          8.0         120.0
# 668   47.43          2019.0          1.0          4.0          15.0
# 671   59.95          2015.0          1.0          4.0          60.0
# 676   70.00          2012.0          1.0          4.0          90.0
# 694   12.00          2017.0          2.0          2.0          15.0
# 732   39.95          2017.0          2.0          5.0          60.0
# 738   29.99          2017.0          2.0          4.0          10.0
# 754  100.00          2018.0          1.0          4.0          30.0
# 763   59.99          2013.0          2.0          5.0          90.0
# 775   12.95          2007.0          2.0          6.0          15.0
# 782   39.99          2005.0          4.0          8.0          45.0
# 788  100.00          2018.0          1.0          6.0          60.0
# 793   79.95          2006.0          2.0          2.0          60.0
# 829   44.99          2017.0          2.0          5.0          30.0
# 877   39.99          2014.0          2.0          5.0          30.0
# 883   60.00          2012.0          1.0          6.0         120.0
# 908   59.95          2013.0          2.0          5.0          90.0
# 922   59.95          2014.0          1.0          5.0          45.0
# 923   49.99          1999.0          1.0         15.0          30.0
# 952   59.95          2015.0          2.0          4.0         120.0
# 955   19.95          2007.0          3.0          6.0          15.0
# 984   59.95          2015.0          2.0          4.0          45.0
#
#      max_playtime  min_age  num_user_ratings  average_user_rating  \
# 139         120.0     10.0               221             3.786459
# 140         120.0     12.0               232             3.776435
# 146          90.0     12.0               102             4.231175
# 303          90.0     13.0               201             3.458881
# 327         120.0     12.0               196             3.261480
# 352          90.0     13.0               135             3.794815
# 374          75.0     10.0               136             3.551471
# 376          90.0     10.0               130             3.350817
# 380          42.0     10.0               123             3.740976
# 397          36.0      8.0               136             3.575184
# 401          60.0     13.0               119             3.771008
# 417          60.0     14.0                43             3.563953
# 438          60.0     13.0               138             3.418841
# 469         180.0     13.0                85             3.771176
# 484          60.0      9.0                76             3.576974
# 513          45.0      8.0               122             3.391311
# 516          90.0     13.0               109             3.356464
# 530          45.0     12.0               106             3.320991
# 615         120.0     14.0                73             3.459093
# 620          90.0     12.0                62             3.870161
# 626          20.0     10.0                95             3.387744
# 657         180.0     12.0                25             3.566000
# 668          25.0      7.0                71             3.636620
# 671         120.0     14.0                85             3.222941
# 676         120.0     10.0                64             3.746875
# 694          15.0      8.0                73             3.486301
# 732          75.0     14.0                63             3.535714
# 738          20.0      5.0                69             3.569703
# 754         120.0     14.0                49             3.678571
# 763         120.0     12.0                59             3.761213
# 775          30.0     14.0                98             3.010008
# 782          60.0     13.0                99             3.065354
# 788         100.0     13.0                46             3.913043
# 793          60.0     10.0                76             3.450658
# 829          45.0      8.0                70             3.337571
# 877          30.0      8.0                73             3.207192
# 883         120.0     12.0                38             3.555526
# 908         120.0     12.0                55             3.477273
# 922          45.0     14.0                37             3.432432
# 923          30.0     13.0                73             3.404795
# 952         180.0     14.0                46             3.431739
# 955          30.0      7.0                91             2.880824
# 984          60.0     13.0                55             3.313333
#
#      num_user_complexity_votes  average_learning_complexity  \
# 139                          0                     0.000000
# 140                          0                     0.000000
# 146                          3                     4.000000
# 303                          0                     0.000000
# 327                          0                     0.000000
# 352                          0                     0.000000
# 374                          0                     0.000000
# 376                          1                     5.000000
# 380                          0                     0.000000
# 397                          0                     0.000000
# 401                          2                     3.000000
# 417                          0                     0.000000
# 438                          0                     0.000000
# 469                          1                     3.000000
# 484                          1                     2.000000
# 513                          0                     0.000000
# 516                          0                     0.000000
# 530                          1                     2.000000
# 615                          0                     0.000000
# 620                          0                     0.000000
# 626                          0                     0.000000
# 657                          0                     0.000000
# 668                          0                     0.000000
# 671                          0                     0.000000
# 676                          0                     0.000000
# 694                          1                     2.000000
# 732                          1                     2.000000
# 738                          0                     0.000000
# 754                          0                     0.000000
# 763                          0                     0.000000
# 775                          3                     1.333333
# 782                          2                     2.000000
# 788                          0                     0.000000
# 793                          1                     2.000000
# 829                          0                     0.000000
# 877                          0                     0.000000
# 883                          0                     0.000000
# 908                          0                     0.000000
# 922                          1                     3.000000
# 923                          0                     0.000000
# 952                          0                     0.000000
# 955                          0                     0.000000
# 984                          0                     0.000000
#
#      average_strategy_complexity  rank       type  num_distributors
# 139                     0.000000   133       game                 1
# 140                     0.000000   134       game                 1
# 146                     3.333333   140       game                 2
# 303                     0.000000   288       game                 4
# 327                     0.000000   311       game                 1
# 352                     0.000000   335       game                 1
# 374                     0.000000   355       game                 2
# 376                     5.000000   357       game                 2
# 380                     0.000000   360  expansion                 1
# 397                     0.000000   376       game                 1
# 401                     3.000000   380       game                 1
# 417                     0.000000   395       game                 1
# 438                     0.000000   415       game                 2
# 469                     5.000000   443       game                 1
# 484                     3.000000   457       game                 2
# 513                     0.000000   483       game                 2
# 516                     0.000000   486       game                 1
# 530                     2.000000   499       game                 1
# 615                     0.000000   579       game                 1
# 620                     0.000000   584       game                 1
# 626                     0.000000   590       game                 3
# 657                     0.000000   620  expansion                 1
# 668                     0.000000   631       game                 1
# 671                     0.000000   634       game                 2
# 676                     0.000000   638       game                 1
# 694                     2.000000   656       game                 1
# 732                     4.000000   692       game                 3
# 738                     0.000000   698       game                 7
# 754                     0.000000   712       game                 3
# 763                     0.000000   721       game                 1
# 775                     1.666667   733       game                 1
# 782                     1.500000   740       game                 1
# 788                     0.000000   746       game                 1
# 793                     2.000000   750       game                 1
# 829                     0.000000   782       game                 6
# 877                     0.000000   828       game                 1
# 883                     0.000000   835       game                 1
# 908                     0.000000   858       game                 1
# 922                     3.000000   871  expansion                 1
# 923                     0.000000   871       game                 3
# 952                     0.000000   897       game                 1
# 955                     0.000000   900       game                 7
# 984                     0.000000   928       game                 1
